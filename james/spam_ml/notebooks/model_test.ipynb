# %%
# %load_ext autoreload
# %autoreload 2

# %%
from spam_ml.models.simple_linear_with_ratios_and_advanced import JamesSimpleLinearRatiosAdvancedStats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from spam_ml.models.simple_linear_with_ratios_and_advanced import JamesSimpleLinearRatiosAdvancedStats
#
# ModuleNotFoundError: No module named 'spam_ml.models.simple_linear_with_ratios_and_advanced'

# %%
from spam_ml.models.regressors.last_matchup_included import JamesWithLastMatchup

# %%
from spam_ml.models.regressors.mlp_ratios_advanced import MlpRatiosAdvancedStats

# %%
model = MlpRatiosAdvancedStats()

# %%
model.train()
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# ...

# %%
from spam_ml.models.classifiers.last_matchup_classifier import JamesWithLastMatchupClassifier

# %%
model = JamesWithLastMatchupClassifier()

# %%
model.train()
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# ...

# %%
model.save()
# Out:
# Saving model happy_lovelace to C:\Users\james\.spam_cache\models\happy_lovelace
# HERE

# %%
m2 = JamesSimpleLinearRegression("happy_lovelace")
# Out:
# Attempting to load model happy_lovelace from C:\Users\james\.spam_cache\models\happy_lovelace

# %%
m2.model
# Out:
# LinearRegression()

# %%
dir(model.model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
# ...

# %%
model.model.coef_, m2.model.coef_
# Out:
# (array([0.59142614, 0.49212586]), array([0.59142614, 0.49212586]))

# %%
dir(m2.model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
# ...

# %%
m2.model.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 m2.model.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'
