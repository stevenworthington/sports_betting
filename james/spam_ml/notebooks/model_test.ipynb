# %%
# %load_ext autoreload
# %autoreload 2

# %%
from spam_ml.models.simple_linear_with_ratios_and_advanced import JamesSimpleLinearRatiosAdvancedStats

# %%
model = JamesSimpleLinearRatiosAdvancedStats()

# %%
model.train()
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
#           ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# GAME_ID
# 22100032          123.0           49.0           98.0             0.500
# 22100033          121.0           45.0           93.0             0.484
# 22100029           83.0           30.0           97.0             0.309
# 22100031          124.0           42.0           87.0             0.483
# 22100037          124.0           48.0           95.0             0.505
#
#           ROLL_HOME_FG3M  ROLL_HOME_FG3A  ROLL_HOME_FG3_PCT  ROLL_HOME_FTM  \
# GAME_ID
# 22100032            13.0            30.0              0.433           12.0
# 22100033            12.0            35.0              0.343           19.0
# 22100029             7.0            34.0              0.206           16.0
# 22100031            16.0            38.0              0.421           24.0
# 22100037            17.0            38.0              0.447           11.0
#
#           ROLL_HOME_FTA  ROLL_HOME_FT_PCT  ...  ROLL_AWAY_FTA  \
# GAME_ID                                    ...
# 22100032           18.0             0.667  ...           29.0
# 22100033           22.0             0.864  ...           28.0
# 22100029           22.0             0.727  ...           13.0
# 22100031           31.0             0.774  ...           16.0
# 22100037           14.0             0.786  ...           23.0
#
#           ROLL_AWAY_FT_PCT  ROLL_AWAY_OREB  ROLL_AWAY_DREB  ROLL_AWAY_REB  \
# GAME_ID
# 22100032             0.655             5.0            33.0           38.0
# 22100033             0.750             7.0            40.0           47.0
# 22100029             0.923            10.0            40.0           50.0
# 22100031             0.813             9.0            33.0           42.0
# 22100037             0.739            15.0            41.0           56.0
#
#           ROLL_AWAY_AST  ROLL_AWAY_STL  ROLL_AWAY_BLK  ROLL_AWAY_TOV  \
# GAME_ID
# 22100032           19.0            6.0            0.0           15.0
# 22100033           31.0            8.0            2.0           11.0
# 22100029           16.0            7.0            3.0           15.0
# 22100031           26.0            7.0            5.0           16.0
# 22100037           34.0           13.0            9.0           18.0
#
#           ROLL_AWAY_PF
# GAME_ID
# 22100032          26.0
# 22100033          22.0
# 22100029          21.0
# 22100031          20.0
# 22100037          24.0
#
# [5 rows x 36 columns]
#           ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# GAME_ID
# 22100032          123.0           49.0           98.0             0.500
# 22100033          121.0           45.0           93.0             0.484
# 22100029           83.0           30.0           97.0             0.309
# 22100031          124.0           42.0           87.0             0.483
# 22100037          124.0           48.0           95.0             0.505
#
#           ROLL_HOME_FG3M  ROLL_HOME_FG3A  ROLL_HOME_FG3_PCT  ROLL_HOME_FTM  \
# GAME_ID
# 22100032            13.0            30.0              0.433           12.0
# 22100033            12.0            35.0              0.343           19.0
# 22100029             7.0            34.0              0.206           16.0
# 22100031            16.0            38.0              0.421           24.0
# 22100037            17.0            38.0              0.447           11.0
#
#           ROLL_HOME_FTA  ROLL_HOME_FT_PCT  ...  ROLL_AWAY_STL  ROLL_AWAY_BLK  \
# GAME_ID                                    ...
# 22100032           18.0             0.667  ...            6.0            0.0
# 22100033           22.0             0.864  ...            8.0            2.0
# 22100029           22.0             0.727  ...            7.0            3.0
# 22100031           31.0             0.774  ...            7.0            5.0
# 22100037           14.0             0.786  ...           13.0            9.0
#
#           ROLL_AWAY_TOV  ROLL_AWAY_PF  ROLL_HOME_3A_RATE  \
# GAME_ID
# 22100032           15.0          26.0           0.306122
# 22100033           11.0          22.0           0.376344
# 22100029           15.0          21.0           0.350515
# 22100031           16.0          20.0           0.436782
# 22100037           18.0          24.0           0.400000
#
#           ROLL_HOME_ASSIST_TO_TURNOVER_RATE  ROLL_HOME_OTOD_REBRATE  \
# GAME_ID
# 22100032                           4.000000                0.433333
# 22100033                           2.083333                0.225000
# 22100029                           0.736842                0.542857
# 22100031                           1.444444                0.393939
# 22100037                           1.705882                0.227273
#
#           ROLL_AWAY_3A_RATE  ROLL_AWAY_ASSIST_TO_TURNOVER_RATE  \
# GAME_ID
# 22100032           0.500000                           1.266667
# 22100033           0.372093                           2.818182
# 22100029           0.462366                           1.066667
# 22100031           0.333333                           1.625000
# 22100037           0.487179                           1.888889
#
#           ROLL_AWAY_OTOD_REBRATE
# GAME_ID
# 22100032                0.151515
# 22100033                0.175000
# 22100029                0.250000
# 22100031                0.272727
# 22100037                0.365854
#
# [5 rows x 42 columns]
# Index(['ROLL_HOME_PTS', 'ROLL_HOME_FGM', 'ROLL_HOME_FGA', 'ROLL_HOME_FG_PCT',
#        'ROLL_HOME_FG3M', 'ROLL_HOME_FG3A', 'ROLL_HOME_FG3_PCT',
#        'ROLL_HOME_FTM', 'ROLL_HOME_FTA', 'ROLL_HOME_FT_PCT', 'ROLL_HOME_OREB',
#        'ROLL_HOME_DREB', 'ROLL_HOME_REB', 'ROLL_HOME_AST', 'ROLL_HOME_STL',
#        'ROLL_HOME_BLK', 'ROLL_HOME_TOV', 'ROLL_HOME_PF', 'ROLL_AWAY_PTS',
#        'ROLL_AWAY_FGM', 'ROLL_AWAY_FGA', 'ROLL_AWAY_FG_PCT', 'ROLL_AWAY_FG3M',
#        'ROLL_AWAY_FG3A', 'ROLL_AWAY_FG3_PCT', 'ROLL_AWAY_FTM', 'ROLL_AWAY_FTA',
#        'ROLL_AWAY_FT_PCT', 'ROLL_AWAY_OREB', 'ROLL_AWAY_DREB', 'ROLL_AWAY_REB',
#        'ROLL_AWAY_AST', 'ROLL_AWAY_STL', 'ROLL_AWAY_BLK', 'ROLL_AWAY_TOV',
#        'ROLL_AWAY_PF', 'ROLL_HOME_3A_RATE',
#        'ROLL_HOME_ASSIST_TO_TURNOVER_RATE', 'ROLL_HOME_OTOD_REBRATE',
#        'ROLL_AWAY_3A_RATE', 'ROLL_AWAY_ASSIST_TO_TURNOVER_RATE',
#        'ROLL_AWAY_OTOD_REBRATE'],
#       dtype='object')
# Index(['ROLL_HOME_3A_RATE', 'ROLL_HOME_ASSIST_TO_TURNOVER_RATE',
#        'ROLL_HOME_OTOD_REBRATE', 'ROLL_AWAY_3A_RATE',
#        'ROLL_AWAY_ASSIST_TO_TURNOVER_RATE', 'ROLL_AWAY_OTOD_REBRATE',
#        'ROLL_HOME_PTS', 'ROLL_HOME_FGM', 'ROLL_HOME_FGA', 'ROLL_HOME_FG_PCT',
#        'ROLL_HOME_FG3M', 'ROLL_HOME_FG3A', 'ROLL_HOME_FG3_PCT',
#        'ROLL_HOME_FTM', 'ROLL_HOME_FTA', 'ROLL_HOME_FT_PCT', 'ROLL_HOME_OREB',
#        'ROLL_HOME_DREB', 'ROLL_HOME_REB', 'ROLL_HOME_AST', 'ROLL_HOME_STL',
#        'ROLL_HOME_BLK', 'ROLL_HOME_TOV', 'ROLL_HOME_PF', 'ROLL_AWAY_PTS',
#        'ROLL_AWAY_FGM', 'ROLL_AWAY_FGA', 'ROLL_AWAY_FG_PCT', 'ROLL_AWAY_FG3M',
#        'ROLL_AWAY_FG3A', 'ROLL_AWAY_FG3_PCT', 'ROLL_AWAY_FTM', 'ROLL_AWAY_FTA',
#        'ROLL_AWAY_FT_PCT', 'ROLL_AWAY_OREB', 'ROLL_AWAY_DREB', 'ROLL_AWAY_REB',
#        'ROLL_AWAY_AST', 'ROLL_AWAY_STL', 'ROLL_AWAY_BLK', 'ROLL_AWAY_TOV',
#        'ROLL_AWAY_PF', 'index', 'SEASON_ID', 'HOME_TEAM_ID',
#        'HOME_TEAM_ABBREVIATION', 'HOME_TEAM_NAME', 'AWAY_TEAM_ID',
#        'AWAY_TEAM_ABBREVIATION', 'AWAY_TEAM_NAME', 'GAME_DATE', 'HOME_PTS',
#        'AWAY_PTS', 'GAME_RESULT', 'TOTAL_PTS', 'PLUS_MINUS', 'MONTH',
#        'PREV_MONTH', 'TEAM_ID', 'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING',
#        'DEF_RATING', 'E_NET_RATING', 'NET_RATING', 'AST_PCT', 'AST_TO',
#        'AST_RATIO', 'OREB_PCT', 'DREB_PCT', 'REB_PCT', 'TM_TOV_PCT', 'EFG_PCT',
#        'TS_PCT', 'E_PACE', 'PACE', 'PACE_PER40', 'POSS', 'PIE', 'GP_RANK',
#        'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'OFF_RATING_RANK',
#        'DEF_RATING_RANK', 'NET_RATING_RANK', 'AST_PCT_RANK', 'AST_TO_RANK',
#        'AST_RATIO_RANK', 'OREB_PCT_RANK', 'DREB_PCT_RANK', 'REB_PCT_RANK',
#        'TM_TOV_PCT_RANK', 'EFG_PCT_RANK', 'TS_PCT_RANK', 'PACE_RANK',
#        'PIE_RANK', 'SEASON', 'CALENDAR_MONTH'],
#       dtype='object')
# Index(['ROLL_HOME_3A_RATE', 'ROLL_HOME_ASSIST_TO_TURNOVER_RATE',
#        'ROLL_HOME_OTOD_REBRATE', 'ROLL_AWAY_3A_RATE',
#        'ROLL_AWAY_ASSIST_TO_TURNOVER_RATE', 'ROLL_AWAY_OTOD_REBRATE',
#        'ROLL_HOME_PTS', 'ROLL_HOME_FGM', 'ROLL_HOME_FGA', 'ROLL_HOME_FG_PCT',
#        'ROLL_HOME_FG3M', 'ROLL_HOME_FG3A', 'ROLL_HOME_FG3_PCT',
#        'ROLL_HOME_FTM', 'ROLL_HOME_FTA', 'ROLL_HOME_FT_PCT', 'ROLL_HOME_OREB',
#        'ROLL_HOME_DREB', 'ROLL_HOME_REB', 'ROLL_HOME_AST', 'ROLL_HOME_STL',
#        'ROLL_HOME_BLK', 'ROLL_HOME_TOV', 'ROLL_HOME_PF', 'ROLL_AWAY_PTS',
#        'ROLL_AWAY_FGM', 'ROLL_AWAY_FGA', 'ROLL_AWAY_FG_PCT', 'ROLL_AWAY_FG3M',
#        'ROLL_AWAY_FG3A', 'ROLL_AWAY_FG3_PCT', 'ROLL_AWAY_FTM', 'ROLL_AWAY_FTA',
#        'ROLL_AWAY_FT_PCT', 'ROLL_AWAY_OREB', 'ROLL_AWAY_DREB', 'ROLL_AWAY_REB',
#        'ROLL_AWAY_AST', 'ROLL_AWAY_STL', 'ROLL_AWAY_BLK', 'ROLL_AWAY_TOV',
#        'ROLL_AWAY_PF', 'index', 'SEASON_ID', 'HOME_TEAM_ID',
#        'HOME_TEAM_ABBREVIATION', 'HOME_TEAM_NAME', 'AWAY_TEAM_ID',
#        'AWAY_TEAM_ABBREVIATION', 'AWAY_TEAM_NAME', 'GAME_DATE', 'HOME_PTS',
#        'AWAY_PTS', 'GAME_RESULT', 'TOTAL_PTS', 'PLUS_MINUS', 'MONTH',
#        'PREV_MONTH', 'HOME_E_OFF_RATING', 'HOME_OFF_RATING',
#        'HOME_E_DEF_RATING', 'HOME_DEF_RATING', 'HOME_E_NET_RATING',
#        'HOME_NET_RATING', 'HOME_AST_PCT', 'HOME_AST_TO', 'HOME_AST_RATIO',
#        'HOME_OREB_PCT', 'HOME_DREB_PCT', 'HOME_REB_PCT', 'HOME_TM_TOV_PCT',
#        'HOME_EFG_PCT', 'HOME_TS_PCT', 'HOME_E_PACE', 'HOME_PACE',
#        'HOME_PACE_PER40', 'HOME_POSS', 'HOME_PIE', 'HOME_GP_RANK',
#        'HOME_W_RANK', 'HOME_L_RANK', 'HOME_W_PCT_RANK', 'HOME_MIN_RANK',
#        'HOME_OFF_RATING_RANK', 'HOME_DEF_RATING_RANK', 'HOME_NET_RATING_RANK',
#        'HOME_AST_PCT_RANK', 'HOME_AST_TO_RANK', 'HOME_AST_RATIO_RANK',
#        'HOME_OREB_PCT_RANK', 'HOME_DREB_PCT_RANK', 'HOME_REB_PCT_RANK',
#        'HOME_TM_TOV_PCT_RANK', 'HOME_EFG_PCT_RANK', 'HOME_TS_PCT_RANK',
#        'HOME_PACE_RANK', 'HOME_PIE_RANK'],
#       dtype='object')
# Index(['ROLL_HOME_3A_RATE', 'ROLL_HOME_ASSIST_TO_TURNOVER_RATE',
#        'ROLL_HOME_OTOD_REBRATE', 'ROLL_AWAY_3A_RATE',
#        'ROLL_AWAY_ASSIST_TO_TURNOVER_RATE', 'ROLL_AWAY_OTOD_REBRATE',
#        'ROLL_HOME_PTS', 'ROLL_HOME_FGM', 'ROLL_HOME_FGA', 'ROLL_HOME_FG_PCT',
#        ...
#        'OREB_PCT_RANK', 'DREB_PCT_RANK', 'REB_PCT_RANK', 'TM_TOV_PCT_RANK',
#        'EFG_PCT_RANK', 'TS_PCT_RANK', 'PACE_RANK', 'PIE_RANK', 'SEASON',
#        'CALENDAR_MONTH'],
#       dtype='object', length=139)
# Index(['ROLL_HOME_3A_RATE', 'ROLL_HOME_ASSIST_TO_TURNOVER_RATE',
#        'ROLL_HOME_OTOD_REBRATE', 'ROLL_AWAY_3A_RATE',
#        'ROLL_AWAY_ASSIST_TO_TURNOVER_RATE', 'ROLL_AWAY_OTOD_REBRATE',
#        'ROLL_HOME_PTS', 'ROLL_HOME_FGM', 'ROLL_HOME_FGA', 'ROLL_HOME_FG_PCT',
#        ...
#        'AWAY_AST_TO_RANK', 'AWAY_AST_RATIO_RANK', 'AWAY_OREB_PCT_RANK',
#        'AWAY_DREB_PCT_RANK', 'AWAY_REB_PCT_RANK', 'AWAY_TM_TOV_PCT_RANK',
#        'AWAY_EFG_PCT_RANK', 'AWAY_TS_PCT_RANK', 'AWAY_PACE_RANK',
#        'AWAY_PIE_RANK'],
#       dtype='object', length=136)
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\box_score_ratios_feature_group.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cur] = df[f"{pref}FG3A"] / df[f"{pref}FGA"]
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\box_score_ratios_feature_group.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cur] = df[f"{pref}AST"] / df[f"{pref}TOV"]
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\box_score_ratios_feature_group.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cur] = df[f"{pref}OREB"] / df[f"{pref}DREB"]
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\box_score_ratios_feature_group.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cur] = df[f"{pref}FG3A"] / df[f"{pref}FGA"]
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\box_score_ratios_feature_group.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cur] = df[f"{pref}AST"] / df[f"{pref}TOV"]
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\box_score_ratios_feature_group.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cur] = df[f"{pref}OREB"] / df[f"{pref}DREB"]
# train_rmse=19.112689051697703
# (      ROLL_HOME_PTS  ROLL_AWAY_PTS  ROLL_HOME_3A_RATE  \
#  2173          114.2          113.0           0.332613
#  1858          113.6          114.6           0.398268
#  214           110.0          106.4           0.446009
#  346           128.6          107.8           0.476852
#  2298          129.0          103.5           0.432836
#  ...             ...            ...                ...
#  666           120.4          115.6           0.359202
#  95            105.6          110.0           0.387528
#  1398          107.8          111.2           0.359413
#  546           103.0          104.6           0.440909
#  2851          129.8          118.4           0.391775
#
#        ROLL_HOME_ASSIST_TO_TURNOVER_RATE  ROLL_HOME_OTOD_REBRATE  \
#  2173                           2.537037                0.314465
#  1858                           2.062500                0.267442
#  214                            2.274510                0.287500
#  346                            2.095238                0.254237
#  2298                           2.146667                0.274286
#  ...                                 ...                     ...
#  666                            2.345455                0.314815
#  95                             1.580645                0.312849
#  1398                           1.765625                0.203593
#  546                            1.937500                0.293814
#  2851                           2.833333                0.288136
#
#        ROLL_AWAY_3A_RATE  ROLL_AWAY_ASSIST_TO_TURNOVER_RATE  \
#  2173           0.332524                           2.370968
#  1858           0.310421                           2.551724
#  214            0.408578                           1.437500
#  346            0.293023                           1.830769
#  2298           0.437158                           1.542857
#  ...                 ...                                ...
#  666            0.336933                           2.105263
#  95             0.403341                           1.791667
#  1398           0.360759                           1.661972
#  546            0.425968                           1.852941
#  2851           0.453089                           2.457627
#
#        ROLL_AWAY_OTOD_REBRATE  HOME_OFF_RATING  HOME_DEF_RATING  HOME_PACE  \
#  2173                0.261438            112.0            111.0      99.40
#  1858                0.360465            111.4            117.6     101.93
#  214                 0.354651             99.3            103.7      99.17
#  346                 0.280822            116.7            108.3      97.47
#  2298                0.545455            119.6            110.6     104.00
#  ...                      ...              ...              ...        ...
#  666                 0.361963            109.3            117.7      99.63
#  95                  0.204420             97.2            111.1     100.25
#  1398                0.414474            113.1            108.8      97.78
#  546                 0.216931            108.5            112.9      99.86
#  2851                0.233696            126.1            115.8     103.29
#
#        HOME_NET_RATING  AWAY_OFF_RATING  AWAY_DEF_RATING  AWAY_PACE  \
#  2173              1.0            118.6            112.6      99.84
#  1858             -6.2            108.6            110.9      98.55
#  214              -4.4            103.3            104.4      99.57
#  346               8.5            107.0            108.4      96.37
#  2298              9.0            109.2            119.8     100.88
#  ...               ...              ...              ...        ...
#  666              -8.5            115.7            116.9      99.07
#  95              -13.9            103.7            104.1     100.64
#  1398              4.4            102.8            113.3      99.84
#  546              -4.4            110.5            104.7      96.96
#  2851             10.4            116.5            114.7      97.14
#
#        AWAY_NET_RATING  TOTAL_PTS
#  2173              6.0        193
#  1858             -2.3        221
#  214              -1.1        210
#  346              -1.4        212
#  2298            -10.6        252
#  ...               ...        ...
#  666              -1.2        213
#  95               -0.4        216
#  1398            -10.5        238
#  546               5.9        218
#  2851              1.8        212
#
#  [2436 rows x 17 columns],
#        ROLL_HOME_PTS  ROLL_AWAY_PTS  ROLL_HOME_3A_RATE  \
#  1853         118.20          123.0           0.396018
#  500          114.60          113.0           0.460674
#  703          110.40          105.8           0.397129
#  2606         119.60          115.0           0.383673
#  1990         122.40          115.8           0.412017
#  ...             ...            ...                ...
#  39           108.75          110.0           0.307471
#  2614         123.00          112.6           0.430108
#  101          112.75          110.8           0.369628
#  2453         122.80          112.0           0.475983
#  2575         112.00          108.2           0.363431
#
#        ROLL_HOME_ASSIST_TO_TURNOVER_RATE  ROLL_HOME_OTOD_REBRATE  \
#  1853                           2.050000                0.247059
#  500                            1.527027                0.331081
#  703                            2.178571                0.244318
#  2606                           2.321429                0.446809
#  1990                           2.557692                0.346154
#  ...                                 ...                     ...
#  39                             2.309524                0.197183
#  2614                           2.350000                0.378378
#  101                            2.108696                0.228188
#  2453                           2.161765                0.325714
#  2575                           2.460317                0.321429
#
#        ROLL_AWAY_3A_RATE  ROLL_AWAY_ASSIST_TO_TURNOVER_RATE  \
#  1853           0.494481                           2.041667
#  500            0.347619                           2.035088
#  703            0.442130                           1.781250
#  2606           0.317597                           2.727273
#  1990           0.358974                           1.354839
#  ...                 ...                                ...
#  39             0.411243                           1.900000
#  2614           0.404977                           1.637681
#  101            0.453362                           1.966667
#  2453           0.350562                           1.983871
#  2575           0.383721                           1.604938
#
#        ROLL_AWAY_OTOD_REBRATE  HOME_OFF_RATING  HOME_DEF_RATING  HOME_PACE  \
#  1853                0.274286            115.1            115.1     101.18
#  500                 0.263473            114.3            121.3      97.75
#  703                 0.368421            111.5            115.8      97.00
#  2606                0.395210            116.4            115.4      97.92
#  1990                0.306011            118.2            116.8     102.17
#  ...                      ...              ...              ...        ...
#  39                  0.326087            107.0             99.3      99.58
#  2614                0.356643            113.6            116.0     100.34
#  101                 0.344444            106.2            105.8     100.00
#  2453                0.369318            116.4            112.4     104.05
#  2575                0.326389            114.2            114.4      99.64
#
#        HOME_NET_RATING  AWAY_OFF_RATING  AWAY_DEF_RATING  AWAY_PACE  \
#  1853              0.0            113.9            111.7     102.27
#  500              -6.9            109.1            110.3      94.72
#  703              -4.2            108.6            109.4      94.27
#  2606              1.0            116.6            114.5      97.53
#  1990              1.5            113.9            116.9     100.86
#  ...               ...              ...              ...        ...
#  39                7.7            114.9            106.3      97.50
#  2614             -2.4            105.7            111.9      98.53
#  101               0.3            106.0            109.1     102.36
#  2453              4.0            118.4            102.2     101.75
#  2575             -0.2            114.0            122.9      99.30
#
#        AWAY_NET_RATING  TOTAL_PTS
#  1853              2.1        221
#  500              -1.3        202
#  703              -0.8        217
#  2606              2.2        239
#  1990             -2.9        248
#  ...               ...        ...
#  39                8.5        219
#  2614             -6.1        232
#  101              -3.0        220
#  2453             16.2        248
#  2575             -8.9        213
#
#  [610 rows x 17 columns])

# %%
model.save()
# Out:
# Saving model happy_lovelace to C:\Users\james\.spam_cache\models\happy_lovelace
# HERE

# %%
m2 = JamesSimpleLinearRegression("happy_lovelace")
# Out:
# Attempting to load model happy_lovelace from C:\Users\james\.spam_cache\models\happy_lovelace

# %%
m2.model
# Out:
# LinearRegression()

# %%
dir(model.model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_intercept',
#  '_validate_data',
#  '_validate_params',
#  'coef_',
#  'copy_X',
#  'fit',
#  'fit_intercept',
#  'get_metadata_routing',
#  'get_params',
#  'intercept_',
#  'n_features_in_',
#  'n_jobs',
#  'positive',
#  'predict',
#  'rank_',
#  'score',
#  'set_fit_request',
#  'set_params',
#  'set_score_request',
#  'singular_']

# %%
model.model.coef_, m2.model.coef_
# Out:
# (array([0.59142614, 0.49212586]), array([0.59142614, 0.49212586]))

# %%
dir(m2.model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_intercept',
#  '_validate_data',
#  '_validate_params',
#  'copy_X',
#  'fit',
#  'fit_intercept',
#  'get_metadata_routing',
#  'get_params',
#  'n_jobs',
#  'positive',
#  'predict',
#  'score',
#  'set_fit_request',
#  'set_params',
#  'set_score_request']

# %%
m2.model.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 m2.model.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'
