# %%
# %load_ext autoreload
# %autoreload 2

# %%
from spam_ml.models.classifiers.first_classifier_test import JamesSimpleLinearRatiosAdvancedStatsClassifier

# %%
model = JamesSimpleLinearRatiosAdvancedStatsClassifier()

# %%
train_df, test_df = model.train()
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# ...

# %%
m = model.model

# %%
m
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

# %%
test_df
# Out:
#       ROLL_HOME_PTS  ROLL_AWAY_PTS  ROLL_HOME_3A_RATE  ROLL_HOME_ASSIST_TO_TURNOVER_RATE  ...  AWAY_DEF_RATING  AWAY_PACE  AWAY_NET_RATING  GAME_RESULT
# 1406          112.4          103.6           0.495370                           2.226415  ...            107.7      99.70              3.0            0
# 837           116.0          106.4           0.322296                           2.098361  ...            117.2      99.02            -11.2            0
# 2847          119.4          127.2           0.424779                           2.278689  ...            116.2     100.39              2.8            0
# 440           122.0          103.6           0.424444                           2.041667  ...            105.1      99.55              5.7            0
# 3019          121.0          124.2           0.382743                           2.566038  ...            115.0      99.25              5.6            1
# ...

# %%
accuracy_score(test_df.GAME_RESULT, m.predict(test_df.drop(columns=["GAME_RESULT"])))
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_ml\.venv\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# 0.6295081967213115
