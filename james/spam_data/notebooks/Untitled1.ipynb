# %%
# %load_ext autoreload
# %autoreload 2

# %%
from spam_data.api.cache_filler import load_or_fetch_from_cache
from spam_data.api import BOX_SCORE_ADVANCED_STATISTICS, ALL_GAMES_BOX_SCORES

# %%
from spam_data.api import game_stats

# %%
df = load_or_fetch_from_cache(BOX_SCORE_ADVANCED_STATISTICS)
# Out:
# [22300821, 22300804, 22300777, 22300763, 22300754, 22300742, 22300729, 22300716, 22300699, 22300690, 22300669, 22300653, 22300634, 22300626, 22300613, 22300595, 22300587, 22300570, 22300559, 22300543, 22300533, 22300521, 22300499, 22300480, 22300467, 22300445, 22300431, 22300408, 22300393, 22300384, 22300371, 22300352, 22300336, 22300330, 22300313, 22300296, 22301218, 22301209, 22300286, 22300272, 22300055, 22300246, 22300241, 22300227, 22300039, 22300029, 22300193, 22300018, 22300175, 22300172, 22300155, 22300135, 22300117, 22300104, 22300097, 22300079, 22300063, 1522300074, 1522300046, 1522300038, 1522300023, 1522300007, 22201216, 22201205, 22201191, 22201182, 22201167, 22201153, 22201131, 22201115, 22201107, 22201090, 22201078, 22201065, 22201048, 22201021, 22201008, 22200999, 22200985, 22200974, 22200958, 22200947, 22200923, 22200911, 22200896, 22200876, 22200857, 22200850, 22200832, 22200818, 22200801, 22200792, 22200777, 22200763, 22200745, 22200725, 22200708, 22200694, 2220068
# ...

# %%
ids = game_stats.get_game_ids_from_season_id(22021)

# %%
ids3 = game_stats.get_game_ids_from_season_id(22023)

# %%
ids
# Out:
# [22101221,
#  22101207,
#  22101192,
#  22101182,
#  22101163,
#  22100452,
#  22101143,
#  22101124,
#  22101102,
#  22101085,
#  22101081,
#  22101064,
#  22101047,
#  22101033,
#  22101021,
#  22101016,
#  22100996,
#  22100984,
#  22100968,
#  22100948,
#  22100710,
#  22100927,
#  22100906,
#  22100891,
#  22100874,
#  22100867,
#  22100856,
#  22100841,
#  22100816,
#  22100807,
#  22100790,
#  22100783,
#  22100767,
#  22100751,
#  22100737,
#  22100725,
#  22100703,
#  22100687,
#  22100670,
#  22100660,
#  22100643,
#  22100636,
#  22100621,
#  22100597,
#  22100589,
#  22100577,
#  22100560,
#  22100533,
#  22100519,
#  22100502,
#  22100488,
#  22100478,
#  22100470,
#  22100434,
#  22100418,
#  22100407,
#  22100384,
#  22100359,
#  22100350,
#  22100335,
#  22100319,
#  22100293,
#  22100285,
#  22100277,
#  22100255,
#  22100242,
#  22100215,
#  22100202,
#  22100193,
#  22100182,
#  22100156,
#  22100152,
#  22100137,
#  22100120,
#  22100113,
#  22100097,
# ...

# %%
df = game_stats.get_adv_stats_df(ids)
# Out:
# 22101221
# Error retrieving 22101221
# 22101207
# Error retrieving 22101207
# 22101192
# Error retrieving 22101192
# 22101182
# Error retrieving 22101182
# 22101163
# Error retrieving 22101163
# 22100452
# Error retrieving 22100452
# 22101143
# Error retrieving 22101143
# 22101124
# Error retrieving 22101124
# 22101102
# Error retrieving 22101102
# 22101085
# Error retrieving 22101085
# 22101081
# Error retrieving 22101081
# KeyboardInterrupt

# %%
from nba_api.stats.static import teams, players
from nba_api.stats.endpoints import (
  scoreboard, leaguegamefinder, playercareerstats,
  boxscorematchupsv3, boxscoreadvancedv2, teamestimatedmetrics, 
  teamgamelogs, TeamGameLogs, TeamEstimatedMetrics, leaguedashteamstats,
    hustlestatsboxscore, boxscoremiscv2, boxscorefourfactorsv2,
    boxscorescoringv2, boxscoreusagev2, boxscoreplayertrackv2, boxscoreadvancedv3
)

def adv_test(game_id_list):
    adv_games_stats_list = []
    for id in game_id_list:
        print(id)
        # query for games
        games = boxscoreadvancedv3.BoxScoreAdvancedV3(game_id=id)
        print(games)
        print(dir(games))
        adv_games_stats_list.append(games.get_data_frames()[1])
        time.sleep(3)
    adv_stats_df = pd.concat(adv_games_stats_list, ignore_index=True)
    adv_stats_df = adv_stats_df.drop_duplicates()
    return adv_stats_df

# %%
boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=21000400)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=21000400)
#
# File ~\Documents\Capstone\sports_betting\james\spam_data\.venv\lib\site-packages\nba_api\stats\endpoints\boxscoreadvancedv2.py:113, in BoxScoreAdvancedV2.__init__(self, game_id, end_period, end_range, range_type, start_period, start_range, proxy, headers, timeout, get_request)
#     104 self.parameters = {
#     105     "GameID": game_id,
#     106     "EndPeriod": end_period,
#    (...)
#     110     "StartRange": start_range,
#     111 }
#     112 if get_request:
# --> 113     self.get_request()
#
# File ~\Documents\Capstone\sports_betting\james\spam_data\.venv\lib\site-packages\nba_api\stats\endpoints\boxscoreadvancedv2.py:123, in BoxScoreAdvancedV2.get_request(self)
#     115 def get_request(self):
# ...

# %%
bs_adv = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=21000400)
check = bs_adv.get_data_frames()[1]
check
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bs_adv = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=21000400)
#       2 check = bs_adv.get_data_frames()[1]
#       3 check
#
# File ~\Documents\Capstone\sports_betting\james\spam_data\.venv\lib\site-packages\nba_api\stats\endpoints\boxscoreadvancedv2.py:113, in BoxScoreAdvancedV2.__init__(self, game_id, end_period, end_range, range_type, start_period, start_range, proxy, headers, timeout, get_request)
#     104 self.parameters = {
#     105     "GameID": game_id,
#     106     "EndPeriod": end_period,
#    (...)
#     110     "StartRange": start_range,
#     111 }
#     112 if get_request:
# --> 113     self.get_request()
#
# File ~\Documents\Capstone\sports_betting\james\spam_data\.venv\lib\site-packages\nba_api\stats\endpoints\boxscoreadvancedv2.py:123, in BoxScoreAdvancedV2.get_request(self)
# ...

# %%
print(ids3)
# Out:
# [22300821, 22300804, 22300777, 22300763, 22300754, 22300742, 22300729, 22300716, 22300699, 22300690, 22300669, 22300653, 22300634, 22300626, 22300613, 22300595, 22300587, 22300570, 22300559, 22300543, 22300533, 22300521, 22300499, 22300480, 22300467, 22300445, 22300431, 22300408, 22300393, 22300384, 22300371, 22300352, 22300336, 22300330, 22300313, 22300296, 22301218, 22301209, 22300286, 22300272, 22300055, 22300246, 22300241, 22300227, 22300039, 22300029, 22300193, 22300018, 22300175, 22300172, 22300155, 22300135, 22300117, 22300104, 22300097, 22300079, 22300063, 1522300074, 1522300046, 1522300038, 1522300023, 1522300007, 22300816, 22300797, 22300780, 22300771, 22300759, 22300743, 22300729, 22300706, 22300684, 22300670, 22300659, 22300646, 22300630, 22300611, 22300603, 22300586, 22300571, 22300563, 22300542, 22300528, 22300517, 22300507, 22300493, 22300479, 22300462, 22300448, 22300432, 22300421, 22300403, 22300389, 22300373, 22300362, 22300344, 22300329, 22300319, 22300305, 2230122
# ...

# %%
adv_test(ids3)
# Out:
# 22300821
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 adv_test(ids3)
#
# Cell In[7], line 15, in adv_test(game_id_list)
#      13 print(id)
#      14 # query for games
# ---> 15 games = boxscoreadvancedv3.BoxScoreAdvancedV3(game_id=id)
#      16 print(games)
#      17 print(dir(games))
#
# File ~\Documents\Capstone\sports_betting\james\spam_data\.venv\lib\site-packages\nba_api\stats\endpoints\boxscoreadvancedv3.py:120, in BoxScoreAdvancedV3.__init__(self, game_id, end_period, end_range, range_type, start_period, start_range, proxy, headers, timeout, get_request)
#     111 self.parameters = {
#     112     "GameID": game_id,
#     113     "EndPeriod": end_period,
#    (...)
#     117     "StartRange": start_range,
#     118 }
#     119 if get_request:
# --> 120     self.get_request()
#
# ...

# %%
game_df = load_or_fetch_from_cache(ALL_GAMES_BOX_SCORES)

# %%
game_df
# Out:
#         SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME   GAME_ID  \
# 0           22023  1610612737               ATL      Atlanta Hawks  22300895
# 1           22023  1610612737               ATL      Atlanta Hawks  22300889
# 2           22023  1610612737               ATL      Atlanta Hawks  22300866
# 3           22023  1610612737               ATL      Atlanta Hawks  22300851
# 4           22023  1610612737               ATL      Atlanta Hawks  22300835
# ...           ...         ...               ...                ...       ...
# 105027      21988  1610612766               CHH  Charlotte Hornets  28800062
# 105028      21988  1610612766               CHH  Charlotte Hornets  28800052
# 105029      21988  1610612766               CHH  Charlotte Hornets  28800024
# 105030      21988  1610612766               CHH  Charlotte Hornets  28800015
# 105031      21988  1610612766               CHH  Charlotte Hornets  28800008
#
# ...

# %%
game_df[game_df.SEASON_ID == 22023]
# Out:
#         SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME  \
# 0           22023  1610612737               ATL      Atlanta Hawks
# 1           22023  1610612737               ATL      Atlanta Hawks
# 2           22023  1610612737               ATL      Atlanta Hawks
# 3           22023  1610612737               ATL      Atlanta Hawks
# 4           22023  1610612737               ATL      Atlanta Hawks
# ...           ...         ...               ...                ...
# 102148      22023  1610612766               CHA  Charlotte Hornets
# 102149      22023  1610612766               CHA  Charlotte Hornets
# 102150      22023  1610612766               CHA  Charlotte Hornets
# 102151      22023  1610612766               CHA  Charlotte Hornets
# 102152      22023  1610612766               CHA  Charlotte Hornets
#
#            GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 0         22300895  2024-03-06  ATL vs. CLE  W  241  112  ...   0.750   8.0
# ...

# %%
y = game_df[game_df.SEASON_ID.isin([22023])]["GAME_ID"].tolist()

# %%
ids == y
# Out:
# True

# %%
len(ids)
# Out:
# 2038

# %%
len(y)
# Out:
# 2038

# %%
df = load_or_fetch_from_cache(BOX_SCORE_ADVANCED_STATISTICS)
# Out:
# [22300895, 22300889, 22300866, 22300851, 22300835, 22300821, 22300804, 22300777, 22300763, 22300754, 22300742, 22300729, 22300716, 22300699, 22300690, 22300669, 22300653, 22300634, 22300626, 22300613, 22300595, 22300587, 22300570, 22300559, 22300543, 22300533, 22300521, 22300499, 22300480, 22300467, 22300445, 22300431, 22300408, 22300393, 22300384, 22300371, 22300352, 22300336, 22300330, 22300313, 22300296, 22301218, 22301209, 22300286, 22300272, 22300055, 22300246, 22300241, 22300227, 22300039, 22300029, 22300193, 22300018, 22300175, 22300172, 22300155, 22300135, 22300117, 22300104, 22300097, 22300079, 22300063, 1522300074, 1522300046, 1522300038, 1522300023, 1522300007, 22201216, 22201205, 22201191, 22201182, 22201167, 22201153, 22201131, 22201115, 22201107, 22201090, 22201078, 22201065, 22201048, 22201021, 22201008, 22200999, 22200985, 22200974, 22200958, 22200947, 22200923, 22200911, 22200896, 22200876, 22200857, 22200850, 22200832, 22200818, 22200801, 22200792, 22200777, 2220076
# ...

# %%
list(range(22021, 22024))
# Out:
# [22021, 22022, 22023]

# %%
from nba_api.stats.endpoints import boxscoreadvancedv3

# %%
boxscoreadvancedv3.BoxScoreAdvancedV3(game_id=1522100003)

# %%
from spam_data.feature_engineering import build_dataset

# %%
df = build_dataset()
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games

# %%
df
# Out:
#        GAME_ID  ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# 0     22100001            NaN            NaN            NaN               NaN
# 1     22100002            NaN            NaN            NaN               NaN
# 2     22100004            NaN            NaN            NaN               NaN
# 3     22100007            NaN            NaN            NaN               NaN
# 4     22100012            NaN            NaN            NaN               NaN
# ...        ...            ...            ...            ...               ...
# 3289  22300820          108.4           42.6           92.6             0.460
# 3290  22300829          125.0           48.2           87.8             0.548
# 3291  22300830          105.2           39.4           85.0             0.465
# 3292  22300828          109.8           41.6           89.2             0.468
# 3293  22300831          125.0           47.0           90.6             0.520
#
# ...

# %%
## Testing get_games_within_seasons

# %%
a = game_stats.get_games_within_seasons(22021)["GAME_ID"].tolist()

# %%
a
# Out:
# [22300895,
#  22300889,
#  22300866,
#  22300851,
#  22300835,
#  22300821,
#  22300804,
#  22300777,
#  22300763,
#  22300754,
#  22300742,
#  22300729,
#  22300716,
#  22300699,
#  22300690,
#  22300669,
#  22300653,
#  22300634,
#  22300626,
#  22300613,
#  22300595,
#  22300587,
#  22300570,
#  22300559,
#  22300543,
#  22300533,
#  22300521,
#  22300499,
#  22300480,
#  22300467,
#  22300445,
#  22300431,
#  22300408,
#  22300393,
#  22300384,
#  22300371,
#  22300352,
#  22300336,
#  22300330,
#  22300313,
#  22300296,
#  22301218,
#  22301209,
#  22300286,
#  22300272,
#  22300055,
#  22300246,
#  22300241,
#  22300227,
#  22300039,
#  22300029,
#  22300193,
#  22300018,
#  22300175,
#  22300172,
#  22300155,
#  22300135,
#  22300117,
#  22300104,
#  22300097,
#  22300079,
#  22300063,
#  1522300074,
#  1522300046,
#  1522300038,
#  1522300023,
#  1522300007,
#  22201216,
#  22201205,
#  22201191,
#  22201182,
#  22201167,
#  22201153,
#  22201131,
#  22201115,
#  22201107,
# ...

# %%
b = list()
for s in range(22021, 22024):
    b.extend(game_stats.get_game_ids_from_season_id(s))

# %%
b
# Out:
# [22101221,
#  22101207,
#  22101192,
#  22101182,
#  22101163,
#  22100452,
#  22101143,
#  22101124,
#  22101102,
#  22101085,
#  22101081,
#  22101064,
#  22101047,
#  22101033,
#  22101021,
#  22101016,
#  22100996,
#  22100984,
#  22100968,
#  22100948,
#  22100710,
#  22100927,
#  22100906,
#  22100891,
#  22100874,
#  22100867,
#  22100856,
#  22100841,
#  22100816,
#  22100807,
#  22100790,
#  22100783,
#  22100767,
#  22100751,
#  22100737,
#  22100725,
#  22100703,
#  22100687,
#  22100670,
#  22100660,
#  22100643,
#  22100636,
#  22100621,
#  22100597,
#  22100589,
#  22100577,
#  22100560,
#  22100533,
#  22100519,
#  22100502,
#  22100488,
#  22100478,
#  22100470,
#  22100434,
#  22100418,
#  22100407,
#  22100384,
#  22100359,
#  22100350,
#  22100335,
#  22100319,
#  22100293,
#  22100285,
#  22100277,
#  22100255,
#  22100242,
#  22100215,
#  22100202,
#  22100193,
#  22100182,
#  22100156,
#  22100152,
#  22100137,
#  22100120,
#  22100113,
#  22100097,
# ...

# %%
a == b
# Out:
# False

# %%
len(a)
# Out:
# 7299

# %%
len(b)
# Out:
# 7299

# %%
list(set(a) ^ set(b))
# Out:
# []

# %%
set(a) == set(b)
# Out:
# True

# %% [markdown]
# ## LEAGUE DASH TEST

# %%
x = leaguedashteamstats.LeagueDashTeamStats(month=1, season="2021-22")

# %%
x.get_data_frames()[0]
# Out:
#        TEAM_ID               TEAM_NAME  GP  W  L  W_PCT    MIN  FGM  FGA  \
# 0   1610612737           Atlanta Hawks   6  3  3  0.500  288.0  253  562
# 1   1610612738          Boston Celtics   6  2  4  0.333  313.0  249  578
# 2   1610612751           Brooklyn Nets   7  4  3  0.571  336.0  270  586
# 3   1610612766       Charlotte Hornets   7  5  2  0.714  341.0  307  657
# 4   1610612741           Chicago Bulls   6  5  1  0.833  288.0  233  515
# 5   1610612739     Cleveland Cavaliers   7  3  4  0.429  336.0  271  607
# 6   1610612742        Dallas Mavericks   6  4  2  0.667  288.0  216  534
# 7   1610612743          Denver Nuggets   6  4  2  0.667  288.0  244  509
# 8   1610612765         Detroit Pistons   6  1  5  0.167  288.0  213  523
# 9   1610612744   Golden State Warriors   6  5  1  0.833  293.0  244  538
# 10  1610612745         Houston Rockets   6  1  5  0.167  288.0  219  515
# 11  1610612754          Indiana Pacers   7  1  6  0.143  346.0  282  627
# ...

# %%
x.get_json()
# Out:
# '{"resource": "leaguedashteamstats", "parameters": {"MeasureType": "Base", "PerMode": "Totals", "PlusMinus": "N", "PaceAdjust": "N", "Rank": "N", "LeagueID": null, "Season": "2021", "SeasonType": "Regular Season", "PORound": null, "Outcome": null, "Location": null, "Month": 12, "SeasonSegment": null, "DateFrom": null, "DateTo": null, "OpponentTeamID": 0, "VsConference": null, "VsDivision": null, "TeamID": null, "Conference": null, "Division": null, "GameSegment": null, "Period": 0, "ShotClockRange": null, "LastNGames": 0, "GameScope": null, "PlayerExperience": null, "PlayerPosition": null, "StarterBench": null, "TwoWay": null, "GameSubtype": null, "ISTRound": null}, "resultSets": [{"name": "LeagueDashTeamStats", "headers": ["TEAM_ID", "TEAM_NAME", "GP", "W", "L", "W_PCT", "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "TOV", "STL", "BLK", "BLKA", "PF", "PFD", "PTS", "PLUS_MINUS", "GP_RANK", "W_RANK", "L_RANK", "W_PCT_RA
# ...

# %% [markdown]
# ## Advanced Stats?
