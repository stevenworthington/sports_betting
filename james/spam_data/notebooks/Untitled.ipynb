# %%
# %load_ext autoreload
# %autoreload 2

# %%
import spam_data

# %%
from spam_data.api.game_stats import *

# %%
from spam_data.api.team_stats import *

# %%
df = get_games()

# %%
team = get_teams()

# %%
team
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
df
# Out:
#      SEASON_ID_AWAY  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 0             22023    1610612747                    LAL
# 2             22023    1610612756                    PHX
# 4             22023    1610612765                    DET
# 6             22023    1610612757                    POR
# 8             22023    1610612745                    HOU
# ...             ...           ...                    ...
# 1805          22023    1610612746                    LAC
# 1807          22023    1610612765                    DET
# 1808          22023    1610612766                    CHA
# 1809          22023    1610612752                    NYK
# 1811          22023    1610612754                    IND
#
#               TEAM_NAME_AWAY     GAME_ID GAME_DATE_AWAY MATCHUP_AWAY WL_AWAY  \
# 0         Los Angeles Lakers  0022300061     2023-10-24    LAL @ DEN       L
# 2               Phoenix Suns  0022300062     2023-10-24    PHX @ GSW       W
# ...

# %% [markdown]
# # Base Feature Test

# %%
from spam_data.feature_engineering import base_builder
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])

# %%
x = base_builder.reshape_box_scores_to_matchups()
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])

# %%
x.columns
# Out:
# Index(['SEASON_ID', 'HOME_TEAM_ID', 'HOME_TEAM_ABBREVIATION', 'HOME_TEAM_NAME',
#        'GAME_ID', 'GAME_DATE', 'HOME_WL', 'HOME_MIN', 'HOME_PTS', 'HOME_FGM',
#        'HOME_FGA', 'HOME_FG_PCT', 'HOME_FG3M', 'HOME_FG3A', 'HOME_FG3_PCT',
#        'HOME_FTM', 'HOME_FTA', 'HOME_FT_PCT', 'HOME_OREB', 'HOME_DREB',
#        'HOME_REB', 'HOME_AST', 'HOME_STL', 'HOME_BLK', 'HOME_TOV', 'HOME_PF',
#        'PLUS_MINUS', 'AWAY_TEAM_ID', 'AWAY_TEAM_ABBREVIATION',
#        'AWAY_TEAM_NAME', 'AWAY_WL', 'AWAY_MIN', 'AWAY_PTS', 'AWAY_FGM',
#        'AWAY_FGA', 'AWAY_FG_PCT', 'AWAY_FG3M', 'AWAY_FG3A', 'AWAY_FG3_PCT',
#        'AWAY_FTM', 'AWAY_FTA', 'AWAY_FT_PCT', 'AWAY_OREB', 'AWAY_DREB',
#        'AWAY_REB', 'AWAY_AST', 'AWAY_STL', 'AWAY_BLK', 'AWAY_TOV', 'AWAY_PF',
#        'GAME_RESULT', 'TOTAL_PTS'],
#       dtype='object')

# %%
df = base_builder.create_base_with_targets()
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])

# %%
df
# Out:
#      SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION     HOME_TEAM_NAME  \
# 0      2021-22    1610612737                    ATL      Atlanta Hawks
# 1      2021-22    1610612737                    ATL      Atlanta Hawks
# 2      2021-22    1610612737                    ATL      Atlanta Hawks
# 3      2021-22    1610612737                    ATL      Atlanta Hawks
# 4      2021-22    1610612737                    ATL      Atlanta Hawks
# ...        ...           ...                    ...                ...
# 3289   2023-24    1610612766                    CHA  Charlotte Hornets
# 3290   2023-24    1610612766                    CHA  Charlotte Hornets
# 3291   2023-24    1610612766                    CHA  Charlotte Hornets
# 3292   2023-24    1610612766                    CHA  Charlotte Hornets
# 3293   2023-24    1610612766                    CHA  Charlotte Hornets
#
#       AWAY_TEAM_ID AWAY_TEAM_ABBREVIATION         AWAY_TEAM_NAME   GAME_ID  \
# ...

# %%
base_columns = ["SEASON_ID", "TEAM_ID", "TEAM_ABBREVIATION", "TEAM_NAME", "GAME_ID", "GAME_DATE", "MATCHUP", "WL", "MIN", ""]

# %%
df.columns
# Out:
# Index(['SEASON_ID', 'HOME_TEAM_ID', 'HOME_TEAM_ABBREVIATION', 'HOME_TEAM_NAME',
#        'AWAY_TEAM_ID', 'AWAY_TEAM_ABBREVIATION', 'AWAY_TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'HOME_PTS', 'AWAY_PTS', 'GAME_RESULT', 'TOTAL_PTS',
#        'PLUS_MINUS'],
#       dtype='object')

# %%
df.head()
# Out:
#   SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION HOME_TEAM_NAME  AWAY_TEAM_ID  \
# 0   2021-22    1610612737                    ATL  Atlanta Hawks    1610612764
# 1   2021-22    1610612737                    ATL  Atlanta Hawks    1610612751
# 2   2021-22    1610612737                    ATL  Atlanta Hawks    1610612739
# 3   2021-22    1610612737                    ATL  Atlanta Hawks    1610612744
# 4   2021-22    1610612737                    ATL  Atlanta Hawks    1610612740
#
#   AWAY_TEAM_ABBREVIATION         AWAY_TEAM_NAME   GAME_ID  GAME_DATE  \
# 0                    WAS     Washington Wizards  22101192 2022-04-06
# 1                    BKN          Brooklyn Nets  22101163 2022-04-02
# 2                    CLE    Cleveland Cavaliers  22100452 2022-03-31
# 3                    GSW  Golden State Warriors  22101102 2022-03-25
# 4                    NOP   New Orleans Pelicans  22101064 2022-03-20
#
#    HOME_PTS  AWAY_PTS  GAME_RESULT  TOTAL_PTS  PLUS_MINUS
# ...

# %%
df
# Out:
#      SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION     HOME_TEAM_NAME  \
# 0      2021-22    1610612737                    ATL      Atlanta Hawks
# 1      2021-22    1610612737                    ATL      Atlanta Hawks
# 2      2021-22    1610612737                    ATL      Atlanta Hawks
# 3      2021-22    1610612737                    ATL      Atlanta Hawks
# 4      2021-22    1610612737                    ATL      Atlanta Hawks
# ...        ...           ...                    ...                ...
# 3289   2023-24    1610612766                    CHA  Charlotte Hornets
# 3290   2023-24    1610612766                    CHA  Charlotte Hornets
# 3291   2023-24    1610612766                    CHA  Charlotte Hornets
# 3292   2023-24    1610612766                    CHA  Charlotte Hornets
# 3293   2023-24    1610612766                    CHA  Charlotte Hornets
#
#       AWAY_TEAM_ID AWAY_TEAM_ABBREVIATION         AWAY_TEAM_NAME   GAME_ID  \
# ...

# %%
df = base_builder.create_base_with_targets()
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])

# %%
df
# Out:
#      SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION     HOME_TEAM_NAME  \
# 0      2021-22    1610612737                    ATL      Atlanta Hawks
# 1      2021-22    1610612737                    ATL      Atlanta Hawks
# 2      2021-22    1610612737                    ATL      Atlanta Hawks
# 3      2021-22    1610612737                    ATL      Atlanta Hawks
# 4      2021-22    1610612737                    ATL      Atlanta Hawks
# ...        ...           ...                    ...                ...
# 3289   2023-24    1610612766                    CHA  Charlotte Hornets
# 3290   2023-24    1610612766                    CHA  Charlotte Hornets
# 3291   2023-24    1610612766                    CHA  Charlotte Hornets
# 3292   2023-24    1610612766                    CHA  Charlotte Hornets
# 3293   2023-24    1610612766                    CHA  Charlotte Hornets
#
#       AWAY_TEAM_ID AWAY_TEAM_ABBREVIATION         AWAY_TEAM_NAME   GAME_ID  \
# ...

# %%
df.
# Out:
#   Cell In[20], line 1
#     df.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Feature Group Merging

# %%
from spam_data.feature_engineering.box_score_feature_group import *

# %%
rw = FixedRollingWindow()
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])

# %%
rwdf = rw.process_data()

# %%
rwdf.dtypes
# Out:
# ROLL_HOME_PTS        float64
# ROLL_HOME_FGM        float64
# ROLL_HOME_FGA        float64
# ROLL_HOME_FG_PCT     float64
# ROLL_HOME_FG3M       float64
# ROLL_HOME_FG3A       float64
# ROLL_HOME_FG3_PCT    float64
# ROLL_HOME_FTM        float64
# ROLL_HOME_FTA        float64
# ROLL_HOME_FT_PCT     float64
# ROLL_HOME_OREB       float64
# ROLL_HOME_DREB       float64
# ROLL_HOME_REB        float64
# ROLL_HOME_AST        float64
# ROLL_HOME_STL        float64
# ROLL_HOME_BLK        float64
# ROLL_HOME_TOV        float64
# ROLL_HOME_PF         float64
# ROLL_AWAY_PTS        float64
# ROLL_AWAY_FGM        float64
# ROLL_AWAY_FGA        float64
# ROLL_AWAY_FG_PCT     float64
# ROLL_AWAY_FG3M       float64
# ROLL_AWAY_FG3A       float64
# ROLL_AWAY_FG3_PCT    float64
# ROLL_AWAY_FTM        float64
# ROLL_AWAY_FTA        float64
# ROLL_AWAY_FT_PCT     float64
# ROLL_AWAY_OREB       float64
# ROLL_AWAY_DREB       float64
# ROLL_AWAY_REB        float64
# ROLL_AWAY_AST        float64
# ...

# %%
df.dtypes
# Out:
# SEASON_ID                         object
# HOME_TEAM_ID                       int64
# HOME_TEAM_ABBREVIATION            object
# HOME_TEAM_NAME                    object
# AWAY_TEAM_ID                       int64
# AWAY_TEAM_ABBREVIATION            object
# AWAY_TEAM_NAME                    object
# GAME_ID                            int64
# GAME_DATE                 datetime64[ns]
# HOME_PTS                           int64
# AWAY_PTS                           int64
# GAME_RESULT                        int64
# TOTAL_PTS                          int64
# PLUS_MINUS                       float64
# dtype: object

# %%
rwdf[rwdf["GAME_ID"] == 22300017]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Capstone\sports_betting\james\spam_data\.venv\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GAME_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ...

# %%
df.set_index("GAME_ID")
# Out:
#          SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION     HOME_TEAM_NAME  \
# GAME_ID
# 22101192   2021-22    1610612737                    ATL      Atlanta Hawks
# 22101163   2021-22    1610612737                    ATL      Atlanta Hawks
# 22100452   2021-22    1610612737                    ATL      Atlanta Hawks
# 22101102   2021-22    1610612737                    ATL      Atlanta Hawks
# 22101064   2021-22    1610612737                    ATL      Atlanta Hawks
# ...            ...           ...                    ...                ...
# 22300017   2023-24    1610612766                    CHA  Charlotte Hornets
# 22300157   2023-24    1610612766                    CHA  Charlotte Hornets
# 22300101   2023-24    1610612766                    CHA  Charlotte Hornets
# 22300077   2023-24    1610612766                    CHA  Charlotte Hornets
# 22300063   2023-24    1610612766                    CHA  Charlotte Hornets
#
# ...

# %%
x = rw.merge_data_to_base(df)

# %%
x
# Out:
#           ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# GAME_ID
# 22100001            NaN            NaN            NaN               NaN
# 22100002            NaN            NaN            NaN               NaN
# 22100004            NaN            NaN            NaN               NaN
# 22100007            NaN            NaN            NaN               NaN
# 22100012            NaN            NaN            NaN               NaN
# ...                 ...            ...            ...               ...
# 22300820          108.4           42.6           92.6             0.460
# 22300829          125.0           48.2           87.8             0.548
# 22300830          105.2           39.4           85.0             0.465
# 22300828          109.8           41.6           89.2             0.468
# 22300831          125.0           47.0           90.6             0.520
#
#           ROLL_HOME_FG3M  ROLL_HOME_FG3A  ROLL_HOME_FG3_PCT  ROLL_HOME_FTM  \
# GAME_ID
# ...

# %%
rw.df.join(df.set_index("GAME_ID"))
# Out:
#        GAME_ID  ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# 525   22100001            NaN            NaN            NaN               NaN
# 444   22100002            NaN            NaN            NaN               NaN
# 1180  22100004            NaN            NaN            NaN               NaN
# 1098  22100007            NaN            NaN            NaN               NaN
# 812   22100012            NaN            NaN            NaN               NaN
# ...        ...            ...            ...            ...               ...
# 3210  22300820          108.4           42.6           92.6             0.460
# 2925  22300829          125.0           48.2           87.8             0.548
# 3181  22300830          105.2           39.4           85.0             0.465
# 2871  22300828          109.8           41.6           89.2             0.468
# 3044  22300831          125.0           47.0           90.6             0.520
#
# ...

# %%
df
# Out:
#      SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION     HOME_TEAM_NAME  \
# 0      2021-22    1610612737                    ATL      Atlanta Hawks
# 1      2021-22    1610612737                    ATL      Atlanta Hawks
# 2      2021-22    1610612737                    ATL      Atlanta Hawks
# 3      2021-22    1610612737                    ATL      Atlanta Hawks
# 4      2021-22    1610612737                    ATL      Atlanta Hawks
# ...        ...           ...                    ...                ...
# 3289   2023-24    1610612766                    CHA  Charlotte Hornets
# 3290   2023-24    1610612766                    CHA  Charlotte Hornets
# 3291   2023-24    1610612766                    CHA  Charlotte Hornets
# 3292   2023-24    1610612766                    CHA  Charlotte Hornets
# 3293   2023-24    1610612766                    CHA  Charlotte Hornets
#
#       AWAY_TEAM_ID AWAY_TEAM_ABBREVIATION         AWAY_TEAM_NAME   GAME_ID  \
# ...

# %%
rwdf
# Out:
#        GAME_ID  ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# 525   22100001            NaN            NaN            NaN               NaN
# 444   22100002            NaN            NaN            NaN               NaN
# 1180  22100004            NaN            NaN            NaN               NaN
# 1098  22100007            NaN            NaN            NaN               NaN
# 812   22100012            NaN            NaN            NaN               NaN
# ...        ...            ...            ...            ...               ...
# 3210  22300820          108.4           42.6           92.6             0.460
# 2925  22300829          125.0           48.2           87.8             0.548
# 3181  22300830          105.2           39.4           85.0             0.465
# 2871  22300828          109.8           41.6           89.2             0.468
# 3044  22300831          125.0           47.0           90.6             0.520
#
# ...

# %%
rwdf.set_index("GAME_ID").join(df.set_index("GAME_ID"))
# Out:
#           ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# GAME_ID
# 22100001            NaN            NaN            NaN               NaN
# 22100002            NaN            NaN            NaN               NaN
# 22100004            NaN            NaN            NaN               NaN
# 22100007            NaN            NaN            NaN               NaN
# 22100012            NaN            NaN            NaN               NaN
# ...                 ...            ...            ...               ...
# 22300820          108.4           42.6           92.6             0.460
# 22300829          125.0           48.2           87.8             0.548
# 22300830          105.2           39.4           85.0             0.465
# 22300828          109.8           41.6           89.2             0.468
# 22300831          125.0           47.0           90.6             0.520
#
#           ROLL_HOME_FG3M  ROLL_HOME_FG3A  ROLL_HOME_FG3_PCT  ROLL_HOME_FTM  \
# GAME_ID
# ...

# %%
x
# Out:
#        GAME_ID  ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# 525   22100001            NaN            NaN            NaN               NaN
# 444   22100002            NaN            NaN            NaN               NaN
# 1180  22100004            NaN            NaN            NaN               NaN
# 1098  22100007            NaN            NaN            NaN               NaN
# 812   22100012            NaN            NaN            NaN               NaN
# ...        ...            ...            ...            ...               ...
# 3210  22300820          108.4           42.6           92.6             0.460
# 2925  22300829          125.0           48.2           87.8             0.548
# 3181  22300830          105.2           39.4           85.0             0.465
# 2871  22300828          109.8           41.6           89.2             0.468
# 3044  22300831          125.0           47.0           90.6             0.520
#
# ...

# %%
rwdf = rw.process_data(

# %%
rwdf

# %%
rwdf.columns

# %%
df.columns

# %%
df.head()

# %%
rwdf.head()

# %% [markdown]
# ## FE TOP

# %%
from spam_data.feature_engineering.box_score_ratios_feature_group import BoxScoreRatios
from spam_data.feature_engineering.box_score_feature_group import FixedRollingWindow
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])

# %%
from spam_data.feature_engineering import build_dataset

# %%
df = build_dataset([BoxScoreRatios(), FixedRollingWindow()])
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# ...

# %%
df.head()
# Out:
#      GAME_ID  ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# 26  22100032          123.0           49.0           98.0             0.500
# 27  22100033          121.0           45.0           93.0             0.484
# 29  22100029           83.0           30.0           97.0             0.309
# 32  22100031          124.0           42.0           87.0             0.483
# 35  22100037          124.0           48.0           95.0             0.505
#
#     ROLL_HOME_FG3M  ROLL_HOME_FG3A  ROLL_HOME_FG3_PCT  ROLL_HOME_FTM  \
# 26            13.0            30.0              0.433           12.0
# 27            12.0            35.0              0.343           19.0
# 29             7.0            34.0              0.206           16.0
# 32            16.0            38.0              0.421           24.0
# 35            17.0            38.0              0.447           11.0
#
#     ROLL_HOME_FTA  ...          HOME_TEAM_NAME  AWAY_TEAM_ID  \
# ...

# %%
df.columns
# Out:
# Index(['GAME_ID', 'ROLL_HOME_PTS', 'ROLL_HOME_FGM', 'ROLL_HOME_FGA',
#        'ROLL_HOME_FG_PCT', 'ROLL_HOME_FG3M', 'ROLL_HOME_FG3A',
#        'ROLL_HOME_FG3_PCT', 'ROLL_HOME_FTM', 'ROLL_HOME_FTA',
#        'ROLL_HOME_FT_PCT', 'ROLL_HOME_OREB', 'ROLL_HOME_DREB', 'ROLL_HOME_REB',
#        'ROLL_HOME_AST', 'ROLL_HOME_STL', 'ROLL_HOME_BLK', 'ROLL_HOME_TOV',
#        'ROLL_HOME_PF', 'ROLL_AWAY_PTS', 'ROLL_AWAY_FGM', 'ROLL_AWAY_FGA',
#        'ROLL_AWAY_FG_PCT', 'ROLL_AWAY_FG3M', 'ROLL_AWAY_FG3A',
#        'ROLL_AWAY_FG3_PCT', 'ROLL_AWAY_FTM', 'ROLL_AWAY_FTA',
#        'ROLL_AWAY_FT_PCT', 'ROLL_AWAY_OREB', 'ROLL_AWAY_DREB', 'ROLL_AWAY_REB',
#        'ROLL_AWAY_AST', 'ROLL_AWAY_STL', 'ROLL_AWAY_BLK', 'ROLL_AWAY_TOV',
#        'ROLL_AWAY_PF', 'ROLL_HOME_3A_RATE',
#        'ROLL_HOME_ASSIST_TO_TURNOVER_RATE', 'ROLL_HOME_OTOD_REBRATE',
#        'ROLL_AWAY_3A_RATE', 'ROLL_AWAY_ASSIST_TO_TURNOVER_RATE',
#        'ROLL_AWAY_OTOD_REBRATE', 'index', 'SEASON_ID', 'HOME_TEAM_ID',
# ...

# %%
fe = BoxScoreRatios()

# %%
fe.process_data()
# Out:
#           ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT  \
# GAME_ID
# 22100032          123.0           49.0           98.0             0.500
# 22100033          121.0           45.0           93.0             0.484
# 22100029           83.0           30.0           97.0             0.309
# 22100031          124.0           42.0           87.0             0.483
# 22100037          124.0           48.0           95.0             0.505
#
#           ROLL_HOME_FG3M  ROLL_HOME_FG3A  ROLL_HOME_FG3_PCT  ROLL_HOME_FTM  \
# GAME_ID
# 22100032            13.0            30.0              0.433           12.0
# 22100033            12.0            35.0              0.343           19.0
# 22100029             7.0            34.0              0.206           16.0
# 22100031            16.0            38.0              0.421           24.0
# 22100037            17.0            38.0              0.447           11.0
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
