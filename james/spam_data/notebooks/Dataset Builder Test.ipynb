# %%
# %load_ext autoreload
# %autoreload 2

# %%
from spam_data.feature_engineering import *

# %%
# df = build_dataset([FixedRollingWindow(), BoxScoreRatios(), PrevMonthAdvancedStatsFeatureGroup()])
df = build_dataset([FixedRollingWindow(), BoxScoreRatios(), PrevMonthAdvancedStatsFeatureGroup(), LastMatchupFeatureGroup()])
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# ...

# %%
df.head()
# Out:
#     GAME_ID  LAST_MATCHUP_PTS  LAST_MATCHUP_WINNER  level_0  \
# 0  22101192               231                    1   1088.0
# 1  22101163               218                    0   1061.0
# 2  22100452               240                    1   1045.0
# 3  22101102               240                    0   1001.0
# 4  22101064               201                    1    966.0
#
#    ROLL_HOME_3A_RATE  ROLL_HOME_ASSIST_TO_TURNOVER_RATE  \
# 0           0.398649                           2.440000
# 1           0.394004                           2.750000
# 2           0.397826                           2.588235
# 3           0.383948                           2.660000
# 4           0.403930                           3.512821
#
#    ROLL_HOME_OTOD_REBRATE  ROLL_AWAY_3A_RATE  \
# 0                0.269663           0.334086
# 1                0.331325           0.371230
# 2                0.331210           0.330952
# 3                0.350318           0.427907
# ...

# %%
df[["LAST_MATCHUP_PTS"]]
# Out:
#       LAST_MATCHUP_PTS
# 0                  231
# 1                  218
# 2                  240
# 3                  240
# 4                  201
# ...                ...
# 2851               243
# 2852               236
# 2853               239
# 2854               211
# 2855               222
#
# [2696 rows x 1 columns]

# %%
for item in df.columns:
    print(item)
# Out:
# level_0
# GAME_ID
# ROLL_HOME_3A_RATE
# ROLL_HOME_ASSIST_TO_TURNOVER_RATE
# ROLL_HOME_OTOD_REBRATE
# ROLL_AWAY_3A_RATE
# ROLL_AWAY_ASSIST_TO_TURNOVER_RATE
# ROLL_AWAY_OTOD_REBRATE
# ROLL_HOME_PTS
# ROLL_HOME_FGM
# ROLL_HOME_FGA
# ROLL_HOME_FG_PCT
# ROLL_HOME_FG3M
# ROLL_HOME_FG3A
# ROLL_HOME_FG3_PCT
# ROLL_HOME_FTM
# ROLL_HOME_FTA
# ROLL_HOME_FT_PCT
# ROLL_HOME_OREB
# ROLL_HOME_DREB
# ROLL_HOME_REB
# ROLL_HOME_AST
# ROLL_HOME_STL
# ROLL_HOME_BLK
# ROLL_HOME_TOV
# ROLL_HOME_PF
# ROLL_AWAY_PTS
# ROLL_AWAY_FGM
# ROLL_AWAY_FGA
# ROLL_AWAY_FG_PCT
# ROLL_AWAY_FG3M
# ROLL_AWAY_FG3A
# ROLL_AWAY_FG3_PCT
# ROLL_AWAY_FTM
# ROLL_AWAY_FTA
# ROLL_AWAY_FT_PCT
# ROLL_AWAY_OREB
# ROLL_AWAY_DREB
# ROLL_AWAY_REB
# ROLL_AWAY_AST
# ROLL_AWAY_STL
# ROLL_AWAY_BLK
# ROLL_AWAY_TOV
# ROLL_AWAY_PF
# index
# SEASON_ID
# HOME_TEAM_ID
# HOME_TEAM_ABBREVIATION
# HOME_TEAM_NAME
# AWAY_TEAM_ID
# AWAY_TEAM_ABBREVIATION
# AWAY_TEAM_NAME
# GAME_DATE
# HOME_PTS
# AWAY_PTS
# GAME_RESULT
# TOTAL_PTS
# PLUS_MINUS
# MONTH
# ...

# %%
df.head()
# Out:
#    level_0   GAME_ID  ROLL_HOME_3A_RATE  ROLL_HOME_ASSIST_TO_TURNOVER_RATE  \
# 0        0  22100094           0.391303                           3.033300
# 1        1  22100099           0.445204                           1.731689
# 2        2  22100095           0.440296                           1.222222
# 3        3  22100096           0.399215                           1.575039
# 4        4  22100101           0.461326                           1.308824
#
#    ROLL_HOME_OTOD_REBRATE  ROLL_AWAY_3A_RATE  \
# 0                0.339626           0.370968
# 1                0.310342           0.348958
# 2                0.314806           0.318348
# 3                0.156853           0.500000
# 4                0.406250           0.424242
#
#    ROLL_AWAY_ASSIST_TO_TURNOVER_RATE  ROLL_AWAY_OTOD_REBRATE  ROLL_HOME_PTS  \
# 0                           1.602564                0.347305        125.667
# 1                           1.538462                0.440000        118.000
# ...

# %%
df["GAME_ID"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Capstone\sports_betting\james\spam_data\.venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GAME_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df["GAME_ID"]
#
# ...

# %%
df.GAME_ID
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7428\747474592.py in ?()
# ----> 1 df.GAME_ID
#
# ~\Documents\Capstone\sports_betting\james\spam_data\.venv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'GAME_ID'

# %%
df = build_dataset([FixedRollingWindow(), BoxScoreRatios(), PrevMonthAdvancedStatsFeatureGroup(), LastMatchupFeatureGroup()])
# Out:
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# C:\Users\james\Documents\Capstone\sports_betting\james\spam_data\spam_data\feature_engineering\utility_functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
# ...

# %%
df

# %%
df = build_dataset([PrevMonthAdvancedStatsFeatureGroup()])
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 860 games
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 851 games
# Index(['SEASON_ID', 'HOME_TEAM_ID', 'HOME_TEAM_ABBREVIATION', 'HOME_TEAM_NAME',
#        'AWAY_TEAM_ID', 'AWAY_TEAM_ABBREVIATION', 'AWAY_TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'HOME_PTS', 'AWAY_PTS', 'GAME_RESULT', 'TOTAL_PTS',
#        'PLUS_MINUS', 'MONTH', 'PREV_MONTH', 'TEAM_ID', 'E_OFF_RATING',
#        'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING', 'E_NET_RATING',
#        'NET_RATING', 'AST_PCT', 'AST_TO', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT',
#        'REB_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'E_PACE', 'PACE',
#        'PACE_PER40', 'POSS', 'PIE', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'OFF_RATING_RANK', 'DEF_RATING_RANK',
#        'NET_RATING_RANK', 'AST_PCT_RANK', 'AST_TO_RANK', 'AST_RATIO_RANK',
# ...

# %%
df.columns
# Out:
# Index(['index', 'SEASON_ID', 'HOME_TEAM_ID', 'HOME_TEAM_ABBREVIATION',
#        'HOME_TEAM_NAME', 'AWAY_TEAM_ID', 'AWAY_TEAM_ABBREVIATION',
#        'AWAY_TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'HOME_PTS', 'AWAY_PTS',
#        'GAME_RESULT', 'TOTAL_PTS', 'PLUS_MINUS', 'MONTH', 'PREV_MONTH',
#        'HOME_E_OFF_RATING', 'HOME_OFF_RATING', 'HOME_E_DEF_RATING',
#        'HOME_DEF_RATING', 'HOME_E_NET_RATING', 'HOME_NET_RATING',
#        'HOME_AST_PCT', 'HOME_AST_TO', 'HOME_AST_RATIO', 'HOME_OREB_PCT',
#        'HOME_DREB_PCT', 'HOME_REB_PCT', 'HOME_TM_TOV_PCT', 'HOME_EFG_PCT',
#        'HOME_TS_PCT', 'HOME_E_PACE', 'HOME_PACE', 'HOME_PACE_PER40',
#        'HOME_POSS', 'HOME_PIE', 'HOME_GP_RANK', 'HOME_W_RANK', 'HOME_L_RANK',
#        'HOME_W_PCT_RANK', 'HOME_MIN_RANK', 'HOME_OFF_RATING_RANK',
#        'HOME_DEF_RATING_RANK', 'HOME_NET_RATING_RANK', 'HOME_AST_PCT_RANK',
#        'HOME_AST_TO_RANK', 'HOME_AST_RATIO_RANK', 'HOME_OREB_PCT_RANK',
# ...

# %%
df.shape
# Out:
# (3046, 137)

# %%
df[["HOME_E_OFF_RATING", "HOME_OFF_RATING"]]
# Out:
#       HOME_E_OFF_RATING  HOME_OFF_RATING
# 0                 117.8            119.1
# 1                 117.8            119.1
# 2                 115.5            117.5
# 3                 115.5            117.5
# 4                 115.5            117.5
# ...                 ...              ...
# 3043              104.6            106.0
# 3044              104.6            106.0
# 3045              104.6            106.0
# 3046              104.6            106.0
# 3047              104.6            106.0
#
# [3048 rows x 2 columns]
