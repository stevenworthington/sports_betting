# %% [markdown]
# <div class="alert alert-danger">
#     <h4 style="font-weight: bold; font-size: 28px;">Feature Selection using Filter Methods</h4>
#     <p style="font-size: 20px;">NBA API Data (2022-2024)</p>
# </div>
#
# <a name="Feature-Selection"></a>

# %% [markdown]
# # Table of Contents

# %% [markdown]
# [Setup](#Setup)
#
# [Data](#Data)
#
# **[1. Filter Methods for Total Points](#1.-Filter-Methods-for-Total-Points)**
#
# - [1.1. Correlation Based](#1.1.-Correlation-Based)
#
# - [1.2. `vtreat` Library](#1.2.-vtreat-Library)
#
# **[2. Filter Methods for Plus Minus](#2.-Filter-Methods-for-Plus-Minus)**
#
# - [2.1. Correlation Based](#2.1.-Correlation-Based)
#
# - [2.2. `vtreat` Library](#2.2.-vtreat-Library)
#
# **[3. Filter Methods for Game Winner](#3.-Filter-Methods-for-Game-Winner)**
#
# - [2.1. Correlation Based](#2.1.-Correlation-Based)
#
# - [2.2. `vtreat` Library](#2.2.-vtreat-Library)

# %% [markdown]
# # Setup
#
# [Return to top](#Feature-Selection)

# %%
import sys
from pathlib import Path
# get current working directory
cwd = %pwd
# add shared_code directory to Python sys.path
sys.path.append(str(Path(cwd).parent / "shared_code"))
# import all libraries in shared_code directory 'imports.py' file
from imports import *
# %matplotlib inline
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# # Data
#
# [Return to top](#Feature-Selection)

# %%
# load all the rolling data
boxscores = pd.read_csv('../../data/processed/nba_team_matchups_rolling_box_scores_2022_2024_r05.csv')
opponent = pd.read_csv('../../data/processed/nba_team_matchups_rolling_opponent_impact_box_scores_2022_2024_r05.csv')
advanced = pd.read_csv('../../data/processed/nba_team_matchups_rolling_adv_stats_2021_2024_r05.csv')
hustle = pd.read_csv('../../data/processed/nba_team_matchups_rolling_hustle_stats_2021_2024_r05.csv')
miscbox = pd.read_csv('../../data/processed/nba_team_matchups_rolling_misc_box_stats_2021_2024_r05.csv')
factor = pd.read_csv('../../data/processed/nba_team_matchups_rolling_four_factor_stats_2021_2024_r05.csv')
scoring = pd.read_csv('../../data/processed/nba_team_matchups_rolling_scoring_box_stats_2021_2024_r05.csv')
track = pd.read_csv('../../data/processed/nba_team_matchups_rolling_player_track_box_stats_2021_2024_r05.csv')

# %%
# merge all the features
cols_to_drop = ['GAME_RESULT', 'TOTAL_PTS', 'PLUS_MINUS', 'HOME_TEAM_NAME',
                'SEASON_ID', 'GAME_DATE', 'AWAY_TEAM_NAME', 'ROLL_HOME_PTS', 'ROLL_AWAY_PTS']

features_df = boxscores.merge(opponent.drop([col for col in cols_to_drop if col in opponent.columns], axis=1), how='left', on='GAME_ID')
features_df = features_df.merge(advanced.drop([col for col in cols_to_drop if col in advanced.columns], axis=1), how='left', on='GAME_ID')
features_df = features_df.merge(hustle.drop([col for col in cols_to_drop if col in hustle.columns], axis=1), how='left', on='GAME_ID')
features_df = features_df.merge(miscbox.drop([col for col in cols_to_drop if col in miscbox.columns], axis=1), how='left', on='GAME_ID')
features_df = features_df.merge(factor.drop([col for col in cols_to_drop if col in factor.columns], axis=1), how='left', on='GAME_ID')
features_df = features_df.merge(scoring.drop([col for col in cols_to_drop if col in scoring.columns], axis=1), how='left', on='GAME_ID')
features_df = features_df.merge(track.drop([col for col in cols_to_drop if col in track.columns], axis=1), how='left', on='GAME_ID')

print(features_df.shape)
features_df.head()
# Out:
# (3172, 264)
#     GAME_ID  GAME_RESULT  TOTAL_PTS  PLUS_MINUS          HOME_TEAM_NAME  \
# 0  22100002            0        235        -7.0      Los Angeles Lakers
# 1  22100001            1        231        23.0         Milwaukee Bucks
# 2  22100007            1        253        11.0       Memphis Grizzlies
# 3  22100008            1        230        18.0  Minnesota Timberwolves
# 4  22100009            0        214       -20.0    New Orleans Pelicans
#
#   SEASON_ID   GAME_DATE  ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  \
# 0   2021-22  2021-10-19            NaN            NaN            NaN
# 1   2021-22  2021-10-19            NaN            NaN            NaN
# 2   2021-22  2021-10-20            NaN            NaN            NaN
# 3   2021-22  2021-10-20            NaN            NaN            NaN
# 4   2021-22  2021-10-20            NaN            NaN            NaN
#
#    ROLL_HOME_FG_PCT_x  ROLL_HOME_FG3M  ROLL_HOME_FG3A  ROLL_HOME_FG3_PCT  \
# 0                 NaN             NaN             NaN                NaN
# 1                 NaN             NaN             NaN                NaN
# 2                 NaN             NaN             NaN                NaN
# 3                 NaN             NaN             NaN                NaN
# 4                 NaN             NaN             NaN                NaN
#
#    ROLL_HOME_FTM  ROLL_HOME_FTA  ROLL_HOME_FT_PCT  ROLL_HOME_OREB  \
# 0            NaN            NaN               NaN             NaN
# 1            NaN            NaN               NaN             NaN
# 2            NaN            NaN               NaN             NaN
# 3            NaN            NaN               NaN             NaN
# 4            NaN            NaN               NaN             NaN
#
#    ROLL_HOME_DREB  ROLL_HOME_REB  ROLL_HOME_AST_x  ROLL_HOME_STL  \
# 0             NaN            NaN              NaN            NaN
# 1             NaN            NaN              NaN            NaN
# 2             NaN            NaN              NaN            NaN
# 3             NaN            NaN              NaN            NaN
# 4             NaN            NaN              NaN            NaN
#
#    ROLL_HOME_BLK_x  ROLL_HOME_TOV  ROLL_HOME_PF_x  ... ROLL_HOME_UFGA  \
# 0              NaN            NaN             NaN  ...            NaN
# 1              NaN            NaN             NaN  ...            NaN
# 2              NaN            NaN             NaN  ...            NaN
# 3              NaN            NaN             NaN  ...            NaN
# 4              NaN            NaN             NaN  ...            NaN
#
#    ROLL_HOME_UFG_PCT  ROLL_HOME_FG_PCT_y  ROLL_HOME_DFGM  ROLL_HOME_DFGA  \
# 0                NaN                 NaN             NaN             NaN
# 1                NaN                 NaN             NaN             NaN
# 2                NaN                 NaN             NaN             NaN
# 3                NaN                 NaN             NaN             NaN
# 4                NaN                 NaN             NaN             NaN
#
#    ROLL_HOME_DFG_PCT  ROLL_AWAY_DIST  ROLL_AWAY_ORBC  ROLL_AWAY_DRBC  \
# 0                NaN             NaN             NaN             NaN
# 1                NaN             NaN             NaN             NaN
# 2                NaN             NaN             NaN             NaN
# 3                NaN             NaN             NaN             NaN
# 4                NaN             NaN             NaN             NaN
#
#    ROLL_AWAY_RBC  ROLL_AWAY_TCHS  ROLL_AWAY_SAST  ROLL_AWAY_FTAST  \
# 0            NaN             NaN             NaN              NaN
# 1            NaN             NaN             NaN              NaN
# 2            NaN             NaN             NaN              NaN
# 3            NaN             NaN             NaN              NaN
# 4            NaN             NaN             NaN              NaN
#
#    ROLL_AWAY_PASS  ROLL_AWAY_AST_y  ROLL_AWAY_CFGM  ROLL_AWAY_CFGA  \
# 0             NaN              NaN             NaN             NaN
# 1             NaN              NaN             NaN             NaN
# 2             NaN              NaN             NaN             NaN
# 3             NaN              NaN             NaN             NaN
# 4             NaN              NaN             NaN             NaN
#
#    ROLL_AWAY_CFG_PCT  ROLL_AWAY_UFGM  ROLL_AWAY_UFGA  ROLL_AWAY_UFG_PCT  \
# 0                NaN             NaN             NaN                NaN
# 1                NaN             NaN             NaN                NaN
# 2                NaN             NaN             NaN                NaN
# 3                NaN             NaN             NaN                NaN
# 4                NaN             NaN             NaN                NaN
#
#    ROLL_AWAY_FG_PCT_y  ROLL_AWAY_DFGM  ROLL_AWAY_DFGA  ROLL_AWAY_DFG_PCT
# 0                 NaN             NaN             NaN                NaN
# 1                 NaN             NaN             NaN                NaN
# 2                 NaN             NaN             NaN                NaN
# 3                 NaN             NaN             NaN                NaN
# 4                 NaN             NaN             NaN                NaN
#
# [5 rows x 264 columns]

# %%
# load, filter (by time) and scale data
pts_features, pm_features, res_features, test_set_obs = utl.load_and_scale_data(
    input_data=features_df,
    seasons_to_keep=['2021-22', '2022-23', '2023-24'],
    training_season='2021-22',
    feature_prefixes=['ROLL_', 'ROLLDIFF_'],
    scaler_type='minmax', 
    scale_target=False
)
# Out:
# Season 2021-22: 1186 games
# Season 2022-23: 1181 games
# Season 2023-24: 691 games
# Total number of games across sampled seasons: 3058 games

# %%
pts_features.head()
# Out:
#             ROLL_HOME_PTS  ROLL_HOME_FGM  ROLL_HOME_FGA  ROLL_HOME_FG_PCT_x  \
# GAME_DATE
# 2021-10-23          0.745          0.522          0.296               0.753
# 2021-10-23          0.000          0.000          0.648               0.000
# 2021-10-23          0.691          0.652          0.507               0.758
# 2021-10-23          0.727          0.826          0.683               0.827
# 2021-10-24          0.745          0.783          0.577               0.848
#
#             ROLL_HOME_FG3M  ROLL_HOME_FG3A  ROLL_HOME_FG3_PCT  ROLL_HOME_FTM  \
# GAME_DATE
# 2021-10-23           0.758           0.580              0.731          0.805
# 2021-10-23           0.076           0.412              0.000          0.466
# 2021-10-23           0.455           0.454              0.466          0.593
# 2021-10-23           0.530           0.244              0.772          0.297
# 2021-10-24           0.833           0.580              0.820          0.254
#
#             ROLL_HOME_FTA  ROLL_HOME_FT_PCT  ROLL_HOME_OREB  ROLL_HOME_DREB  \
# GAME_DATE
# 2021-10-23          0.878             0.535           0.571           0.292
# 2021-10-23          0.534             0.438           1.000           0.381
# 2021-10-23          0.534             0.720           0.286           0.602
# 2021-10-23          0.382             0.315           0.571           0.159
# 2021-10-24          0.229             0.560           0.357           0.779
#
#             ROLL_HOME_REB  ROLL_HOME_AST_x  ROLL_HOME_STL  ROLL_HOME_BLK_x  \
# GAME_DATE
# 2021-10-23          0.478            0.612          1.000            1.000
# 2021-10-23          0.826            0.000          0.420            0.273
# 2021-10-23          0.609            0.561          0.058            0.364
# 2021-10-23          0.348            0.918          0.275            0.182
# 2021-10-24          0.826            0.765          0.565            0.818
#
#             ROLL_HOME_TOV  ROLL_HOME_PF_x  ROLL_AWAY_PTS  ROLL_AWAY_FGM  \
# GAME_DATE
# 2021-10-23          0.600           0.661          0.577          0.586
# 2021-10-23          0.657           0.576          0.096          0.017
# 2021-10-23          0.257           0.661          0.635          0.586
# 2021-10-23          0.029           0.661          0.250          0.069
# 2021-10-24          0.543           0.322          1.000          0.897
#
#             ROLL_AWAY_FGA  ROLL_AWAY_FG_PCT_x  ROLL_AWAY_FG3M  ROLL_AWAY_FG3A  \
# GAME_DATE
# 2021-10-23          0.202               0.704           0.526           0.176
# 2021-10-23          0.362               0.000           0.421           0.588
# 2021-10-23          0.176               0.728           0.263           0.265
# 2021-10-23          0.122               0.225           0.368           0.559
# 2021-10-24          1.000               0.362           0.842           1.000
#
#             ROLL_AWAY_FG3_PCT  ...  ROLL_HOME_UFG_PCT  ROLL_HOME_FG_PCT_y  \
# GAME_DATE                      ...
# 2021-10-23              1.000  ...              0.761               0.753
# 2021-10-23              0.364  ...              0.000               0.000
# 2021-10-23              0.396  ...              0.676               0.758
# 2021-10-23              0.317  ...              0.712               0.827
# 2021-10-24              0.559  ...              0.850               0.848
#
#             ROLL_HOME_DFGM  ROLL_HOME_DFGA  ROLL_HOME_DFG_PCT  ROLL_AWAY_DIST  \
# GAME_DATE
# 2021-10-23           0.909           1.000              0.352           0.665
# 2021-10-23           0.909           0.655              0.762           0.619
# 2021-10-23           0.398           0.276              0.720           0.591
# 2021-10-23           0.455           0.586              0.291           0.715
# 2021-10-24           0.341           0.655              0.075           1.000
#
#             ROLL_AWAY_ORBC  ROLL_AWAY_DRBC  ROLL_AWAY_RBC  ROLL_AWAY_TCHS  \
# GAME_DATE
# 2021-10-23           0.613           0.119          0.252           0.530
# 2021-10-23           0.387           0.489          0.409           0.579
# 2021-10-23           0.032           0.744          0.370           0.660
# 2021-10-23           0.452           0.460          0.409           0.460
# 2021-10-24           0.903           0.460          0.665           1.000
#
#             ROLL_AWAY_SAST  ROLL_AWAY_FTAST  ROLL_AWAY_PASS  ROLL_AWAY_AST_y  \
# GAME_DATE
# 2021-10-23           0.250            0.714           0.531            0.500
# 2021-10-23           0.125            0.179           0.517            0.083
# 2021-10-23           0.375            0.357           0.638            0.708
# 2021-10-23           0.375            0.179           0.403            0.208
# 2021-10-24           0.875            0.536           0.859            0.833
#
#             ROLL_AWAY_CFGM  ROLL_AWAY_CFGA  ROLL_AWAY_CFG_PCT  ROLL_AWAY_UFGM  \
# GAME_DATE
# 2021-10-23           0.595           0.704              0.564           0.409
# 2021-10-23           0.000           0.458              0.000           0.364
# 2021-10-23           0.238           0.246              0.581           0.682
# 2021-10-23           0.357           0.282              0.735           0.136
# 2021-10-24           0.179           0.352              0.355           1.000
#
#             ROLL_AWAY_UFGA  ROLL_AWAY_UFG_PCT  ROLL_AWAY_FG_PCT_y  \
# GAME_DATE
# 2021-10-23           0.190              0.738               0.704
# 2021-10-23           0.453              0.301               0.000
# 2021-10-23           0.433              0.749               0.728
# 2021-10-23           0.372              0.075               0.225
# 2021-10-24           1.000              0.470               0.362
#
#             ROLL_AWAY_DFGM  ROLL_AWAY_DFGA  ROLL_AWAY_DFG_PCT  TOTAL_PTS
# GAME_DATE
# 2021-10-23           0.620           0.423              1.000        185
# 2021-10-23           0.185           0.269              0.453        198
# 2021-10-23           0.076           0.423              0.023        239
# 2021-10-23           0.511           0.346              0.965        232
# 2021-10-24           0.783           0.731              0.732        204
#
# [5 rows x 257 columns]

# %% [markdown]
# <a name="1.-Filter-Methods-for-Total-Points"></a>
# # 1. Filter Methods for Total Points
#
# [Return to top](#Feature-Selection)

# %% [markdown]
# <a name="1.1.-Correlation-Based"></a>
# ## 1.1. Correlation Based
#
# [Return to top](#Feature-Selection)

# %%
start_time = time.time()

# filter-based feature selection
pts_selection = utl.filter_feature_selection(
    df=pts_features, 
    outcome_name='TOTAL_PTS'
)

end_time = time.time()
print(f"Total time taken: {end_time - start_time:.2f} seconds")
# Out:
# {
#     "outcome_correlation": [
#         "ROLL_HOME_PTS",
#         "ROLL_HOME_FGM",
#         "ROLL_HOME_FG_PCT_x",
#         "ROLL_HOME_FTM",
#         "ROLL_HOME_FTA",
#         "ROLL_HOME_AST_x",
#         "ROLL_AWAY_PTS",
#         "ROLL_AWAY_FGM",
#         "ROLL_AWAY_FGA",
#         "ROLL_AWAY_FG_PCT_x",
#         "ROLL_AWAY_FTM",
#         "ROLL_AWAY_FTA",
#         "ROLL_AWAY_AST_x",
#         "ROLL_HOME_estimatedOffensiveRating",
#         "ROLL_HOME_offensiveRating",
#         "ROLL_HOME_estimatedDefensiveRating",
#         "ROLL_HOME_defensiveRating",
#         "ROLL_HOME_assistToTurnover",
#         "ROLL_HOME_assistRatio",
#         "ROLL_HOME_effectiveFieldGoalPercentage",
#         "ROLL_HOME_trueShootingPercentage",
#         "ROLL_HOME_estimatedPace",
#         "ROLL_AWAY_estimatedOffensiveRating",
#         "ROLL_AWAY_offensiveRating",
#         "ROLL_AWAY_estimatedDefensiveRating",
#         "ROLL_AWAY_defensiveRating",
#         "ROLL_AWAY_assistToTurnover",
#         "ROLL_AWAY_estimatedTeamTurnoverPercentage",
#         "ROLL_AWAY_turnoverRatio",
#         "ROLL_AWAY_effectiveFieldGoalPercentage",
#         "ROLL_AWAY_trueShootingPercentage",
#         "ROLL_AWAY_estimatedPace",
#         "ROLL_AWAY_pace",
#         "ROLL_AWAY_pacePer40",
#         "ROLL_AWAY_possessions",
#         "ROLL_HOME_CHARGES_DRAWN",
#         "ROLL_HOME_LOOSE_BALLS_RECOVERED",
#         "ROLL_AWAY_DEF_BOXOUTS",
#         "ROLL_AWAY_BOX_OUT_PLAYER_TEAM_REBS",
#         "ROLL_AWAY_BOX_OUTS",
#         "ROLL_HOME_PTS_FB",
#         "ROLL_HOME_PTS_PAINT",
#         "ROLL_HOME_OPP_PTS_PAINT",
#         "ROLL_AWAY_PTS_PAINT",
#         "ROLL_AWAY_OPP_PTS_PAINT",
#         "ROLL_HOME_EFG_PCT",
#         "ROLL_HOME_FTA_RATE",
#         "ROLL_HOME_OPP_EFG_PCT",
#         "ROLL_HOME_OPP_TOV_PCT",
#         "ROLL_AWAY_EFG_PCT",
#         "ROLL_AWAY_TM_TOV_PCT",
#         "ROLL_AWAY_OPP_EFG_PCT",
#         "ROLL_AWAY_OPP_FTA_RATE",
#         "ROLL_HOME_PCT_PTS_OFF_TOV",
#         "ROLL_HOME_AST_y",
#         "ROLL_HOME_CFGM",
#         "ROLL_HOME_CFG_PCT",
#         "ROLL_HOME_UFG_PCT",
#         "ROLL_HOME_FG_PCT_y",
#         "ROLL_HOME_DFGM",
#         "ROLL_HOME_DFG_PCT",
#         "ROLL_AWAY_AST_y",
#         "ROLL_AWAY_CFGM",
#         "ROLL_AWAY_UFGM",
#         "ROLL_AWAY_FG_PCT_y",
#         "ROLL_AWAY_DFGM"
#     ],
#     "feature_correlation": [
#         "ROLL_HOME_PTS",
#         "ROLL_HOME_FGA",
#         "ROLL_HOME_FG3M",
#         "ROLL_HOME_FG3_PCT",
#         "ROLL_HOME_FTM",
#         "ROLL_HOME_FT_PCT",
#         "ROLL_HOME_OREB",
#         "ROLL_HOME_DREB",
#         "ROLL_HOME_AST_x",
#         "ROLL_HOME_STL",
#         "ROLL_HOME_BLK_x",
#         "ROLL_HOME_TOV",
#         "ROLL_HOME_PF_x",
#         "ROLL_AWAY_PTS",
#         "ROLL_AWAY_FGA",
#         "ROLL_AWAY_FG3M",
#         "ROLL_AWAY_FTM",
#         "ROLL_AWAY_FT_PCT",
#         "ROLL_AWAY_OREB",
#         "ROLL_AWAY_DREB",
#         "ROLL_AWAY_STL",
#         "ROLL_AWAY_BLK_x",
#         "ROLL_AWAY_TOV",
#         "ROLL_AWAY_PF_x",
#         "ROLLDIFF_HOME_PTS",
#         "ROLLDIFF_HOME_FGA",
#         "ROLLDIFF_HOME_FG3M",
#         "ROLLDIFF_HOME_FG3A",
#         "ROLLDIFF_HOME_FTM",
#         "ROLLDIFF_HOME_FT_PCT",
#         "ROLLDIFF_HOME_OREB",
#         "ROLLDIFF_HOME_AST",
#         "ROLLDIFF_HOME_STL",
#         "ROLLDIFF_HOME_BLK",
#         "ROLLDIFF_AWAY_PTS",
#         "ROLLDIFF_AWAY_FGA",
#         "ROLLDIFF_AWAY_FG3M",
#         "ROLLDIFF_AWAY_FG3A",
#         "ROLLDIFF_AWAY_FTM",
#         "ROLLDIFF_AWAY_FT_PCT",
#         "ROLLDIFF_AWAY_AST",
#         "ROLLDIFF_AWAY_STL",
#         "ROLLDIFF_AWAY_BLK",
#         "ROLL_HOME_estimatedDefensiveRating",
#         "ROLL_HOME_defensiveReboundPercentage",
#         "ROLL_HOME_usagePercentage",
#         "ROLL_HOME_estimatedUsagePercentage",
#         "ROLL_HOME_estimatedPace",
#         "ROLL_AWAY_estimatedDefensiveRating",
#         "ROLL_AWAY_defensiveReboundPercentage",
#         "ROLL_AWAY_usagePercentage",
#         "ROLL_AWAY_estimatedUsagePercentage",
#         "ROLL_AWAY_estimatedPace",
#         "ROLL_HOME_CONTESTED_SHOTS",
#         "ROLL_HOME_CONTESTED_SHOTS_3PT",
#         "ROLL_HOME_DEFLECTIONS",
#         "ROLL_HOME_CHARGES_DRAWN",
#         "ROLL_HOME_SCREEN_ASSISTS",
#         "ROLL_HOME_OFF_LOOSE_BALLS_RECOVERED",
#         "ROLL_HOME_DEF_LOOSE_BALLS_RECOVERED",
#         "ROLL_HOME_OFF_BOXOUTS",
#         "ROLL_HOME_DEF_BOXOUTS",
#         "ROLL_AWAY_CONTESTED_SHOTS",
#         "ROLL_AWAY_CONTESTED_SHOTS_3PT",
#         "ROLL_AWAY_DEFLECTIONS",
#         "ROLL_AWAY_CHARGES_DRAWN",
#         "ROLL_AWAY_SCREEN_ASSISTS",
#         "ROLL_AWAY_OFF_LOOSE_BALLS_RECOVERED",
#         "ROLL_AWAY_DEF_LOOSE_BALLS_RECOVERED",
#         "ROLL_AWAY_OFF_BOXOUTS",
#         "ROLL_AWAY_DEF_BOXOUTS",
#         "ROLL_HOME_PTS_OFF_TOV",
#         "ROLL_HOME_PTS_FB",
#         "ROLL_HOME_PTS_PAINT",
#         "ROLL_HOME_OPP_PTS_FB",
#         "ROLL_HOME_OPP_PTS_PAINT",
#         "ROLL_HOME_BLKA",
#         "ROLL_AWAY_PTS_OFF_TOV",
#         "ROLL_AWAY_PTS_FB",
#         "ROLL_AWAY_PTS_PAINT",
#         "ROLL_AWAY_OPP_PTS_OFF_TOV",
#         "ROLL_AWAY_OPP_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_FB",
#         "ROLL_AWAY_OPP_PTS_PAINT",
#         "ROLL_AWAY_BLKA",
#         "ROLL_HOME_PCT_PTS_2PT_MR",
#         "ROLL_HOME_PCT_AST_3PM",
#         "ROLL_AWAY_PCT_PTS_2PT_MR",
#         "ROLL_AWAY_PCT_AST_3PM",
#         "ROLL_HOME_DIST",
#         "ROLL_HOME_DRBC",
#         "ROLL_HOME_TCHS",
#         "ROLL_HOME_SAST",
#         "ROLL_HOME_FTAST",
#         "ROLL_HOME_CFG_PCT",
#         "ROLL_HOME_UFGM",
#         "ROLL_HOME_DFG_PCT",
#         "ROLL_AWAY_DIST",
#         "ROLL_AWAY_TCHS",
#         "ROLL_AWAY_SAST",
#         "ROLL_AWAY_FTAST",
#         "ROLL_AWAY_CFG_PCT",
#         "ROLL_AWAY_UFGM",
#         "ROLL_AWAY_DFG_PCT"
#     ],
#     "VIF": [
#         "ROLLDIFF_HOME_STL",
#         "ROLLDIFF_AWAY_STL",
#         "ROLL_HOME_estimatedUsagePercentage",
#         "ROLL_AWAY_estimatedUsagePercentage",
#         "ROLL_HOME_DEFLECTIONS",
#         "ROLL_HOME_CHARGES_DRAWN",
#         "ROLL_HOME_BOX_OUT_PLAYER_REBS",
#         "ROLL_AWAY_DEFLECTIONS",
#         "ROLL_AWAY_CHARGES_DRAWN",
#         "ROLL_AWAY_BOX_OUT_PLAYER_REBS",
#         "ROLL_HOME_PTS_2ND_CHANCE",
#         "ROLL_HOME_OPP_PTS_OFF_TOV",
#         "ROLL_HOME_OPP_PTS_2ND_CHANCE",
#         "ROLL_HOME_OPP_PTS_FB",
#         "ROLL_AWAY_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_OFF_TOV",
#         "ROLL_AWAY_OPP_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_FB",
#         "ROLL_HOME_SAST",
#         "ROLL_HOME_FTAST",
#         "ROLL_AWAY_SAST",
#         "ROLL_AWAY_FTAST"
#     ],
#     "feature_intersection": [
#         "ROLL_HOME_CHARGES_DRAWN"
#     ]
# }
# Total time taken: 750.20 seconds

# %% [markdown]
# <a name="1.2.-vtreat-Library"></a>
# ## 1.2. `vtreat` Library
#
# [Return to top](#Feature-Selection)

# %%
start_time = time.time()

# automated feature selection and preprocessing
pts_features_selected, pts_selection = utl.vtreat_feature_selection(
    df=pts_features,
    outcome_name='TOTAL_PTS'
)

end_time = time.time()
print(f"Total time taken: {end_time - start_time:.2f} seconds")
# Out:
# There were 83 features selected out of 256 original features
#
# Total time taken: 0.81 seconds

# %%
pts_features_selected.head()
# Out:
#    ROLL_HOME_PCT_AST_2PM  ROLL_AWAY_effectiveFieldGoalPercentage  \
# 0                  0.807                                   0.712
# 1                  0.184                                   0.000
# 2                  0.291                                   0.618
# 3                  0.604                                   0.210
# 4                  0.650                                   0.416
#
#    ROLL_AWAY_offensiveRating  ROLL_HOME_CHARGES_DRAWN  ROLL_HOME_CFG_PCT  \
# 0                      0.611                    0.667              0.511
# 1                      0.152                    0.000              0.138
# 2                      0.684                    0.000              0.601
# 3                      0.277                    0.000              0.746
# 4                      0.600                    0.333              0.566
#
#    ROLL_HOME_pacePer40  ROLL_HOME_DFGA  ROLL_AWAY_possessions  ROLL_HOME_CFGM  \
# 0                1.000           1.000                  0.379           0.257
# 1                0.909           0.655                  0.408           0.527
# 2                0.879           0.276                  0.349           0.932
# 3                0.242           0.586                  0.438           0.662
# 4                0.758           0.655                  1.000           0.865
#
#    ROLL_HOME_offensiveRating  ROLL_AWAY_BOX_OUT_PLAYER_TEAM_REBS  \
# 0                      0.727                               0.149
# 1                      0.000                               0.468
# 2                      0.715                               0.149
# 3                      0.987                               0.149
# 4                      0.791                               0.415
#
#    ROLL_AWAY_CFG_PCT  ROLL_HOME_FTA  ROLL_HOME_OFF_LOOSE_BALLS_RECOVERED  \
# 0              0.564          0.878                                 0.60
# 1              0.000          0.534                                 0.30
# 2              0.581          0.534                                 0.45
# 3              0.735          0.382                                 0.60
# 4              0.355          0.229                                 0.45
#
#    ROLL_HOME_FTM  ROLL_HOME_estimatedOffensiveRating  \
# 0          0.805                               0.762
# 1          0.466                               0.000
# 2          0.593                               0.685
# 3          0.297                               0.849
# 4          0.254                               0.708
#
#    ROLL_HOME_trueShootingPercentage  ROLL_HOME_FTA_RATE  ROLL_AWAY_TM_TOV_PCT  \
# 0                             0.808               0.812                 0.521
# 1                             0.000               0.414                 0.406
# 2                             0.712               0.444                 0.255
# 3                             0.683               0.281                 0.385
# 4                             0.797               0.167                 0.370
#
#    ROLL_AWAY_PTS_OFF_TOV  ROLL_AWAY_FGM  ROLL_AWAY_EFG_PCT  ROLL_AWAY_DFG_PCT  \
# 0                  0.604          0.586              0.712              1.000
# 1                  0.340          0.017              0.000              0.453
# 2                  0.377          0.586              0.618              0.023
# 3                  0.000          0.069              0.210              0.965
# 4                  0.453          0.897              0.416              0.732
#
#    ROLL_HOME_PCT_UAST_2PM  ROLL_AWAY_UFGM  ...  ROLL_HOME_UFG_PCT  \
# 0                   0.193           0.409  ...              0.761
# 1                   0.816           0.364  ...              0.000
# 2                   0.709           0.682  ...              0.676
# 3                   0.396           0.136  ...              0.712
# 4                   0.350           1.000  ...              0.850
#
#    ROLL_AWAY_estimatedDefensiveRating  ROLL_AWAY_trueShootingPercentage  \
# 0                               0.881                             0.714
# 1                               0.566                             0.035
# 2                               0.462                             0.670
# 3                               0.894                             0.256
# 4                               0.555                             0.414
#
#    ROLL_HOME_defensiveRating  ROLL_HOME_assistRatio  \
# 0                      0.315                  0.597
# 1                      0.192                  0.000
# 2                      0.728                  0.582
# 3                      0.402                  0.888
# 4                      0.101                  0.724
#
#    ROLL_AWAY_estimatedOffensiveRating  ROLL_HOME_AST_x  ROLL_HOME_DFG_PCT  \
# 0                               0.672            0.612              0.352
# 1                               0.183            0.000              0.762
# 2                               0.700            0.561              0.720
# 3                               0.279            0.918              0.291
# 4                               0.543            0.765              0.075
#
#    ROLL_HOME_estimatedPace  ROLL_HOME_estimatedDefensiveRating  \
# 0                    0.763                               0.298
# 1                    0.732                               0.176
# 2                    0.740                               0.717
# 3                    0.367                               0.328
# 4                    0.812                               0.002
#
#    ROLL_HOME_AST_y  ROLL_HOME_PCT_PTS_OFF_TOV  ROLL_AWAY_FTM  \
# 0            0.612                      1.000          0.336
# 1            0.000                      0.602          0.294
# 2            0.561                      0.087          0.672
# 3            0.918                      0.469          0.588
# 4            0.765                      0.461          0.504
#
#    ROLL_AWAY_estimatedTeamTurnoverPercentage  ROLL_HOME_OPP_EFG_PCT  \
# 0                                      0.519                  0.487
# 1                                      0.404                  0.308
# 2                                      0.256                  0.624
# 3                                      0.383                  0.239
# 4                                      0.371                  0.205
#
#    ROLL_AWAY_PTS  ROLL_AWAY_AST_y  ROLL_AWAY_AST_x  ROLL_AWAY_defensiveRating  \
# 0          0.577            0.500            0.500                      0.875
# 1          0.096            0.083            0.083                      0.583
# 2          0.635            0.708            0.708                      0.513
# 3          0.250            0.208            0.208                      0.944
# 4          1.000            0.833            0.833                      0.614
#
#    ROLL_AWAY_pace  ROLL_AWAY_DFGA  ROLL_AWAY_DEF_BOXOUTS  ROLL_HOME_DFGM  \
# 0           0.515           0.423                  0.208           0.909
# 1           0.557           0.269                  0.307           0.909
# 2           0.430           0.423                  0.208           0.398
# 3           0.641           0.346                  0.109           0.455
# 4           0.516           0.731                  0.455           0.341
#
#    ROLL_HOME_OPP_TOV_PCT  TOTAL_PTS
# 0                  0.840        185
# 1                  0.762        198
# 2                  0.144        239
# 3                  0.519        232
# 4                  0.591        204
#
# [5 rows x 84 columns]

# %%
pts_selection
# Out:
# ['ROLL_HOME_PCT_AST_2PM',
#  'ROLL_AWAY_effectiveFieldGoalPercentage',
#  'ROLL_AWAY_offensiveRating',
#  'ROLL_HOME_CHARGES_DRAWN',
#  'ROLL_HOME_CFG_PCT',
#  'ROLL_HOME_pacePer40',
#  'ROLL_HOME_DFGA',
#  'ROLL_AWAY_possessions',
#  'ROLL_HOME_CFGM',
#  'ROLL_HOME_offensiveRating',
#  'ROLL_AWAY_BOX_OUT_PLAYER_TEAM_REBS',
#  'ROLL_AWAY_CFG_PCT',
#  'ROLL_HOME_FTA',
#  'ROLL_HOME_OFF_LOOSE_BALLS_RECOVERED',
#  'ROLL_HOME_FTM',
#  'ROLL_HOME_estimatedOffensiveRating',
#  'ROLL_HOME_trueShootingPercentage',
#  'ROLL_HOME_FTA_RATE',
#  'ROLL_AWAY_TM_TOV_PCT',
#  'ROLL_AWAY_PTS_OFF_TOV',
#  'ROLL_AWAY_FGM',
#  'ROLL_AWAY_EFG_PCT',
#  'ROLL_AWAY_DFG_PCT',
#  'ROLL_HOME_PCT_UAST_2PM',
#  'ROLL_AWAY_UFGM',
#  'ROLL_AWAY_FGA',
#  'ROLL_HOME_FG_PCT_y',
#  'ROLL_AWAY_OFF_LOOSE_BALLS_RECOVERED',
#  'ROLL_HOME_PTS_PAINT',
#  'ROLL_AWAY_assistToTurnover',
#  'ROLL_AWAY_BOX_OUTS',
#  'ROLL_AWAY_CFGM',
#  'ROLL_AWAY_DFGM',
#  'ROLL_HOME_FGM',
#  'ROLL_AWAY_FTA',
#  'ROLL_HOME_OPP_PTS_PAINT',
#  'ROLL_HOME_FTAST',
#  'ROLL_HOME_pace',
#  'ROLL_HOME_PTS',
#  'ROLL_HOME_effectiveFieldGoalPercentage',
#  'ROLL_AWAY_OPP_PTS_PAINT',
#  'ROLL_AWAY_UFG_PCT',
#  'ROLL_HOME_EFG_PCT',
#  'ROLL_AWAY_OPP_FTA_RATE',
#  'ROLL_AWAY_pacePer40',
#  'ROLL_HOME_LOOSE_BALLS_RECOVERED',
#  'ROLL_AWAY_OPP_EFG_PCT',
#  'ROLL_HOME_CFGA',
#  'ROLL_AWAY_PTS_FB',
#  'ROLL_AWAY_assistRatio',
#  'ROLL_AWAY_turnoverRatio',
#  'ROLL_HOME_assistToTurnover',
#  'ROLL_HOME_PTS_FB',
#  'ROLL_AWAY_TOV',
#  'ROLL_AWAY_PTS_PAINT',
#  'ROLL_AWAY_FG_PCT_x',
#  'ROLL_AWAY_FG_PCT_y',
#  'ROLL_HOME_FG_PCT_x',
#  'ROLL_AWAY_estimatedPace',
#  'ROLL_HOME_UFG_PCT',
#  'ROLL_AWAY_estimatedDefensiveRating',
#  'ROLL_AWAY_trueShootingPercentage',
#  'ROLL_HOME_defensiveRating',
#  'ROLL_HOME_assistRatio',
#  'ROLL_AWAY_estimatedOffensiveRating',
#  'ROLL_HOME_AST_x',
#  'ROLL_HOME_DFG_PCT',
#  'ROLL_HOME_estimatedPace',
#  'ROLL_HOME_estimatedDefensiveRating',
#  'ROLL_HOME_AST_y',
#  'ROLL_HOME_PCT_PTS_OFF_TOV',
#  'ROLL_AWAY_FTM',
#  'ROLL_AWAY_estimatedTeamTurnoverPercentage',
#  'ROLL_HOME_OPP_EFG_PCT',
#  'ROLL_AWAY_PTS',
#  'ROLL_AWAY_AST_y',
#  'ROLL_AWAY_AST_x',
#  'ROLL_AWAY_defensiveRating',
#  'ROLL_AWAY_pace',
#  'ROLL_AWAY_DFGA',
#  'ROLL_AWAY_DEF_BOXOUTS',
#  'ROLL_HOME_DFGM',
#  'ROLL_HOME_OPP_TOV_PCT']

# %% [markdown]
# <a name="2.-Filter-Methods-for-Plus-Minus"></a>
# # 2. Filter Methods for Plus Minus
#
# [Return to top](#Feature-Selection)

# %% [markdown]
# <a name="2.1.-Correlation-Based"></a>
# ## 2.1. Correlation Based
#
# [Return to top](#Feature-Selection)

# %%
start_time = time.time()

# filter-based feature selection
pm_selection = utl.filter_feature_selection(
    df=pm_features, 
    outcome_name='PLUS_MINUS'
)

end_time = time.time()
print(f"Total time taken: {end_time - start_time:.2f} seconds")
# Out:
# {
#     "outcome_correlation": [
#         "ROLL_HOME_PTS",
#         "ROLL_HOME_FG_PCT_x",
#         "ROLL_AWAY_FT_PCT",
#         "ROLLDIFF_HOME_PTS",
#         "ROLLDIFF_HOME_FGM",
#         "ROLLDIFF_HOME_FG_PCT",
#         "ROLLDIFF_HOME_DREB",
#         "ROLLDIFF_HOME_REB",
#         "ROLLDIFF_HOME_AST",
#         "ROLLDIFF_HOME_BLK",
#         "ROLLDIFF_AWAY_PTS",
#         "ROLLDIFF_AWAY_FGM",
#         "ROLLDIFF_AWAY_FG_PCT",
#         "ROLLDIFF_AWAY_FT_PCT",
#         "ROLLDIFF_AWAY_DREB",
#         "ROLLDIFF_AWAY_AST",
#         "ROLL_HOME_estimatedOffensiveRating",
#         "ROLL_HOME_offensiveRating",
#         "ROLL_HOME_estimatedNetRating",
#         "ROLL_HOME_netRating",
#         "ROLL_HOME_effectiveFieldGoalPercentage",
#         "ROLL_HOME_trueShootingPercentage",
#         "ROLL_HOME_PIE",
#         "ROLL_AWAY_offensiveRating",
#         "ROLL_AWAY_estimatedDefensiveRating",
#         "ROLL_AWAY_defensiveRating",
#         "ROLL_AWAY_estimatedNetRating",
#         "ROLL_AWAY_netRating",
#         "ROLL_AWAY_PIE",
#         "ROLL_HOME_SCREEN_ASSISTS",
#         "ROLL_HOME_SCREEN_AST_PTS",
#         "ROLL_HOME_BLKA",
#         "ROLL_AWAY_OPP_PTS_PAINT",
#         "ROLL_HOME_EFG_PCT",
#         "ROLL_HOME_OPP_EFG_PCT",
#         "ROLL_AWAY_OPP_EFG_PCT",
#         "ROLL_HOME_CFGA",
#         "ROLL_HOME_CFG_PCT",
#         "ROLL_HOME_UFGM",
#         "ROLL_HOME_FG_PCT_y",
#         "ROLL_AWAY_DFGM"
#     ],
#     "feature_correlation": [
#         "ROLL_HOME_PTS",
#         "ROLL_HOME_FGA",
#         "ROLL_HOME_FG3M",
#         "ROLL_HOME_FG3_PCT",
#         "ROLL_HOME_FTM",
#         "ROLL_HOME_FT_PCT",
#         "ROLL_HOME_OREB",
#         "ROLL_HOME_DREB",
#         "ROLL_HOME_AST_x",
#         "ROLL_HOME_STL",
#         "ROLL_HOME_BLK_x",
#         "ROLL_HOME_TOV",
#         "ROLL_HOME_PF_x",
#         "ROLL_AWAY_PTS",
#         "ROLL_AWAY_FGA",
#         "ROLL_AWAY_FG3M",
#         "ROLL_AWAY_FTM",
#         "ROLL_AWAY_FT_PCT",
#         "ROLL_AWAY_OREB",
#         "ROLL_AWAY_DREB",
#         "ROLL_AWAY_STL",
#         "ROLL_AWAY_BLK_x",
#         "ROLL_AWAY_TOV",
#         "ROLL_AWAY_PF_x",
#         "ROLLDIFF_HOME_PTS",
#         "ROLLDIFF_HOME_FGA",
#         "ROLLDIFF_HOME_FG3M",
#         "ROLLDIFF_HOME_FG3A",
#         "ROLLDIFF_HOME_FTM",
#         "ROLLDIFF_HOME_FT_PCT",
#         "ROLLDIFF_HOME_OREB",
#         "ROLLDIFF_HOME_AST",
#         "ROLLDIFF_HOME_STL",
#         "ROLLDIFF_HOME_BLK",
#         "ROLLDIFF_AWAY_PTS",
#         "ROLLDIFF_AWAY_FGA",
#         "ROLLDIFF_AWAY_FG3M",
#         "ROLLDIFF_AWAY_FG3A",
#         "ROLLDIFF_AWAY_FTM",
#         "ROLLDIFF_AWAY_FT_PCT",
#         "ROLLDIFF_AWAY_AST",
#         "ROLLDIFF_AWAY_STL",
#         "ROLLDIFF_AWAY_BLK",
#         "ROLL_HOME_estimatedDefensiveRating",
#         "ROLL_HOME_defensiveReboundPercentage",
#         "ROLL_HOME_usagePercentage",
#         "ROLL_HOME_estimatedUsagePercentage",
#         "ROLL_HOME_estimatedPace",
#         "ROLL_AWAY_estimatedDefensiveRating",
#         "ROLL_AWAY_defensiveReboundPercentage",
#         "ROLL_AWAY_usagePercentage",
#         "ROLL_AWAY_estimatedUsagePercentage",
#         "ROLL_AWAY_estimatedPace",
#         "ROLL_HOME_CONTESTED_SHOTS",
#         "ROLL_HOME_CONTESTED_SHOTS_3PT",
#         "ROLL_HOME_DEFLECTIONS",
#         "ROLL_HOME_CHARGES_DRAWN",
#         "ROLL_HOME_SCREEN_ASSISTS",
#         "ROLL_HOME_OFF_LOOSE_BALLS_RECOVERED",
#         "ROLL_HOME_DEF_LOOSE_BALLS_RECOVERED",
#         "ROLL_HOME_OFF_BOXOUTS",
#         "ROLL_HOME_DEF_BOXOUTS",
#         "ROLL_AWAY_CONTESTED_SHOTS",
#         "ROLL_AWAY_CONTESTED_SHOTS_3PT",
#         "ROLL_AWAY_DEFLECTIONS",
#         "ROLL_AWAY_CHARGES_DRAWN",
#         "ROLL_AWAY_SCREEN_ASSISTS",
#         "ROLL_AWAY_OFF_LOOSE_BALLS_RECOVERED",
#         "ROLL_AWAY_DEF_LOOSE_BALLS_RECOVERED",
#         "ROLL_AWAY_OFF_BOXOUTS",
#         "ROLL_AWAY_DEF_BOXOUTS",
#         "ROLL_HOME_PTS_OFF_TOV",
#         "ROLL_HOME_PTS_FB",
#         "ROLL_HOME_PTS_PAINT",
#         "ROLL_HOME_OPP_PTS_FB",
#         "ROLL_HOME_OPP_PTS_PAINT",
#         "ROLL_HOME_BLKA",
#         "ROLL_AWAY_PTS_OFF_TOV",
#         "ROLL_AWAY_PTS_FB",
#         "ROLL_AWAY_PTS_PAINT",
#         "ROLL_AWAY_OPP_PTS_OFF_TOV",
#         "ROLL_AWAY_OPP_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_FB",
#         "ROLL_AWAY_OPP_PTS_PAINT",
#         "ROLL_AWAY_BLKA",
#         "ROLL_HOME_PCT_PTS_2PT_MR",
#         "ROLL_HOME_PCT_AST_3PM",
#         "ROLL_AWAY_PCT_PTS_2PT_MR",
#         "ROLL_AWAY_PCT_AST_3PM",
#         "ROLL_HOME_DIST",
#         "ROLL_HOME_DRBC",
#         "ROLL_HOME_TCHS",
#         "ROLL_HOME_SAST",
#         "ROLL_HOME_FTAST",
#         "ROLL_HOME_CFG_PCT",
#         "ROLL_HOME_UFGM",
#         "ROLL_HOME_DFG_PCT",
#         "ROLL_AWAY_DIST",
#         "ROLL_AWAY_TCHS",
#         "ROLL_AWAY_SAST",
#         "ROLL_AWAY_FTAST",
#         "ROLL_AWAY_CFG_PCT",
#         "ROLL_AWAY_UFGM",
#         "ROLL_AWAY_DFG_PCT"
#     ],
#     "VIF": [
#         "ROLLDIFF_HOME_STL",
#         "ROLLDIFF_AWAY_STL",
#         "ROLL_HOME_estimatedUsagePercentage",
#         "ROLL_AWAY_estimatedUsagePercentage",
#         "ROLL_HOME_DEFLECTIONS",
#         "ROLL_HOME_CHARGES_DRAWN",
#         "ROLL_HOME_BOX_OUT_PLAYER_REBS",
#         "ROLL_AWAY_DEFLECTIONS",
#         "ROLL_AWAY_CHARGES_DRAWN",
#         "ROLL_AWAY_BOX_OUT_PLAYER_REBS",
#         "ROLL_HOME_PTS_2ND_CHANCE",
#         "ROLL_HOME_OPP_PTS_OFF_TOV",
#         "ROLL_HOME_OPP_PTS_2ND_CHANCE",
#         "ROLL_HOME_OPP_PTS_FB",
#         "ROLL_AWAY_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_OFF_TOV",
#         "ROLL_AWAY_OPP_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_FB",
#         "ROLL_HOME_SAST",
#         "ROLL_HOME_FTAST",
#         "ROLL_AWAY_SAST",
#         "ROLL_AWAY_FTAST"
#     ],
#     "feature_intersection": []
# }
# Total time taken: 1109.91 seconds

# %% [markdown]
# <a name="2.2.-vtreat-Library"></a>
# ## 2.2. `vtreat` Library
#
# [Return to top](#Feature-Selection)

# %%
start_time = time.time()

# automated feature selection and preprocessing
pm_features_selected, pm_selection = utl.vtreat_feature_selection(
    df=pm_features,
    outcome_name='PLUS_MINUS'
)

end_time = time.time()
print(f"Total time taken: {end_time - start_time:.2f} seconds")
# Out:
# There were 63 features selected out of 256 original features
#
# Total time taken: 0.66 seconds

# %%
pm_features_selected.head()
# Out:
#    ROLL_AWAY_offensiveRating  ROLLDIFF_AWAY_FG_PCT  ROLLDIFF_AWAY_TOV  \
# 0                      0.611                 0.428              0.280
# 1                      0.152                 0.464              0.402
# 2                      0.684                 0.399              0.366
# 3                      0.277                 0.188              0.585
# 4                      0.600                 0.232              0.463
#
#    ROLLDIFF_HOME_AST  ROLL_AWAY_SAST  ROLL_HOME_CFG_PCT  ROLL_HOME_FG3M  \
# 0              0.519           0.250              0.511           0.758
# 1              0.331           0.125              0.138           0.076
# 2              0.459           0.375              0.601           0.455
# 3              0.504           0.375              0.746           0.530
# 4              0.624           0.875              0.566           0.833
#
#    ROLLDIFF_AWAY_AST  ROLL_HOME_offensiveRating  ROLL_HOME_netRating  \
# 0              0.381                      0.727                0.698
# 1              0.467                      0.000                0.242
# 2              0.171                      0.715                0.417
# 3              0.314                      0.987                0.833
# 4              0.571                      0.791                0.886
#
#    ROLLDIFF_HOME_FGM  ROLL_HOME_estimatedOffensiveRating  \
# 0              0.485                               0.762
# 1              0.288                               0.000
# 2              0.523                               0.685
# 3              0.538                               0.849
# 4              0.750                               0.708
#
#    ROLL_HOME_trueShootingPercentage  ROLL_HOME_UFGA  ROLLDIFF_HOME_FG_PCT  \
# 0                             0.808           0.679                 0.488
# 1                             0.000           0.359                 0.130
# 2                             0.712           0.295                 0.569
# 3                             0.683           0.808                 0.346
# 4                             0.797           0.391                 0.715
#
#    ROLL_AWAY_FGM  ROLL_HOME_SCREEN_ASSISTS  ROLL_HOME_FG_PCT_y  \
# 0          0.586                     0.209               0.753
# 1          0.017                     0.209               0.000
# 2          0.586                     0.860               0.758
# 3          0.069                     0.488               0.827
# 4          0.897                     0.349               0.848
#
#    ROLLDIFF_AWAY_STL  ROLL_HOME_PIE  ROLL_AWAY_PIE  ROLL_AWAY_DFGM  \
# 0              0.533          0.780          0.330           0.620
# 1              0.300          0.000          0.060           0.185
# 2              0.600          0.502          0.746           0.076
# 3              0.350          0.787          0.000           0.511
# 4              0.400          0.978          0.471           0.783
#
#    ROLL_HOME_FGM  ROLLDIFF_HOME_DREB  ROLLDIFF_HOME_PTS  ...  ROLL_HOME_DREB  \
# 0          0.522               0.585              0.641  ...           0.292
# 1          0.000               0.455              0.286  ...           0.381
# 2          0.652               0.675              0.484  ...           0.602
# 3          0.826               0.317              0.508  ...           0.159
# 4          0.783               0.634              0.738  ...           0.779
#
#    ROLL_AWAY_netRating  ROLL_HOME_FG_PCT_x  ROLL_HOME_UFG_PCT  \
# 0                0.319               0.753              0.761
# 1                0.182               0.000              0.000
# 2                0.654               0.758              0.676
# 3                0.000               0.827              0.712
# 4                0.509               0.848              0.850
#
#    ROLL_AWAY_estimatedDefensiveRating  ROLL_AWAY_trueShootingPercentage  \
# 0                               0.881                             0.714
# 1                               0.566                             0.035
# 2                               0.462                             0.670
# 3                               0.894                             0.256
# 4                               0.555                             0.414
#
#    ROLL_HOME_defensiveRating  ROLL_HOME_assistRatio  \
# 0                      0.315                  0.597
# 1                      0.192                  0.000
# 2                      0.728                  0.582
# 3                      0.402                  0.888
# 4                      0.101                  0.724
#
#    ROLL_AWAY_estimatedOffensiveRating  ROLLDIFF_AWAY_FT_PCT  ROLL_HOME_BLKA  \
# 0                               0.672                 0.519             0.3
# 1                               0.183                 0.390             0.8
# 2                               0.700                 0.523             0.4
# 3                               0.279                 0.627             0.6
# 4                               0.543                 0.415             0.4
#
#    ROLL_HOME_estimatedDefensiveRating  ROLLDIFF_AWAY_FGM  ROLL_AWAY_FT_PCT  \
# 0                               0.298              0.509             0.603
# 1                               0.176              0.491             0.837
# 2                               0.717              0.473             0.469
# 3                               0.328              0.161             0.268
# 4                               0.002              0.268             0.446
#
#    ROLLDIFF_AWAY_PTS  ROLL_HOME_OPP_EFG_PCT  ROLL_AWAY_PTS  ROLLDIFF_AWAY_REB  \
# 0              0.482                  0.487          0.577              0.437
# 1              0.472                  0.308          0.096              0.364
# 2              0.365                  0.624          0.635              0.331
# 3              0.149                  0.239          0.250              0.245
# 4              0.309                  0.205          1.000              0.318
#
#    ROLL_AWAY_defensiveRating  ROLL_AWAY_DFGA  ROLL_HOME_SCREEN_AST_PTS  \
# 0                      0.875           0.423                     0.248
# 1                      0.583           0.269                     0.208
# 2                      0.513           0.423                     0.861
# 3                      0.944           0.346                     0.406
# 4                      0.614           0.731                     0.366
#
#    ROLL_HOME_DFGM  ROLLDIFF_HOME_FG3M  ROLL_HOME_estimatedNetRating  \
# 0           0.909               0.686                         0.779
# 1           0.909               0.605                         0.286
# 2           0.398               0.256                         0.457
# 3           0.455               0.593                         0.827
# 4           0.341               0.698                         0.931
#
#    PLUS_MINUS
# 0         7.0
# 1        -8.0
# 2        29.0
# 3       -10.0
# 4       -10.0
#
# [5 rows x 64 columns]

# %%
pm_selection
# Out:
# ['ROLL_AWAY_offensiveRating',
#  'ROLLDIFF_AWAY_FG_PCT',
#  'ROLLDIFF_AWAY_TOV',
#  'ROLLDIFF_HOME_AST',
#  'ROLL_AWAY_SAST',
#  'ROLL_HOME_CFG_PCT',
#  'ROLL_HOME_FG3M',
#  'ROLLDIFF_AWAY_AST',
#  'ROLL_HOME_offensiveRating',
#  'ROLL_HOME_netRating',
#  'ROLLDIFF_HOME_FGM',
#  'ROLL_HOME_estimatedOffensiveRating',
#  'ROLL_HOME_trueShootingPercentage',
#  'ROLL_HOME_UFGA',
#  'ROLLDIFF_HOME_FG_PCT',
#  'ROLL_AWAY_FGM',
#  'ROLL_HOME_SCREEN_ASSISTS',
#  'ROLL_HOME_FG_PCT_y',
#  'ROLLDIFF_AWAY_STL',
#  'ROLL_HOME_PIE',
#  'ROLL_AWAY_PIE',
#  'ROLL_AWAY_DFGM',
#  'ROLL_HOME_FGM',
#  'ROLLDIFF_HOME_DREB',
#  'ROLLDIFF_HOME_PTS',
#  'ROLL_HOME_OPP_PTS_PAINT',
#  'ROLLDIFF_AWAY_DREB',
#  'ROLL_HOME_PTS',
#  'ROLL_AWAY_estimatedNetRating',
#  'ROLLDIFF_HOME_REB',
#  'ROLL_HOME_effectiveFieldGoalPercentage',
#  'ROLL_AWAY_OPP_PTS_PAINT',
#  'ROLL_HOME_EFG_PCT',
#  'ROLL_AWAY_OPP_EFG_PCT',
#  'ROLL_HOME_CFGA',
#  'ROLL_AWAY_OPP_PTS_OFF_TOV',
#  'ROLLDIFF_HOME_BLK',
#  'ROLL_HOME_SAST',
#  'ROLL_HOME_UFGM',
#  'ROLL_HOME_DREB',
#  'ROLL_AWAY_netRating',
#  'ROLL_HOME_FG_PCT_x',
#  'ROLL_HOME_UFG_PCT',
#  'ROLL_AWAY_estimatedDefensiveRating',
#  'ROLL_AWAY_trueShootingPercentage',
#  'ROLL_HOME_defensiveRating',
#  'ROLL_HOME_assistRatio',
#  'ROLL_AWAY_estimatedOffensiveRating',
#  'ROLLDIFF_AWAY_FT_PCT',
#  'ROLL_HOME_BLKA',
#  'ROLL_HOME_estimatedDefensiveRating',
#  'ROLLDIFF_AWAY_FGM',
#  'ROLL_AWAY_FT_PCT',
#  'ROLLDIFF_AWAY_PTS',
#  'ROLL_HOME_OPP_EFG_PCT',
#  'ROLL_AWAY_PTS',
#  'ROLLDIFF_AWAY_REB',
#  'ROLL_AWAY_defensiveRating',
#  'ROLL_AWAY_DFGA',
#  'ROLL_HOME_SCREEN_AST_PTS',
#  'ROLL_HOME_DFGM',
#  'ROLLDIFF_HOME_FG3M',
#  'ROLL_HOME_estimatedNetRating']

# %% [markdown]
# <a name="3.-Filter-Methods-for-Game-Winner"></a>
# # 3. Filter Methods for Game Winner
#
# [Return to top](#Feature-Selection)

# %% [markdown]
# <a name="3.1.-Correlation-Based"></a>
# ## 3.1. Correlation Based
#
# [Return to top](#Feature-Selection)

# %%
start_time = time.time()

# filter-based feature selection
res_selection = utl.filter_feature_selection(
    df=res_features, 
    outcome_name='GAME_RESULT'
)

end_time = time.time()
print(f"Total time taken: {end_time - start_time:.2f} seconds")
# Out:
# {
#     "outcome_correlation": [
#         "ROLL_HOME_FG_PCT_x",
#         "ROLL_AWAY_STL",
#         "ROLLDIFF_HOME_PTS",
#         "ROLLDIFF_HOME_FGM",
#         "ROLLDIFF_HOME_FG_PCT",
#         "ROLLDIFF_HOME_DREB",
#         "ROLLDIFF_HOME_REB",
#         "ROLLDIFF_HOME_BLK",
#         "ROLLDIFF_AWAY_PTS",
#         "ROLLDIFF_AWAY_FGM",
#         "ROLLDIFF_AWAY_FG_PCT",
#         "ROLLDIFF_AWAY_AST",
#         "ROLLDIFF_AWAY_STL",
#         "ROLLDIFF_AWAY_TOV",
#         "ROLL_HOME_estimatedOffensiveRating",
#         "ROLL_HOME_offensiveRating",
#         "ROLL_HOME_estimatedDefensiveRating",
#         "ROLL_HOME_estimatedNetRating",
#         "ROLL_HOME_netRating",
#         "ROLL_HOME_effectiveFieldGoalPercentage",
#         "ROLL_HOME_trueShootingPercentage",
#         "ROLL_HOME_PIE",
#         "ROLL_AWAY_estimatedDefensiveRating",
#         "ROLL_AWAY_defensiveRating",
#         "ROLL_AWAY_estimatedNetRating",
#         "ROLL_AWAY_netRating",
#         "ROLL_AWAY_PIE",
#         "ROLL_AWAY_DEFLECTIONS",
#         "ROLL_HOME_OPP_PTS_PAINT",
#         "ROLL_HOME_BLKA",
#         "ROLL_AWAY_PTS_OFF_TOV",
#         "ROLL_HOME_EFG_PCT",
#         "ROLL_HOME_CFGA",
#         "ROLL_HOME_CFG_PCT",
#         "ROLL_HOME_UFGM",
#         "ROLL_HOME_UFGA",
#         "ROLL_HOME_FG_PCT_y"
#     ],
#     "feature_correlation": [
#         "ROLL_HOME_PTS",
#         "ROLL_HOME_FGA",
#         "ROLL_HOME_FG3M",
#         "ROLL_HOME_FG3_PCT",
#         "ROLL_HOME_FTM",
#         "ROLL_HOME_FT_PCT",
#         "ROLL_HOME_OREB",
#         "ROLL_HOME_DREB",
#         "ROLL_HOME_AST_x",
#         "ROLL_HOME_STL",
#         "ROLL_HOME_BLK_x",
#         "ROLL_HOME_TOV",
#         "ROLL_HOME_PF_x",
#         "ROLL_AWAY_PTS",
#         "ROLL_AWAY_FGA",
#         "ROLL_AWAY_FG3M",
#         "ROLL_AWAY_FTM",
#         "ROLL_AWAY_FT_PCT",
#         "ROLL_AWAY_OREB",
#         "ROLL_AWAY_DREB",
#         "ROLL_AWAY_STL",
#         "ROLL_AWAY_BLK_x",
#         "ROLL_AWAY_TOV",
#         "ROLL_AWAY_PF_x",
#         "ROLLDIFF_HOME_PTS",
#         "ROLLDIFF_HOME_FGA",
#         "ROLLDIFF_HOME_FG3M",
#         "ROLLDIFF_HOME_FG3A",
#         "ROLLDIFF_HOME_FTM",
#         "ROLLDIFF_HOME_FT_PCT",
#         "ROLLDIFF_HOME_OREB",
#         "ROLLDIFF_HOME_AST",
#         "ROLLDIFF_HOME_STL",
#         "ROLLDIFF_HOME_BLK",
#         "ROLLDIFF_AWAY_PTS",
#         "ROLLDIFF_AWAY_FGA",
#         "ROLLDIFF_AWAY_FG3M",
#         "ROLLDIFF_AWAY_FG3A",
#         "ROLLDIFF_AWAY_FTM",
#         "ROLLDIFF_AWAY_FT_PCT",
#         "ROLLDIFF_AWAY_AST",
#         "ROLLDIFF_AWAY_STL",
#         "ROLLDIFF_AWAY_BLK",
#         "ROLL_HOME_estimatedDefensiveRating",
#         "ROLL_HOME_defensiveReboundPercentage",
#         "ROLL_HOME_usagePercentage",
#         "ROLL_HOME_estimatedUsagePercentage",
#         "ROLL_HOME_estimatedPace",
#         "ROLL_AWAY_estimatedDefensiveRating",
#         "ROLL_AWAY_defensiveReboundPercentage",
#         "ROLL_AWAY_usagePercentage",
#         "ROLL_AWAY_estimatedUsagePercentage",
#         "ROLL_AWAY_estimatedPace",
#         "ROLL_HOME_CONTESTED_SHOTS",
#         "ROLL_HOME_CONTESTED_SHOTS_3PT",
#         "ROLL_HOME_DEFLECTIONS",
#         "ROLL_HOME_CHARGES_DRAWN",
#         "ROLL_HOME_SCREEN_ASSISTS",
#         "ROLL_HOME_OFF_LOOSE_BALLS_RECOVERED",
#         "ROLL_HOME_DEF_LOOSE_BALLS_RECOVERED",
#         "ROLL_HOME_OFF_BOXOUTS",
#         "ROLL_HOME_DEF_BOXOUTS",
#         "ROLL_AWAY_CONTESTED_SHOTS",
#         "ROLL_AWAY_CONTESTED_SHOTS_3PT",
#         "ROLL_AWAY_DEFLECTIONS",
#         "ROLL_AWAY_CHARGES_DRAWN",
#         "ROLL_AWAY_SCREEN_ASSISTS",
#         "ROLL_AWAY_OFF_LOOSE_BALLS_RECOVERED",
#         "ROLL_AWAY_DEF_LOOSE_BALLS_RECOVERED",
#         "ROLL_AWAY_OFF_BOXOUTS",
#         "ROLL_AWAY_DEF_BOXOUTS",
#         "ROLL_HOME_PTS_OFF_TOV",
#         "ROLL_HOME_PTS_FB",
#         "ROLL_HOME_PTS_PAINT",
#         "ROLL_HOME_OPP_PTS_FB",
#         "ROLL_HOME_OPP_PTS_PAINT",
#         "ROLL_HOME_BLKA",
#         "ROLL_AWAY_PTS_OFF_TOV",
#         "ROLL_AWAY_PTS_FB",
#         "ROLL_AWAY_PTS_PAINT",
#         "ROLL_AWAY_OPP_PTS_OFF_TOV",
#         "ROLL_AWAY_OPP_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_FB",
#         "ROLL_AWAY_OPP_PTS_PAINT",
#         "ROLL_AWAY_BLKA",
#         "ROLL_HOME_PCT_PTS_2PT_MR",
#         "ROLL_HOME_PCT_AST_3PM",
#         "ROLL_AWAY_PCT_PTS_2PT_MR",
#         "ROLL_AWAY_PCT_AST_3PM",
#         "ROLL_HOME_DIST",
#         "ROLL_HOME_DRBC",
#         "ROLL_HOME_TCHS",
#         "ROLL_HOME_SAST",
#         "ROLL_HOME_FTAST",
#         "ROLL_HOME_CFG_PCT",
#         "ROLL_HOME_UFGM",
#         "ROLL_HOME_DFG_PCT",
#         "ROLL_AWAY_DIST",
#         "ROLL_AWAY_TCHS",
#         "ROLL_AWAY_SAST",
#         "ROLL_AWAY_FTAST",
#         "ROLL_AWAY_CFG_PCT",
#         "ROLL_AWAY_UFGM",
#         "ROLL_AWAY_DFG_PCT"
#     ],
#     "VIF": [
#         "ROLLDIFF_HOME_STL",
#         "ROLLDIFF_AWAY_STL",
#         "ROLL_HOME_estimatedUsagePercentage",
#         "ROLL_AWAY_estimatedUsagePercentage",
#         "ROLL_HOME_DEFLECTIONS",
#         "ROLL_HOME_CHARGES_DRAWN",
#         "ROLL_HOME_BOX_OUT_PLAYER_REBS",
#         "ROLL_AWAY_DEFLECTIONS",
#         "ROLL_AWAY_CHARGES_DRAWN",
#         "ROLL_AWAY_BOX_OUT_PLAYER_REBS",
#         "ROLL_HOME_PTS_2ND_CHANCE",
#         "ROLL_HOME_OPP_PTS_OFF_TOV",
#         "ROLL_HOME_OPP_PTS_2ND_CHANCE",
#         "ROLL_HOME_OPP_PTS_FB",
#         "ROLL_AWAY_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_OFF_TOV",
#         "ROLL_AWAY_OPP_PTS_2ND_CHANCE",
#         "ROLL_AWAY_OPP_PTS_FB",
#         "ROLL_HOME_SAST",
#         "ROLL_HOME_FTAST",
#         "ROLL_AWAY_SAST",
#         "ROLL_AWAY_FTAST"
#     ],
#     "feature_intersection": [
#         "ROLL_AWAY_DEFLECTIONS",
#         "ROLLDIFF_AWAY_STL"
#     ]
# }
# Total time taken: 1256.15 seconds

# %% [markdown]
# <a name="3.2.-vtreat-Library"></a>
# ## 3.2. `vtreat` Library
#
# [Return to top](#Feature-Selection)

# %%
start_time = time.time()

# automated feature selection and preprocessing
res_features_selected, res_selection = utl.vtreat_feature_selection(
    df=res_features,
    outcome_name='GAME_RESULT'
)

end_time = time.time()
print(f"Total time taken: {end_time - start_time:.2f} seconds")
# Out:
# There were 54 features selected out of 256 original features
#
# Total time taken: 1.06 seconds

# %%
res_features_selected.head()
# Out:
#    ROLLDIFF_AWAY_FG_PCT  ROLLDIFF_AWAY_TOV  ROLLDIFF_HOME_AST  \
# 0                 0.428              0.280              0.519
# 1                 0.464              0.402              0.331
# 2                 0.399              0.366              0.459
# 3                 0.188              0.585              0.504
# 4                 0.232              0.463              0.624
#
#    ROLL_AWAY_DEFLECTIONS  ROLL_HOME_CFG_PCT  ROLL_HOME_DFGA  \
# 0                  0.363              0.511           1.000
# 1                  0.265              0.138           0.655
# 2                  0.314              0.601           0.276
# 3                  0.314              0.746           0.586
# 4                  0.559              0.566           0.655
#
#    ROLLDIFF_AWAY_AST  ROLL_HOME_offensiveRating  ROLL_HOME_netRating  \
# 0              0.381                      0.727                0.698
# 1              0.467                      0.000                0.242
# 2              0.171                      0.715                0.417
# 3              0.314                      0.987                0.833
# 4              0.571                      0.791                0.886
#
#    ROLLDIFF_HOME_FGM  ROLL_HOME_estimatedOffensiveRating  \
# 0              0.485                               0.762
# 1              0.288                               0.000
# 2              0.523                               0.685
# 3              0.538                               0.849
# 4              0.750                               0.708
#
#    ROLL_HOME_trueShootingPercentage  ROLL_HOME_UFGA  ROLLDIFF_HOME_FG_PCT  \
# 0                             0.808           0.679                 0.488
# 1                             0.000           0.359                 0.130
# 2                             0.712           0.295                 0.569
# 3                             0.683           0.808                 0.346
# 4                             0.797           0.391                 0.715
#
#    ROLL_AWAY_STL  ROLL_AWAY_PTS_OFF_TOV  ROLL_HOME_SCREEN_ASSISTS  \
# 0           0.28                  0.604                     0.209
# 1           0.28                  0.340                     0.209
# 2           0.36                  0.377                     0.860
# 3           0.20                  0.000                     0.488
# 4           0.76                  0.453                     0.349
#
#    ROLL_HOME_FG_PCT_y  ROLLDIFF_AWAY_STL  ROLL_HOME_PIE  ROLL_AWAY_PIE  \
# 0               0.753              0.533          0.780          0.330
# 1               0.000              0.300          0.000          0.060
# 2               0.758              0.600          0.502          0.746
# 3               0.827              0.350          0.787          0.000
# 4               0.848              0.400          0.978          0.471
#
#    ROLL_AWAY_DFGM  ROLLDIFF_HOME_DREB  ROLLDIFF_HOME_PTS  \
# 0           0.620               0.585              0.641
# 1           0.185               0.455              0.286
# 2           0.076               0.675              0.484
# 3           0.511               0.317              0.508
# 4           0.783               0.634              0.738
#
#    ROLL_HOME_OPP_PTS_PAINT  ...  ROLL_HOME_EFG_PCT  ROLL_AWAY_OPP_EFG_PCT  \
# 0                    0.808  ...              0.769                  0.900
# 1                    0.758  ...              0.000                  0.735
# 2                    0.505  ...              0.679                  0.474
# 3                    0.606  ...              0.739                  0.907
# 4                    0.202  ...              0.836                  0.763
#
#    ROLL_HOME_CFGA  ROLL_AWAY_OPP_PTS_OFF_TOV  ROLLDIFF_HOME_BLK  \
# 0           0.225                      0.875              0.552
# 1           1.000                      0.125              0.621
# 2           0.922                      0.542              0.534
# 3           0.496                      0.625              0.069
# 4           0.884                      0.458              0.707
#
#    ROLL_AWAY_assistRatio  ROLL_HOME_UFGM  ROLL_HOME_DREB  ROLL_AWAY_netRating  \
# 0                  0.571           0.696           0.292                0.319
# 1                  0.116           0.000           0.381                0.182
# 2                  0.769           0.391           0.602                0.654
# 3                  0.265           0.739           0.159                0.000
# 4                  0.571           0.565           0.779                0.509
#
#    ROLL_HOME_FG_PCT_x  ROLL_AWAY_estimatedDefensiveRating  \
# 0               0.753                               0.881
# 1               0.000                               0.566
# 2               0.758                               0.462
# 3               0.827                               0.894
# 4               0.848                               0.555
#
#    ROLL_HOME_defensiveRating  ROLL_HOME_BLKA  \
# 0                      0.315             0.3
# 1                      0.192             0.8
# 2                      0.728             0.4
# 3                      0.402             0.6
# 4                      0.101             0.4
#
#    ROLL_HOME_estimatedDefensiveRating  ROLLDIFF_AWAY_FGM  ROLLDIFF_AWAY_PTS  \
# 0                               0.298              0.509              0.482
# 1                               0.176              0.491              0.472
# 2                               0.717              0.473              0.365
# 3                               0.328              0.161              0.149
# 4                               0.002              0.268              0.309
#
#    ROLL_HOME_OPP_EFG_PCT  ROLL_AWAY_AST_y  ROLL_AWAY_AST_x  \
# 0                  0.487            0.500            0.500
# 1                  0.308            0.083            0.083
# 2                  0.624            0.708            0.708
# 3                  0.239            0.208            0.208
# 4                  0.205            0.833            0.833
#
#    ROLL_AWAY_defensiveRating  ROLL_AWAY_OPP_TOV_PCT  ROLL_HOME_SCREEN_AST_PTS  \
# 0                      0.875                  0.377                     0.248
# 1                      0.583                  0.309                     0.208
# 2                      0.513                  0.491                     0.861
# 3                      0.944                  0.171                     0.406
# 4                      0.614                  0.440                     0.366
#
#    ROLL_HOME_DFGM  ROLL_HOME_estimatedNetRating  GAME_RESULT
# 0           0.909                         0.779            1
# 1           0.909                         0.286            0
# 2           0.398                         0.457            1
# 3           0.455                         0.827            0
# 4           0.341                         0.931            0
#
# [5 rows x 55 columns]

# %%
res_selection
# Out:
# ['ROLLDIFF_AWAY_FG_PCT',
#  'ROLLDIFF_AWAY_TOV',
#  'ROLLDIFF_HOME_AST',
#  'ROLL_AWAY_DEFLECTIONS',
#  'ROLL_HOME_CFG_PCT',
#  'ROLL_HOME_DFGA',
#  'ROLLDIFF_AWAY_AST',
#  'ROLL_HOME_offensiveRating',
#  'ROLL_HOME_netRating',
#  'ROLLDIFF_HOME_FGM',
#  'ROLL_HOME_estimatedOffensiveRating',
#  'ROLL_HOME_trueShootingPercentage',
#  'ROLL_HOME_UFGA',
#  'ROLLDIFF_HOME_FG_PCT',
#  'ROLL_AWAY_STL',
#  'ROLL_AWAY_PTS_OFF_TOV',
#  'ROLL_HOME_SCREEN_ASSISTS',
#  'ROLL_HOME_FG_PCT_y',
#  'ROLLDIFF_AWAY_STL',
#  'ROLL_HOME_PIE',
#  'ROLL_AWAY_PIE',
#  'ROLL_AWAY_DFGM',
#  'ROLLDIFF_HOME_DREB',
#  'ROLLDIFF_HOME_PTS',
#  'ROLL_HOME_OPP_PTS_PAINT',
#  'ROLL_HOME_PTS',
#  'ROLL_AWAY_estimatedNetRating',
#  'ROLLDIFF_HOME_REB',
#  'ROLL_HOME_effectiveFieldGoalPercentage',
#  'ROLL_AWAY_OPP_PTS_PAINT',
#  'ROLL_HOME_EFG_PCT',
#  'ROLL_AWAY_OPP_EFG_PCT',
#  'ROLL_HOME_CFGA',
#  'ROLL_AWAY_OPP_PTS_OFF_TOV',
#  'ROLLDIFF_HOME_BLK',
#  'ROLL_AWAY_assistRatio',
#  'ROLL_HOME_UFGM',
#  'ROLL_HOME_DREB',
#  'ROLL_AWAY_netRating',
#  'ROLL_HOME_FG_PCT_x',
#  'ROLL_AWAY_estimatedDefensiveRating',
#  'ROLL_HOME_defensiveRating',
#  'ROLL_HOME_BLKA',
#  'ROLL_HOME_estimatedDefensiveRating',
#  'ROLLDIFF_AWAY_FGM',
#  'ROLLDIFF_AWAY_PTS',
#  'ROLL_HOME_OPP_EFG_PCT',
#  'ROLL_AWAY_AST_y',
#  'ROLL_AWAY_AST_x',
#  'ROLL_AWAY_defensiveRating',
#  'ROLL_AWAY_OPP_TOV_PCT',
#  'ROLL_HOME_SCREEN_AST_PTS',
#  'ROLL_HOME_DFGM',
#  'ROLL_HOME_estimatedNetRating']
