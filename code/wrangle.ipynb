# %%
import pandas as pd

# %% [markdown]
# # Team box scores

# %%
# read in each file
two = pd.read_csv("../data/original/br_team_box_scores_2000_2024.csv")
team_bs_df = pd.read_csv("../data/original/br_team_box_scores_1999.csv")

# %%
team_bs_df = pd.concat([one, two, three, four, five], ignore_index=True)

# %%
# append datasets
# team_bs_df = pd.concat([one, two], ignore_index=True)

# make 'date' the first column
date_column = team_bs_df.pop('date')
team_bs_df.insert(0, 'date', date_column)

# %%
team_bs_df.head()
# Out:
#          date                        team       outcome  minutes_played  \
# 0  1999-11-02          Team.ORLANDO_MAGIC  Outcome.LOSS             240
# 1  1999-11-02      Team.CHARLOTTE_HORNETS   Outcome.WIN             240
# 2  1999-11-02  Team.GOLDEN_STATE_WARRIORS  Outcome.LOSS             240
# 3  1999-11-02       Team.DALLAS_MAVERICKS   Outcome.WIN             240
# 4  1999-11-02           Team.PHOENIX_SUNS  Outcome.LOSS             265
#
#    made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# 0                34                     80                             0
# 1                34                     82                            10
# 2                34                     82                             7
# 3                39                     85                             2
# 4                43                    111                             9
#
#    attempted_three_point_field_goals  made_free_throws  attempted_free_throws  \
# 0                                  8                18                     27
# 1                                 22                22                     37
# 2                                 18                21                     27
# 3                                 15                28                     34
# 4                                 22                 7                     14
#
#    offensive_rebounds  defensive_rebounds  assists  steals  blocks  turnovers  \
# 0                  12                  36       17       9       4         22
# 1                  14                  33       25      13       5         21
# 2                  18                  33       14       4       2         23
# 3                  11                  30       22      11       6         13
# 4                  21                  37       29       9       5         13
#
#    personal_fouls  points
# 0              31      86
# 1              25     100
# 2              29      96
# 3              19     108
# 4              28     102

# %%
# remove prefixes from categorical columns
columns_to_process = ['team', 'outcome']

for col in columns_to_process:
    team_bs_df[col] = team_bs_df[col].apply(lambda x: x.split('.')[1] if pd.notnull(x) and '.' in x else x)
    team_bs_df[col] = team_bs_df[col].str.replace('_', ' ').str.title()

# %%
team_bs_df.head()
# Out:
#          date                   team outcome  minutes_played  \
# 0  1999-11-02          Orlando Magic    Loss             240
# 1  1999-11-02      Charlotte Hornets     Win             240
# 2  1999-11-02  Golden State Warriors    Loss             240
# 3  1999-11-02       Dallas Mavericks     Win             240
# 4  1999-11-02           Phoenix Suns    Loss             265
#
#    made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# 0                34                     80                             0
# 1                34                     82                            10
# 2                34                     82                             7
# 3                39                     85                             2
# 4                43                    111                             9
#
#    attempted_three_point_field_goals  made_free_throws  attempted_free_throws  \
# 0                                  8                18                     27
# 1                                 22                22                     37
# 2                                 18                21                     27
# 3                                 15                28                     34
# 4                                 22                 7                     14
#
#    offensive_rebounds  defensive_rebounds  assists  steals  blocks  turnovers  \
# 0                  12                  36       17       9       4         22
# 1                  14                  33       25      13       5         21
# 2                  18                  33       14       4       2         23
# 3                  11                  30       22      11       6         13
# 4                  21                  37       29       9       5         13
#
#    personal_fouls  points
# 0              31      86
# 1              25     100
# 2              29      96
# 3              19     108
# 4              28     102

# %%
team_bs_df = pd.concat([team_bs_df, two], ignore_index=True)

# %%
team_bs_df.head()
# Out:
#          date                   team outcome  minutes_played  \
# 0  1999-11-02          Orlando Magic    Loss             240
# 1  1999-11-02      Charlotte Hornets     Win             240
# 2  1999-11-02  Golden State Warriors    Loss             240
# 3  1999-11-02       Dallas Mavericks     Win             240
# 4  1999-11-02           Phoenix Suns    Loss             265
#
#    made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# 0                34                     80                             0
# 1                34                     82                            10
# 2                34                     82                             7
# 3                39                     85                             2
# 4                43                    111                             9
#
#    attempted_three_point_field_goals  made_free_throws  attempted_free_throws  \
# 0                                  8                18                     27
# 1                                 22                22                     37
# 2                                 18                21                     27
# 3                                 15                28                     34
# 4                                 22                 7                     14
#
#    offensive_rebounds  defensive_rebounds  assists  steals  blocks  turnovers  \
# 0                  12                  36       17       9       4         22
# 1                  14                  33       25      13       5         21
# 2                  18                  33       14       4       2         23
# 3                  11                  30       22      11       6         13
# 4                  21                  37       29       9       5         13
#
#    personal_fouls  points
# 0              31      86
# 1              25     100
# 2              29      96
# 3              19     108
# 4              28     102

# %%
team_bs_df.to_csv('../data/original/br_team_box_scores_2000_2024_2.csv', index=False)

# %% [markdown]
# # Player Box Scores

# %%
# read in each file
two = pd.read_csv("../data/original/br_player_box_scores_2000_2024.csv")
player_bs_df = pd.read_csv("../data/original/br_player_box_scores_1999.csv")

# %%
# append datasets
# player_bs_df = pd.concat([one, two, three, four, five], ignore_index=True)

# make 'date' the first column
date_column = player_bs_df.pop('date')
player_bs_df.insert(0, 'date', date_column)

# %%
# remove prefixes from categorical columns
columns_to_process = ['team', 'location', 'opponent', 'outcome']

for col in columns_to_process:
    player_bs_df[col] = player_bs_df[col].apply(lambda x: x.split('.')[1] if pd.notnull(x) and '.' in x else x)
    player_bs_df[col] = player_bs_df[col].str.replace('_', ' ').str.title()

# %%
player_bs_df.head()
# Out:
#          date       slug           name                  team location  \
# 0  1999-11-02  cassesa01    Sam Cassell       Milwaukee Bucks     Away
# 1  1999-11-02  vanexni01  Nick Van Exel        Denver Nuggets     Home
# 2  1999-11-02  piercpa01    Paul Pierce        Boston Celtics     Away
# 3  1999-11-02   odomla01     Lamar Odom  Los Angeles Clippers     Home
# 4  1999-11-02   hillgr01     Grant Hill       Detroit Pistons     Away
#
#               opponent outcome  seconds_played  made_field_goals  \
# 0      Houston Rockets     Win            2250                15
# 1         Phoenix Suns     Win            2733                12
# 2      Toronto Raptors     Win            2273                12
# 3  Seattle Supersonics    Loss            2607                10
# 4           Miami Heat    Loss            3134                16
#
#    attempted_field_goals  ...  made_free_throws  attempted_free_throws  \
# 0                     20  ...                 5                      7
# 1                     21  ...                 5                      7
# 2                     19  ...                 3                      6
# 3                     18  ...                 8                     15
# 4                     35  ...                 8                     11
#
#    offensive_rebounds  defensive_rebounds  assists  steals  blocks  turnovers  \
# 0                   1                   2       11       1       0          4
# 1                   2                   7        9       0       0          3
# 2                   1                   7        5       2       0          2
# 3                   2                  10        3       2       2          3
# 4                   3                   6        5       0       1          4
#
#    personal_fouls  game_score
# 0               5        30.2
# 1               1        29.7
# 2               3        25.4
# 3               1        25.1
# 4               5        23.8
#
# [5 rows x 22 columns]

# %%
player_bs_df = pd.concat([player_bs_df, two], ignore_index=True)

# %%
player_bs_df.head()
# Out:
#          date       slug           name                  team location  \
# 0  1999-11-02  cassesa01    Sam Cassell       Milwaukee Bucks     Away
# 1  1999-11-02  vanexni01  Nick Van Exel        Denver Nuggets     Home
# 2  1999-11-02  piercpa01    Paul Pierce        Boston Celtics     Away
# 3  1999-11-02   odomla01     Lamar Odom  Los Angeles Clippers     Home
# 4  1999-11-02   hillgr01     Grant Hill       Detroit Pistons     Away
#
#               opponent outcome  seconds_played  made_field_goals  \
# 0      Houston Rockets     Win            2250                15
# 1         Phoenix Suns     Win            2733                12
# 2      Toronto Raptors     Win            2273                12
# 3  Seattle Supersonics    Loss            2607                10
# 4           Miami Heat    Loss            3134                16
#
#    attempted_field_goals  ...  made_free_throws  attempted_free_throws  \
# 0                     20  ...                 5                      7
# 1                     21  ...                 5                      7
# 2                     19  ...                 3                      6
# 3                     18  ...                 8                     15
# 4                     35  ...                 8                     11
#
#    offensive_rebounds  defensive_rebounds  assists  steals  blocks  turnovers  \
# 0                   1                   2       11       1       0          4
# 1                   2                   7        9       0       0          3
# 2                   1                   7        5       2       0          2
# 3                   2                  10        3       2       2          3
# 4                   3                   6        5       0       1          4
#
#    personal_fouls  game_score
# 0               5        30.2
# 1               1        29.7
# 2               3        25.4
# 3               1        25.1
# 4               5        23.8
#
# [5 rows x 22 columns]

# %%
player_bs_df.to_csv('../data/original/br_player_box_scores_2000_2024_2.csv', index=False)

# %% [markdown]
# # Standings

# %%
standings_df = pd.read_csv("../data/original/br_standings_2000_2023.csv")

# %%
# reorder columns
standings_df = standings_df[['year', 'conference', 'division', 
                             'team', 'wins', 'losses']]

# %%
# remove prefixes from categorical columns
columns_to_process = ['team', 'division', 'conference']

for col in columns_to_process:
    standings_df[col] = standings_df[col].apply(lambda x: x.split('.')[1] if pd.notnull(x) and '.' in x else x)
    standings_df[col] = standings_df[col].str.replace('_', ' ').str.title()

# %%
standings_df.head()
# Out:
#    year conference  division                team  wins  losses
# 0  2000    Eastern  Atlantic          Miami Heat    52      30
# 1  2000    Eastern  Atlantic     New York Knicks    50      32
# 2  2000    Eastern  Atlantic  Philadelphia 76Ers    49      33
# 3  2000    Eastern  Atlantic       Orlando Magic    41      41
# 4  2000    Eastern  Atlantic      Boston Celtics    35      47

# %%
standings_df.to_csv('../data/original/br_standings_2000_2023_2.csv', index=False)

# %% [markdown]
# # Season Schedule

# %%
season_schedule_df = pd.read_csv("../data/original/br_season_schedule_2000_2023.csv")

# %%
# reorder columns
season_schedule_df = season_schedule_df[['year', 'start_time', 'home_team', 
                             'away_team', 'home_team_score', 'away_team_score']]

# %%
# remove prefixes from categorical columns
columns_to_process = ['home_team', 'away_team']

for col in columns_to_process:
    season_schedule_df[col] = season_schedule_df[col].apply(lambda x: x.split('.')[1] if pd.notnull(x) and '.' in x else x)
    season_schedule_df[col] = season_schedule_df[col].str.replace('_', ' ').str.title()

# %%
season_schedule_df.head()
# Out:
#    year                 start_time             home_team  \
# 0  2000  1999-11-02 05:00:00+00:00     Charlotte Hornets
# 1  2000  1999-11-02 05:00:00+00:00      Dallas Mavericks
# 2  2000  1999-11-02 05:00:00+00:00        Denver Nuggets
# 3  2000  1999-11-02 05:00:00+00:00       Houston Rockets
# 4  2000  1999-11-02 05:00:00+00:00  Los Angeles Clippers
#
#                away_team  home_team_score  away_team_score
# 0          Orlando Magic              100               86
# 1  Golden State Warriors              108               96
# 2           Phoenix Suns              107              102
# 3        Milwaukee Bucks               93               98
# 4    Seattle Supersonics               92              104

# %%
season_schedule_df.to_csv('../data/original/br_season_schedule_2000_2023_2.csv', index=False)

# %% [markdown]
# # Player seasons totals

# %%
# read in each file
players_season_totals_df = pd.read_csv("../data/original/br_players_season_totals_2000_2023.csv")

# %%
# make 'year' the first column
year_column = players_season_totals_df.pop('year')
players_season_totals_df.insert(0, 'year', year_column)

# %%
players_season_totals_df.head()

# %%
# remove prefixes from categorical columns
columns_to_process = ['team']

for col in columns_to_process:
    players_season_totals_df[col] = players_season_totals_df[col].apply(lambda x: x.split('.')[1] if pd.notnull(x) and '.' in x else x)
    players_season_totals_df[col] = players_season_totals_df[col].str.replace('_', ' ').str.title()

# %%
# extract strings from 'positions' column
import re

def extract_position(text):
    '''
    Converts 'CENTER' to 'Center' and 'POWER FORWARD' to 'Power Forward'
    '''
    match = re.search(r"Position\.\w+: '([\w\s]+)'", text)
    if match:
        return match.group(1).title()  


players_season_totals_df['positions'] = players_season_totals_df['positions'].apply(extract_position)

# %%
players_season_totals_df.head()

# %%
players_season_totals_df.to_csv('../data/original/br_players_season_totals_2000_2023_2.csv', index=False)

# %% [markdown]
# # Player seasons totals advanced

# %%
# read in each file
players_season_totals_adv_df = pd.read_csv("../data/original/br_players_season_totals_advanced_2000_2023.csv")

# %%
# make 'year' the first column
year_column = players_season_totals_adv_df.pop('year')
players_season_totals_adv_df.insert(0, 'year', year_column)

# %%
players_season_totals_adv_df.head()

# %%
# remove prefixes from categorical columns
columns_to_process = ['team']

for col in columns_to_process:
    players_season_totals_adv_df[col] = players_season_totals_adv_df[col].apply(lambda x: x.split('.')[1] if pd.notnull(x) and '.' in x else x)
    players_season_totals_adv_df[col] = players_season_totals_adv_df[col].str.replace('_', ' ').str.title()

# %%
# extract strings from 'positions' column
import re

def extract_position(text):
    '''
    Converts 'CENTER' to 'Center' and 'POWER FORWARD' to 'Power Forward'
    '''
    match = re.search(r"Position\.\w+: '([\w\s]+)'", text)
    if match:
        return match.group(1).title()  


players_season_totals_adv_df['positions'] = players_season_totals_adv_df['positions'].apply(extract_position)

# %%
players_season_totals_adv_df.head()

# %%
players_season_totals_adv_df.to_csv('../data/original/br_players_season_totals_advanced_2000_2023_2.csv', index=False)
