# %% [markdown]
# <div class="alert alert-danger">
#     <h4 style="font-weight: bold; font-size: 28px;">Feature Engineering</h4>
#     <p style="font-size: 20px;">NBA API Data (2022-2024)</p>
# </div>
#
# <a name="Feature-Engineering"></a>

# %% [markdown]
# # Table of Contents

# %% [markdown]
# [Setup](#Setup)
#
# [Data](#Data)
#
# **[1. Create Team Matchups and Targets](#1.-Create-Team-Matchups-and-Targets)**
#
# - [1.1. Clean Game Data](#1.1.-Clean-Game-Data)
#
# - [1.2. Reshape to Game Matchups](#1.2.-Reshape-to-Game-Matchups)
#
# - [1.3. Create Target Variables](#1.3.-Create-Target-Variables)
#
# **[2. Create Rolling Window Statistics](#2.-Create-Rolling-Window-Statistics)**

# %% [markdown]
# # Setup
#
# [Return to top](#Feature-Engineering)

# %%
import sys
from pathlib import Path
# get current working directory
cwd = %pwd
# add shared_code directory to Python sys.path
sys.path.append(str(Path(cwd).parent / "shared_code"))
# import all libraries in shared_code directory 'imports.py' file
from imports import *
# %matplotlib inline

# %% [markdown]
# # Data
#
# [Return to top](#Feature-Engineering)

# %%
hustle_stats_df = pd.read_csv('../../data/original/nba_hustle_statistics_2021_2024.csv')
hustle_stats_df.rename(columns={'MINUTES':'MIN'}, inplace=True)
hustle_stats_df['MIN'] = hustle_stats_df['MIN'].str.slice(0, 3)
hustle_stats_df = hustle_stats_df.drop(hustle_stats_df[hustle_stats_df['MIN'] == '0.0'].index)
hustle_stats_df = hustle_stats_df.drop(hustle_stats_df[hustle_stats_df['MIN'] == '80.'].index)
hustle_stats_df['MIN'] = hustle_stats_df['MIN'].astype(int)
hustle_stats_df.head()
# Out:
#     GAME_ID     TEAM_ID           TEAM_NAME TEAM_ABBREVIATION  MIN  PTS  \
# 0  22101221  1610612737       Atlanta Hawks               ATL  240  130
# 1  22101221  1610612745     Houston Rockets               HOU  240  114
# 2  22101207  1610612737       Atlanta Hawks               ATL  240  109
# 3  22101207  1610612748          Miami Heat               MIA  240  113
# 4  22101192  1610612764  Washington Wizards               WAS  240  103
#
#    CONTESTED_SHOTS  CONTESTED_SHOTS_2PT  CONTESTED_SHOTS_3PT  DEFLECTIONS  \
# 0               45                   21                   24           12
# 1               42                   24                   18            3
# 2               40                   25                   15           19
# 3               53                   31                   22           17
# 4               49                   27                   22            9
#
#    CHARGES_DRAWN  SCREEN_ASSISTS  SCREEN_AST_PTS  OFF_LOOSE_BALLS_RECOVERED  \
# 0              0               4              10                          0
# 1              0              18              44                          5
# 2              1               7              15                          4
# 3              0               9              21                          3
# 4              0               7              15                          2
#
#    DEF_LOOSE_BALLS_RECOVERED  LOOSE_BALLS_RECOVERED  OFF_BOXOUTS  DEF_BOXOUTS  \
# 0                          1                      1            1           11
# 1                          1                      6            1            4
# 2                          3                      7            1            6
# 3                          2                      5            0           10
# 4                          2                      4            2           14
#
#    BOX_OUT_PLAYER_TEAM_REBS  BOX_OUT_PLAYER_REBS  BOX_OUTS  SEASON_ID  \
# 0                         9                    3        12      22021
# 1                         4                    3         5      22021
# 2                         6                    4         7      22021
# 3                        10                    2        10      22021
# 4                        16                   10        16      22021
#
#     GAME_DATE      MATCHUP
# 0  2022-04-10    ATL @ HOU
# 1  2022-04-10  HOU vs. ATL
# 2  2022-04-08    ATL @ MIA
# 3  2022-04-08  MIA vs. ATL
# 4  2022-04-06    WAS @ ATL

# %%
box_score_df = pd.read_csv('../../data/original/nba_games_box_scores_2022_2024.csv')

# %%
box_score_df.tail()
# Out:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 7520      22023  1610612764               WAS  Washington Wizards  22300642
# 7521      22023  1610612764               WAS  Washington Wizards  22300665
# 7522      22023  1610612764               WAS  Washington Wizards  22300676
# 7523      22023  1610612764               WAS  Washington Wizards  22300689
# 7524      22023  1610612764               WAS  Washington Wizards  22300705
#
#        GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 7520  2024-01-27    WAS @ DET  W  240  118   45  100   0.450    11  34.0
# 7521  2024-01-29    WAS @ SAS  W  240  118   46   86   0.535     9  25.0
# 7522  2024-01-31  WAS vs. LAC  L  239  109   45   97   0.464     9  29.0
# 7523  2024-02-02  WAS vs. MIA  L  239  102   37   90   0.411    11  42.0
# 7524  2024-02-04  WAS vs. PHX  L  240  112   47   96   0.490     7  32.0
#
#       FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB   REB  AST   STL  BLK  TOV  PF  \
# 7520    0.324   17   21   0.810  16.0  34.0  50.0   26  10.0    4    9  19
# 7521    0.360   17   24   0.708  14.0  31.0  45.0   32   9.0    8   18  15
# 7522    0.310   10   15   0.667  12.0  33.0  45.0   19   4.0   10   13  19
# 7523    0.262   17   21   0.810   6.0  37.0  43.0   28   5.0    4    8  25
# 7524    0.219   11   17   0.647  13.0  22.0  35.0   32  11.0    4   18  19
#
#       PLUS_MINUS
# 7520        14.0
# 7521         5.0
# 7522       -16.0
# 7523        -8.0
# 7524       -28.0

# %% [markdown]
# <a name="1.-Create-Team-Matchups-and-Targets"></a>
# # 1. Create Team Matchups and Targets
#
# [Return to top](#Feature-Engineering)

# %% [markdown]
# <a name="1.1.-Clean-Game-Data"></a>
# ## 1.1. Clean Game Data
#
# [Return to top](#Feature-Engineering)

# %% [markdown]
# We need to do three key things to clean the data:
#
# 1. Remove games with team aggregated game times of less than 238 minutes (which will remove exhibition matches).
# 2. Retain only games that are part of the regular season.
# 3. Remove any orphans (i.e., game IDs that do not have a partner) when reshaping to matchups.

# %% [markdown]
# Last 3 NBA regular seasons start and end dates:
#
# - 2021-22 season: 2021-10-19 to 2022-04-10
# - 2022-23 season: 2022-10-18 to 2023-04-09
# - 2023-24 season: 2023-10-24 to 2024-04-14

# %%
# last 3 seasons start and end dates and labels
season_start_dates = ['2021-10-19', '2022-10-18', '2023-10-24']
season_end_dates   = ['2022-04-10', '2023-04-09', '2024-04-14']
season_labels      = ['2021-22', '2022-23', '2023-24']

# %%
# clean up the data
hustle_stats_df_cleaned = utl.clean_team_bs_data(hustle_stats_df, season_start_dates=season_start_dates, 
                                            season_end_dates=season_end_dates, season_labels=season_labels)
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 842 games

# %%
# clean up the data
box_score_df_cleaned = utl.clean_team_bs_data(box_score_df, season_start_dates=season_start_dates, 
                                            season_end_dates=season_end_dates, season_labels=season_labels)
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 736 games

# %%
#get GAME_DATE, MATCHUP, GAME_ID, TEAM_ABBREVIATION fields from games_df
hustle_stats_df_cleaned = pd.merge(hustle_stats_df_cleaned, box_score_df_cleaned[['WL','GAME_ID','TEAM_ID', 'TEAM_ABBREVIATION', 'PLUS_MINUS']], on=['GAME_ID','TEAM_ID', 'TEAM_ABBREVIATION'])

hustle_stats_df_cleaned.sort_values(by=['PTS'])
# Out:
#        GAME_ID     TEAM_ID              TEAM_NAME TEAM_ABBREVIATION  MIN  PTS  \
# 889   22100075  1610612742       Dallas Mavericks               DAL  240   75
# 224   22100717  1610612758       Sacramento Kings               SAC  240   75
# 242   22100595  1610612752        New York Knicks               NYK  240   75
# 787   22100988  1610612742       Dallas Mavericks               DAL  240   77
# 727   22100257  1610612741          Chicago Bulls               CHI  240   77
# ...        ...         ...                    ...               ...  ...  ...
# 2316  22100899  1610612759      San Antonio Spurs               SAS  290  157
# 3480  22201230  1610612744  Golden State Warriors               GSW  240  157
# 2048  22100723  1610612766      Charlotte Hornets               CHA  240  158
# 3751  22200902  1610612746            LA Clippers               LAC  290  175
# 3750  22200902  1610612758       Sacramento Kings               SAC  290  176
#
#       CONTESTED_SHOTS  CONTESTED_SHOTS_2PT  CONTESTED_SHOTS_3PT  DEFLECTIONS  \
# 889                38                   22                   16           18
# 224                72                   39                   33           17
# 242                46                   27                   19           14
# 787                46                   28                   18           14
# 727                51                   33                   18           15
# ...               ...                  ...                  ...          ...
# 2316               68                   40                   28           13
# 3480               59                   37                   22           14
# 2048               44                   25                   19           15
# 3751               51                   27                   24           18
# 3750               53                   28                   25           21
#
#       CHARGES_DRAWN  SCREEN_ASSISTS  SCREEN_AST_PTS  \
# 889               0               6              15
# 224               0               4               9
# 242               0              10              22
# 787               1              10              22
# 727               0               7              15
# ...             ...             ...             ...
# 2316              0              17              37
# 3480              0               8              21
# 2048              1               7              18
# 3751              1               4               9
# 3750              0               6              15
#
#       OFF_LOOSE_BALLS_RECOVERED  DEF_LOOSE_BALLS_RECOVERED  \
# 889                           2                          1
# 224                           4                          5
# 242                           1                          3
# 787                           2                          1
# 727                           1                          0
# ...                         ...                        ...
# 2316                          4                          5
# 3480                          2                          4
# 2048                          5                          5
# 3751                          3                          4
# 3750                          0                          3
#
#       LOOSE_BALLS_RECOVERED  OFF_BOXOUTS  DEF_BOXOUTS  \
# 889                       3            0            8
# 224                       9            1            6
# 242                       4            4           11
# 787                       3            1            9
# 727                       1            2            9
# ...                     ...          ...          ...
# 2316                      9            3            6
# 3480                      6            4            4
# 2048                     10            1            5
# 3751                      7            1            5
# 3750                      3            0            5
#
#       BOX_OUT_PLAYER_TEAM_REBS  BOX_OUT_PLAYER_REBS  BOX_OUTS SEASON_ID  \
# 889                          4                    1         8   2021-22
# 224                          6                    2         7   2021-22
# 242                         14                    6        15   2021-22
# 787                          8                    3        10   2021-22
# 727                          9                    0        11   2021-22
# ...                        ...                  ...       ...       ...
# 2316                         8                    5         9   2021-22
# 3480                         7                    5         8   2022-23
# 2048                         4                    0         6   2021-22
# 3751                         6                    3         6   2022-23
# 3750                         5                    1         5   2022-23
#
#       GAME_DATE      MATCHUP WL  PLUS_MINUS
# 889  2021-10-29    DAL @ DEN  L       -31.0
# 224  2022-01-25    SAC @ BOS  L       -53.0
# 242  2022-01-08    NYK @ BOS  L       -24.0
# 787  2022-03-09  DAL vs. NYK  L       -30.0
# 727  2021-11-22  CHI vs. IND  L       -32.0
# ...         ...          ... ..         ...
# 2316 2022-02-25    SAS @ WAS  W         4.0
# 3480 2023-04-09    GSW @ POR  W        56.0
# 2048 2022-01-26    CHA @ IND  W        32.0
# 3751 2023-02-24  LAC vs. SAC  L        -1.0
# 3750 2023-02-24    SAC @ LAC  W         1.0
#
# [6366 rows x 26 columns]

# %% [markdown]
# <a name="1.2.-Reshape-to-Game-Matchups"></a>
# ## 1.2. Reshape to Game Matchups
#
# [Return to top](#Feature-Engineering)

# %%
# identify non-stats columns
non_stats_cols = ['SEASON_ID', 'GAME_ID', 'GAME_DATE', 'MATCHUP']

# reshape team box score data to wide format so each row is a game matchup
hustle_stats_matchups_df = utl.reshape_team_bs_to_matchups(hustle_stats_df_cleaned, non_stats_cols)
# Out:
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 728 games

# %%
hustle_stats_matchups_df.head()
# Out:
#     GAME_ID  HOME_TEAM_ID   HOME_TEAM_NAME HOME_TEAM_ABBREVIATION  HOME_MIN  \
# 0  22101221    1610612745  Houston Rockets                    HOU       240
# 1  22101207    1610612748       Miami Heat                    MIA       240
# 2  22101192    1610612737    Atlanta Hawks                    ATL       240
# 3  22101182    1610612761  Toronto Raptors                    TOR       240
# 4  22101163    1610612737    Atlanta Hawks                    ATL       240
#
#    HOME_PTS  HOME_CONTESTED_SHOTS  HOME_CONTESTED_SHOTS_2PT  \
# 0       114                    42                        24
# 1       113                    53                        31
# 2       118                    48                        28
# 3       118                    60                        39
# 4       122                    58                        37
#
#    HOME_CONTESTED_SHOTS_3PT  HOME_DEFLECTIONS  HOME_CHARGES_DRAWN  \
# 0                        18                 3                   0
# 1                        22                17                   0
# 2                        20                14                   0
# 3                        21                 6                   0
# 4                        21                13                   0
#
#    HOME_SCREEN_ASSISTS  HOME_SCREEN_AST_PTS  HOME_OFF_LOOSE_BALLS_RECOVERED  \
# 0                   18                   44                               5
# 1                    9                   21                               3
# 2                   10                   26                               2
# 3                    4                    8                               2
# 4                    6                   13                               2
#
#    HOME_DEF_LOOSE_BALLS_RECOVERED  HOME_LOOSE_BALLS_RECOVERED  \
# 0                               1                           6
# 1                               2                           5
# 2                               1                           3
# 3                               4                           6
# 4                               6                           8
#
#    HOME_OFF_BOXOUTS  HOME_DEF_BOXOUTS  HOME_BOX_OUT_PLAYER_TEAM_REBS  \
# 0                 1                 4                              4
# 1                 0                10                             10
# 2                 3                 7                             10
# 3                 3                11                             13
# 4                 2                 9                             11
#
#    HOME_BOX_OUT_PLAYER_REBS  HOME_BOX_OUTS SEASON_ID  GAME_DATE HOME_WL  \
# 0                         3              5   2021-22 2022-04-10       L
# 1                         2             10   2021-22 2022-04-08       W
# 2                         6             10   2021-22 2022-04-06       W
# 3                         6             14   2021-22 2022-04-05       W
# 4                         7             11   2021-22 2022-04-02       W
#
#    HOME_PLUS_MINUS  AWAY_TEAM_ID      AWAY_TEAM_NAME AWAY_TEAM_ABBREVIATION  \
# 0            -16.0    1610612737       Atlanta Hawks                    ATL
# 1              4.0    1610612737       Atlanta Hawks                    ATL
# 2             15.0    1610612764  Washington Wizards                    WAS
# 3             10.0    1610612737       Atlanta Hawks                    ATL
# 4              7.0    1610612751       Brooklyn Nets                    BKN
#
#    AWAY_MIN  AWAY_PTS  AWAY_CONTESTED_SHOTS  AWAY_CONTESTED_SHOTS_2PT  \
# 0       240       130                    45                        21
# 1       240       109                    40                        25
# 2       240       103                    49                        27
# 3       240       108                    64                        42
# 4       240       115                    51                        28
#
#    AWAY_CONTESTED_SHOTS_3PT  AWAY_DEFLECTIONS  AWAY_CHARGES_DRAWN  \
# 0                        24                12                   0
# 1                        15                19                   1
# 2                        22                 9                   0
# 3                        22                 7                   0
# 4                        23                11                   0
#
#    AWAY_SCREEN_ASSISTS  AWAY_SCREEN_AST_PTS  AWAY_OFF_LOOSE_BALLS_RECOVERED  \
# 0                    4                   10                               0
# 1                    7                   15                               4
# 2                    7                   15                               2
# 3                    7                   16                               3
# 4                   14                   34                               2
#
#    AWAY_DEF_LOOSE_BALLS_RECOVERED  AWAY_LOOSE_BALLS_RECOVERED  \
# 0                               1                           1
# 1                               3                           7
# 2                               2                           4
# 3                               2                           5
# 4                               3                           5
#
#    AWAY_OFF_BOXOUTS  AWAY_DEF_BOXOUTS  AWAY_BOX_OUT_PLAYER_TEAM_REBS  \
# 0                 1                11                              9
# 1                 1                 6                              6
# 2                 2                14                             16
# 3                 0                13                             12
# 4                 3                12                             15
#
#    AWAY_BOX_OUT_PLAYER_REBS  AWAY_BOX_OUTS AWAY_WL  AWAY_PLUS_MINUS
# 0                         3             12       W             16.0
# 1                         4              7       L             -4.0
# 2                        10             16       L            -15.0
# 3                         7             13       L            -10.0
# 4                         5             15       L             -7.0

# %% [markdown]
# <a name="1.3.-Create-Target-Variables"></a>
# ## 1.3. Create Target Variables
#
# [Return to top](#Feature-Engineering)

# %% [markdown]
# There are three targets of interest:
#
# 1. **Total Game Points (over / under):** This can be calculated as the sum of `HOME_PTS + AWAY_PTS`.
# 2. **Difference in Game Points (plus / minus):** This can be calculated in relation to the home team as the following difference: `HOME_PTS - AWAY_PTS`.
# 3. **Game Winner (moneyline):** This can be defined in relation to the home team using the `HOME_WL` column, where a win for the home team is equal to 1 and a loss for the home team equal to 0. We will create a new column called `GAME_RESULT` for this indicator.

# %%
# create the above three target variables
hustle_stats_matchups_df = utl.create_target_variables(hustle_stats_matchups_df, 'HOME_WL', 'HOME_PTS', 'AWAY_PTS')

# %%
hustle_stats_matchups_df[['GAME_DATE', 'GAME_ID',  'HOME_TEAM_NAME', 'AWAY_TEAM_NAME', 'HOME_PTS', 'AWAY_PTS', 'GAME_RESULT', 'TOTAL_PTS', 'PLUS_MINUS']].tail()
# Out:
#       GAME_DATE   GAME_ID      HOME_TEAM_NAME      AWAY_TEAM_NAME  HOME_PTS  \
# 3166 2023-11-22  22300225   Charlotte Hornets  Washington Wizards       117
# 3167 2023-11-10  22300009  Washington Wizards   Charlotte Hornets       117
# 3168 2023-11-08  22300157   Charlotte Hornets  Washington Wizards       116
# 3169 2024-01-24  22300619     Detroit Pistons   Charlotte Hornets       113
# 3170 2023-10-27  22300077   Charlotte Hornets     Detroit Pistons        99
#
#       AWAY_PTS  GAME_RESULT  TOTAL_PTS  PLUS_MINUS
# 3166       114            1        231         3.0
# 3167       124            0        241        -7.0
# 3168       132            0        248       -16.0
# 3169       106            1        219         7.0
# 3170       111            0        210       -12.0

# %% [markdown]
# <a name="2.-Create-Rolling-Window-Statistics"></a>
# # 2. Create Rolling Window Statistics
#
# [Return to top](#Feature-Engineering)

# %% [markdown]
# Here we create average box scores for each team over a rolling window of the previous $n$-games.

# %%
# identify stats columns
non_stats_cols = ['SEASON_ID', 'GAME_ID', 'GAME_DATE', 'HOME_TEAM_ID', 'AWAY_TEAM_ID',
                  'HOME_TEAM_NAME', 'AWAY_TEAM_NAME', 'HOME_WL', 'AWAY_WL', 'HOME_MIN', 
                  'AWAY_MIN', 'HOME_TEAM_ABBREVIATION', 'AWAY_TEAM_ABBREVIATION']
stats_cols = [col for col in hustle_stats_matchups_df.columns if col not in non_stats_cols]

# %%
# calculate rolling averages for each statistic and add them to the DataFrame
hustle_stats_matchups_roll_df = utl.process_rolling_stats(
    hustle_stats_matchups_df, 
    stats_cols, 
    target_cols=['GAME_RESULT', 'TOTAL_PTS', 'PLUS_MINUS'],
    window_size=5,   # the number of games to include in the rolling window
    min_obs=1,       # the minimum number of observations present within the window to yield an aggregate value
    stratify_by_season=True,  # should the rolling calculations be reset at the start of each new season or be contiguous across seasons? 
    exclude_initial_games=0   # number of initial games to exclude from the rolling averages (optionally by season)
)

# %%
hustle_stats_matchups_roll_df.tail()
# Out:
#        GAME_ID  GAME_RESULT  TOTAL_PTS  PLUS_MINUS      HOME_TEAM_NAME  \
# 2540  22300703            0        218       -16.0   San Antonio Spurs
# 3077  22300705            0        252       -28.0  Washington Wizards
# 3017  22300704            0        210       -12.0     Detroit Pistons
# 3036  22300707            0        214       -18.6   Charlotte Hornets
# 2492  22300706            1        222        40.0      Boston Celtics
#
#      SEASON_ID  GAME_DATE  ROLL_HOME_PTS  ROLL_HOME_CONTESTED_SHOTS  \
# 2540   2023-24 2024-02-03         114.60                      43.65
# 3077   2023-24 2024-02-04         115.10                      44.00
# 3017   2023-24 2024-02-04         113.05                      52.45
# 3036   2023-24 2024-02-04         107.55                      46.25
# 2492   2023-24 2024-02-04         121.05                      47.15
#
#       ROLL_HOME_CONTESTED_SHOTS_2PT  ROLL_HOME_CONTESTED_SHOTS_3PT  \
# 2540                          28.85                          14.80
# 3077                          29.05                          14.95
# 3017                          33.70                          18.75
# 3036                          27.20                          19.05
# 2492                          30.10                          17.05
#
#       ROLL_HOME_DEFLECTIONS  ROLL_HOME_CHARGES_DRAWN  \
# 2540                  13.95                     0.30
# 3077                  12.95                     0.40
# 3017                  11.85                     0.10
# 3036                  12.10                     0.75
# 2492                  14.10                     0.45
#
#       ROLL_HOME_SCREEN_ASSISTS  ROLL_HOME_SCREEN_AST_PTS  \
# 2540                      7.30                     16.65
# 3077                      9.65                     21.70
# 3017                      9.80                     22.05
# 3036                      9.65                     22.00
# 2492                      8.30                     20.40
#
#       ROLL_HOME_OFF_LOOSE_BALLS_RECOVERED  \
# 2540                                 2.85
# 3077                                 2.40
# 3017                                 3.50
# 3036                                 2.35
# 2492                                 2.70
#
#       ROLL_HOME_DEF_LOOSE_BALLS_RECOVERED  ROLL_HOME_LOOSE_BALLS_RECOVERED  \
# 2540                                 2.60                             5.45
# 3077                                 2.75                             5.15
# 3017                                 2.60                             6.10
# 3036                                 2.40                             4.75
# 2492                                 2.80                             5.50
#
#       ROLL_HOME_OFF_BOXOUTS  ROLL_HOME_DEF_BOXOUTS  \
# 2540                   1.15                   4.10
# 3077                   1.05                   5.80
# 3017                   1.85                   5.80
# 3036                   1.75                   5.45
# 2492                   1.40                   6.90
#
#       ROLL_HOME_BOX_OUT_PLAYER_TEAM_REBS  ROLL_HOME_BOX_OUT_PLAYER_REBS  \
# 2540                                5.10                           2.20
# 3077                                6.45                           2.95
# 3017                                7.55                           4.10
# 3036                                6.95                           3.35
# 2492                                8.00                           4.05
#
#       ROLL_HOME_BOX_OUTS       AWAY_TEAM_NAME  ROLL_AWAY_PTS  \
# 2540                5.25  Cleveland Cavaliers         112.80
# 3077                6.85         Phoenix Suns         119.85
# 3017                7.65        Orlando Magic         111.70
# 3036                7.20       Indiana Pacers         121.90
# 2492                8.30    Memphis Grizzlies         110.10
#
#       ROLL_AWAY_CONTESTED_SHOTS  ROLL_AWAY_CONTESTED_SHOTS_2PT  \
# 2540                      43.65                          26.80
# 3077                      42.35                          27.75
# 3017                      40.00                          23.70
# 3036                      46.70                          30.45
# 2492                      44.60                          28.40
#
#       ROLL_AWAY_CONTESTED_SHOTS_3PT  ROLL_AWAY_DEFLECTIONS  \
# 2540                          16.85                   14.2
# 3077                          14.60                   14.5
# 3017                          16.30                   14.9
# 3036                          16.25                   13.9
# 2492                          16.20                   13.7
#
#       ROLL_AWAY_CHARGES_DRAWN  ROLL_AWAY_SCREEN_ASSISTS  \
# 2540                     0.50                     10.10
# 3077                     0.25                     10.60
# 3017                     0.55                      8.55
# 3036                     0.35                      7.75
# 2492                     0.70                      7.50
#
#       ROLL_AWAY_SCREEN_AST_PTS  ROLL_AWAY_OFF_LOOSE_BALLS_RECOVERED  \
# 2540                     23.40                                 2.45
# 3077                     23.45                                 3.45
# 3017                     18.70                                 2.30
# 3036                     16.60                                 2.70
# 2492                     17.25                                 2.65
#
#       ROLL_AWAY_DEF_LOOSE_BALLS_RECOVERED  ROLL_AWAY_LOOSE_BALLS_RECOVERED  \
# 2540                                 2.65                             5.10
# 3077                                 3.50                             6.95
# 3017                                 2.90                             5.20
# 3036                                 3.00                             5.70
# 2492                                 2.85                             5.50
#
#       ROLL_AWAY_OFF_BOXOUTS  ROLL_AWAY_DEF_BOXOUTS  \
# 2540                   1.15                   7.40
# 3077                   1.45                   5.95
# 3017                   2.30                   5.35
# 3036                   1.75                   4.80
# 2492                   1.05                   4.60
#
#       ROLL_AWAY_BOX_OUT_PLAYER_TEAM_REBS  ROLL_AWAY_BOX_OUT_PLAYER_REBS  \
# 2540                                8.30                           3.85
# 3077                                6.80                           3.35
# 3017                                7.30                           3.25
# 3036                                6.10                           3.40
# 2492                                5.55                           2.75
#
#       ROLL_AWAY_BOX_OUTS
# 2540                8.55
# 3077                7.40
# 3017                7.65
# 3036                6.55
# 2492                5.65

# %%
# write out the matchups with rolling features
hustle_stats_matchups_roll_df.to_csv('../../data/processed/nba_team_matchups_rolling_hustle_stats_2021_2024_r05.csv', index=False)
