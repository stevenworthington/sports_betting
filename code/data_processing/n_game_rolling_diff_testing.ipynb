# %% [markdown]
# <div class="alert alert-danger">
#     <h4 style="font-weight: bold; font-size: 28px;">Feature Engineering</h4>
#     <p style="font-size: 20px;">NBA API Data (2022-2024)</p>
# </div>
#
# <a name="Feature Engineering"></a>

# %% [markdown]
# # Table of Contents

# %% [markdown]
# [Setup](#Setup)
#
# [Data](#Data)
#
# **[1. Create Team Matchups and Targets](#1.-Create-Team-Matchups-and-Targets)**
#
# - [1.1. Clean Game Data](#1.1.-Clean-Game-Data)
#
# - [1.2. Reshape to Game Matchups](#1.2.-Reshape-to-Game-Matchups)
#
# - [1.3. Create Target Variables](#1.3.-Create-Target-Variables)
#
# **[2. Step by Step for Rolling Difference Calculation](#2.Create-Rolling-Difference-Window-Statistics)**

# %% [markdown]
# # Setup
#
# [Return to top](#Feature-Engineering)

# %%
import sys
from pathlib import Path
# get current working directory
cwd = %pwd
# add shared_code directory to Python sys.path
sys.path.append(str(Path(cwd).parent / "shared_code"))
# import all libraries in shared_code directory 'imports.py' file
from imports import *
# %matplotlib inline
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# # Raw Data
#
# [Return to top](#Feature-Engineering)

# %%
team_bs_df = pd.read_csv('../../data/original/nba_games_box_scores_2022_2024.csv')

# %%
team_bs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7525 entries, 0 to 7524
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SEASON_ID          7525 non-null   int64
#  1   TEAM_ID            7525 non-null   int64
#  2   TEAM_ABBREVIATION  7525 non-null   object
#  3   TEAM_NAME          7525 non-null   object
#  4   GAME_ID            7525 non-null   int64
#  5   GAME_DATE          7525 non-null   object
#  6   MATCHUP            7525 non-null   object
#  7   WL                 7514 non-null   object
#  8   MIN                7525 non-null   int64
#  9   PTS                7525 non-null   int64
#  10  FGM                7525 non-null   int64
#  11  FGA                7525 non-null   int64
#  12  FG_PCT             7523 non-null   float64
#  13  FG3M               7525 non-null   int64
#  14  FG3A               7525 non-null   float64
#  15  FG3_PCT            7523 non-null   float64
#  16  FTM                7525 non-null   int64
#  17  FTA                7525 non-null   int64
#  18  FT_PCT             7521 non-null   float64
#  19  OREB               7525 non-null   float64
#  20  DREB               7525 non-null   float64
#  21  REB                7525 non-null   float64
#  22  AST                7525 non-null   int64
#  23  STL                7525 non-null   float64
#  24  BLK                7525 non-null   int64
#  25  TOV                7525 non-null   int64
#  26  PF                 7525 non-null   int64
#  27  PLUS_MINUS         7525 non-null   float64
# dtypes: float64(9), int64(14), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# <a name="1.-Create-Team-Matchups-and-Targets"></a>
# # 1. Create Team Matchups and Targets
#
# [Return to top](#Feature-Engineering)

# %% [markdown]
# <a name="1.1.-Clean-Game-Data"></a>
# ## 1.1. Clean Game Data
#
# [Return to top](#Feature-Engineering)

# %% [markdown]
# We need to do three key things to clean the data:
#
# 1. Remove games with team aggregated game times of less than 238 minutes (which will remove exhibition matches).
# 2. Retain only games that are part of the regular season.
# 3. Remove any orphans (i.e., game IDs that do not have a partner) when reshaping to matchups.

# %% [markdown]
# Last 3 NBA regular seasons start and end dates:
#
# - 2021-22 season: 2021-10-19 to 2022-04-10
# - 2022-23 season: 2022-10-18 to 2023-04-09
# - 2023-24 season: 2023-10-24 to 2024-04-14

# %%
# last 3 seasons start and end dates and labels
season_start_dates = ['2021-10-19', '2022-10-18', '2023-10-24']
season_end_dates   = ['2022-04-10', '2023-04-09', '2024-04-14']
season_labels      = ['2021-22', '2022-23', '2023-24']

# %%
# clean up the data
team_bs_df_cleaned = utl.clean_team_bs_data(team_bs_df, season_start_dates=season_start_dates, 
                                            season_end_dates=season_end_dates, season_labels=season_labels)
# Out:
# Season 2021-22: 1230 games
# Season 2022-23: 1230 games
# Season 2023-24: 736 games

# %% [markdown]
# <a name="1.2.-Reshape-to-Game-Matchups"></a>
# ## 1.2. Reshape to Game Matchups
#
# [Return to top](#Feature-Engineering)

# %%
# identify non-stats columns
non_stats_cols = ['SEASON_ID', 'GAME_ID', 'GAME_DATE', 'MATCHUP']

# reshape team box score data to wide format so each row is a game matchup
team_bs_matchups_df = utl.reshape_team_bs_to_matchups(team_bs_df_cleaned, non_stats_cols)
# Out:
# Season 2021-22: 1222 games
# Season 2022-23: 1221 games
# Season 2023-24: 729 games

# %%
team_bs_matchups_df.head()
# Out:
#   SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION HOME_TEAM_NAME   GAME_ID  \
# 0   2021-22    1610612737                    ATL  Atlanta Hawks  22100014
# 1   2021-22    1610612737                    ATL  Atlanta Hawks  22100043
# 2   2021-22    1610612737                    ATL  Atlanta Hawks  22100097
# 3   2021-22    1610612737                    ATL  Atlanta Hawks  22100120
# 4   2021-22    1610612737                    ATL  Atlanta Hawks  22100193
#
#    GAME_DATE HOME_WL  HOME_MIN  HOME_PTS  HOME_FGM  HOME_FGA  HOME_FG_PCT  \
# 0 2021-10-21       W       242       113        45        94        0.479
# 1 2021-10-25       W       238       122        46        90        0.511
# 2 2021-11-01       W       240       118        38        83        0.458
# 3 2021-11-04       L       240        98        35        82        0.427
# 4 2021-11-14       W       241       120        47        97        0.485
#
#    HOME_FG3M  HOME_FG3A  HOME_FG3_PCT  HOME_FTM  HOME_FTA  HOME_FT_PCT  \
# 0         15       35.0         0.429         8         9        0.889
# 1         12       32.0         0.375        18        21        0.857
# 2         13       34.0         0.382        29        29        1.000
# 3          7       28.0         0.250        21        26        0.808
# 4         15       35.0         0.429        11        13        0.846
#
#    HOME_OREB  HOME_DREB  HOME_REB  HOME_AST  HOME_STL  HOME_BLK  HOME_TOV  \
# 0        6.0       49.0      55.0        31       8.0         9        13
# 1       10.0       39.0      49.0        24      11.0         3        13
# 2       13.0       34.0      47.0        24       9.0         5        11
# 3        5.0       27.0      32.0        18      11.0         4         9
# 4       15.0       36.0      51.0        21       6.0         1        12
#
#    ...  HOME_PLUS_MINUS  AWAY_TEAM_ID  AWAY_TEAM_ABBREVIATION  \
# 0  ...             26.0    1610612742                     DAL
# 1  ...             18.0    1610612765                     DET
# 2  ...              7.0    1610612764                     WAS
# 3  ...            -18.0    1610612762                     UTA
# 4  ...             20.0    1610612749                     MIL
#
#        AWAY_TEAM_NAME AWAY_WL AWAY_MIN  AWAY_PTS  AWAY_FGM  AWAY_FGA  \
# 0    Dallas Mavericks       L      240        87        31        93
# 1     Detroit Pistons       L      239       104        40        91
# 2  Washington Wizards       L      240       111        41        86
# 3           Utah Jazz       W      240       116        41        81
# 4     Milwaukee Bucks       L      240       100        38        84
#
#    AWAY_FG_PCT  AWAY_FG3M  AWAY_FG3A  AWAY_FG3_PCT  AWAY_FTM  AWAY_FTA  \
# 0        0.333         13       43.0         0.302        12        13
# 1        0.440          9       33.0         0.273        15        18
# 2        0.477         13       39.0         0.333        16        16
# 3        0.506         17       41.0         0.415        17        23
# 4        0.452         14       41.0         0.341        10        16
#
#    AWAY_FT_PCT  AWAY_OREB  AWAY_DREB  AWAY_REB  AWAY_AST  AWAY_STL  AWAY_BLK  \
# 0        0.923       10.0       40.0      50.0        16       7.0         3
# 1        0.833       11.0       25.0      36.0        26       7.0         6
# 2        1.000        7.0       29.0      36.0        27       7.0         4
# 3        0.739        8.0       38.0      46.0        30       6.0         4
# 4        0.625        4.0       26.0      30.0        24       8.0         3
#
#    AWAY_TOV  AWAY_PF  AWAY_PLUS_MINUS
# 0        15       21            -26.0
# 1        14       15            -18.0
# 2        12       24             -7.0
# 3        14       20             18.0
# 4        11       17            -20.0
#
# [5 rows x 51 columns]

# %% [markdown]
# <a name="1.3.-Create-Target-Variables"></a>
# ## 1.3. Create Target Variables
#
# [Return to top](#Feature-Engineering)

# %% [markdown]
# There are three targets of interest:
#
# 1. **Total Game Points (over / under):** This can be calculated as the sum of `HOME_PTS + AWAY_PTS`.
# 2. **Difference in Game Points (plus / minus):** This can be calculated in relation to the home team as the following difference: `HOME_PTS - AWAY_PTS`.
# 3. **Game Winner (moneyline):** This can be defined in relation to the home team using the `HOME_WL` column, where a win for the home team is equal to 1 and a loss for the home team equal to 0. We will create a new column called `GAME_RESULT` for this indicator.

# %%
# create the above three target variables
team_bs_matchups_df = utl.create_target_variables(team_bs_matchups_df, 'HOME_WL', 'HOME_PTS', 'AWAY_PTS')

# %%
team_bs_matchups_df[['GAME_DATE', 'GAME_ID',  'HOME_TEAM_NAME', 'AWAY_TEAM_NAME', 'HOME_PTS', 'AWAY_PTS', 'GAME_RESULT', 'TOTAL_PTS', 'PLUS_MINUS']].tail()
# Out:
#       GAME_DATE   GAME_ID      HOME_TEAM_NAME          AWAY_TEAM_NAME  \
# 3167 2024-01-24  22300620  Washington Wizards  Minnesota Timberwolves
# 3168 2024-01-25  22300628  Washington Wizards               Utah Jazz
# 3169 2024-01-31  22300676  Washington Wizards             LA Clippers
# 3170 2024-02-02  22300689  Washington Wizards              Miami Heat
# 3171 2024-02-04  22300705  Washington Wizards            Phoenix Suns
#
#       HOME_PTS  AWAY_PTS  GAME_RESULT  TOTAL_PTS  PLUS_MINUS
# 3167       107       118            0        225       -11.0
# 3168       108       123            0        231       -15.0
# 3169       109       125            0        234       -16.0
# 3170       102       110            0        212        -8.0
# 3171       112       140            0        252       -28.0

# %% [markdown]
# <a name="2.Create-Rolling-Difference-Window-Statistics"></a>
# # 2. Step by Step Calculations for Rolling Difference (Average Over/Under Performance)
#
# [Return to top](#Feature-Engineering)

# %% [markdown]
# Here we create the average difference in box scores between teams over a rolling window of the previous $n$-games.

# %%
team_bs_matchups_df.shape
# Out:
# (3172, 52)

# %%
# declare variables
team_col = "HOME_TEAM_NAME"
stratify_by_season = True

# %%
# determine whether to use 'HOME' or 'AWAY' stats
prefix = 'HOME_' if 'HOME' in team_col else 'AWAY_'
prefix
# Out:
# 'HOME_'

# %%
# identify stats columns
non_stats_cols = ['SEASON_ID', 'GAME_ID', 'GAME_DATE', 'HOME_TEAM_ID', 'AWAY_TEAM_ID',
                  'HOME_TEAM_NAME', 'AWAY_TEAM_NAME', 'HOME_WL', 'AWAY_WL', 'HOME_MIN', 
                  'AWAY_MIN', 'HOME_TEAM_ABBREVIATION', 'AWAY_TEAM_ABBREVIATION']
stats_cols = [col for col in team_bs_matchups_df.columns if col not in non_stats_cols]

# %%
# Filter the stats columns 
# We will have three stats columns lists: prefix with only HOME_, prefix with only AWAY_, and both HOME_ and AWAY stats 
# We require all lists for filtering the df columns later for taking the difference 
filtered_stats_cols_home = [col for col in stats_cols if col.startswith('HOME_')]
print(filtered_stats_cols_home)    

filtered_stats_cols_away = [col for col in stats_cols if col.startswith('AWAY_')]
print(filtered_stats_cols_away)    

filtered_stats_cols_both = [col for col in stats_cols if col.startswith('HOME_') or col.startswith('AWAY_')]
print(filtered_stats_cols_both)
# Out:
# ['HOME_PTS', 'HOME_FGM', 'HOME_FGA', 'HOME_FG_PCT', 'HOME_FG3M', 'HOME_FG3A', 'HOME_FG3_PCT', 'HOME_FTM', 'HOME_FTA', 'HOME_FT_PCT', 'HOME_OREB', 'HOME_DREB', 'HOME_REB', 'HOME_AST', 'HOME_STL', 'HOME_BLK', 'HOME_TOV', 'HOME_PF']
# ['AWAY_PTS', 'AWAY_FGM', 'AWAY_FGA', 'AWAY_FG_PCT', 'AWAY_FG3M', 'AWAY_FG3A', 'AWAY_FG3_PCT', 'AWAY_FTM', 'AWAY_FTA', 'AWAY_FT_PCT', 'AWAY_OREB', 'AWAY_DREB', 'AWAY_REB', 'AWAY_AST', 'AWAY_STL', 'AWAY_BLK', 'AWAY_TOV', 'AWAY_PF']
# ['HOME_PTS', 'HOME_FGM', 'HOME_FGA', 'HOME_FG_PCT', 'HOME_FG3M', 'HOME_FG3A', 'HOME_FG3_PCT', 'HOME_FTM', 'HOME_FTA', 'HOME_FT_PCT', 'HOME_OREB', 'HOME_DREB', 'HOME_REB', 'HOME_AST', 'HOME_STL', 'HOME_BLK', 'HOME_TOV', 'HOME_PF', 'AWAY_PTS', 'AWAY_FGM', 'AWAY_FGA', 'AWAY_FG_PCT', 'AWAY_FG3M', 'AWAY_FG3A', 'AWAY_FG3_PCT', 'AWAY_FTM', 'AWAY_FTA', 'AWAY_FT_PCT', 'AWAY_OREB', 'AWAY_DREB', 'AWAY_REB', 'AWAY_AST', 'AWAY_STL', 'AWAY_BLK', 'AWAY_TOV', 'AWAY_PF']

# %%
# ensure data is sorted by team, season (if stratified), and date for accurate rolling calculation
# set GAME_ID and GAME_DATE as the indices to preserve them through the rolling operation
sort_cols = [team_col, 'SEASON_ID', 'GAME_DATE'] if stratify_by_season else [team_col, 'GAME_DATE']
sort_cols
# Out:
# ['HOME_TEAM_NAME', 'SEASON_ID', 'GAME_DATE']

# %%
df_sorted = team_bs_matchups_df.sort_values(by=sort_cols).set_index(['GAME_ID', 'GAME_DATE'])
df_sorted.shape
# Out:
# (3172, 50)

# %%
df_sorted.head(10)
# Out:
#                     SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21   2021-22    1610612737                    ATL
# 22100043 2021-10-25   2021-22    1610612737                    ATL
# 22100097 2021-11-01   2021-22    1610612737                    ATL
# 22100120 2021-11-04   2021-22    1610612737                    ATL
# 22100193 2021-11-14   2021-22    1610612737                    ATL
# 22100202 2021-11-15   2021-22    1610612737                    ATL
# 22100215 2021-11-17   2021-22    1610612737                    ATL
# 22100242 2021-11-20   2021-22    1610612737                    ATL
# 22100255 2021-11-22   2021-22    1610612737                    ATL
# 22100293 2021-11-27   2021-22    1610612737                    ATL
#
#                     HOME_TEAM_NAME HOME_WL  HOME_MIN  HOME_PTS  HOME_FGM  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21  Atlanta Hawks       W       242       113        45
# 22100043 2021-10-25  Atlanta Hawks       W       238       122        46
# 22100097 2021-11-01  Atlanta Hawks       W       240       118        38
# 22100120 2021-11-04  Atlanta Hawks       L       240        98        35
# 22100193 2021-11-14  Atlanta Hawks       W       241       120        47
# 22100202 2021-11-15  Atlanta Hawks       W       239       129        47
# 22100215 2021-11-17  Atlanta Hawks       W       240       110        41
# 22100242 2021-11-20  Atlanta Hawks       W       241       115        43
# 22100255 2021-11-22  Atlanta Hawks       W       239       113        42
# 22100293 2021-11-27  Atlanta Hawks       L       240        90        33
#
#                      HOME_FGA  HOME_FG_PCT  HOME_FG3M  HOME_FG3A  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21        94        0.479         15       35.0
# 22100043 2021-10-25        90        0.511         12       32.0
# 22100097 2021-11-01        83        0.458         13       34.0
# 22100120 2021-11-04        82        0.427          7       28.0
# 22100193 2021-11-14        97        0.485         15       35.0
# 22100202 2021-11-15        85        0.553         14       30.0
# 22100215 2021-11-17        81        0.506         13       37.0
# 22100242 2021-11-20        82        0.524         12       34.0
# 22100255 2021-11-22        87        0.483         14       34.0
# 22100293 2021-11-27        93        0.355          9       37.0
#
#                      HOME_FG3_PCT  HOME_FTM  HOME_FTA  HOME_FT_PCT  HOME_OREB  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21         0.429         8         9        0.889        6.0
# 22100043 2021-10-25         0.375        18        21        0.857       10.0
# 22100097 2021-11-01         0.382        29        29        1.000       13.0
# 22100120 2021-11-04         0.250        21        26        0.808        5.0
# 22100193 2021-11-14         0.429        11        13        0.846       15.0
# 22100202 2021-11-15         0.467        21        32        0.656        9.0
# 22100215 2021-11-17         0.351        15        18        0.833        6.0
# 22100242 2021-11-20         0.353        17        21        0.810        8.0
# 22100255 2021-11-22         0.412        15        16        0.938        8.0
# 22100293 2021-11-27         0.243        15        20        0.750       13.0
#
#                      HOME_DREB  HOME_REB  HOME_AST  HOME_STL  HOME_BLK  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21       49.0      55.0        31       8.0         9
# 22100043 2021-10-25       39.0      49.0        24      11.0         3
# 22100097 2021-11-01       34.0      47.0        24       9.0         5
# 22100120 2021-11-04       27.0      32.0        18      11.0         4
# 22100193 2021-11-14       36.0      51.0        21       6.0         1
# 22100202 2021-11-15       37.0      46.0        32      10.0         7
# 22100215 2021-11-17       34.0      40.0        28       9.0         4
# 22100242 2021-11-20       38.0      46.0        24       6.0         6
# 22100255 2021-11-22       36.0      44.0        25       6.0         6
# 22100293 2021-11-27       39.0      52.0        18       8.0         6
#
#                      HOME_TOV  HOME_PF  PLUS_MINUS  AWAY_TEAM_ID  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21        13       16        26.0    1610612742
# 22100043 2021-10-25        13       19        18.0    1610612765
# 22100097 2021-11-01        11       17         7.0    1610612764
# 22100120 2021-11-04         9       24       -18.0    1610612762
# 22100193 2021-11-14        12       19        20.0    1610612749
# 22100202 2021-11-15        11       17        18.0    1610612753
# 22100215 2021-11-17        11       17        11.0    1610612738
# 22100242 2021-11-20        12       22        10.0    1610612766
# 22100255 2021-11-22         7       16        12.0    1610612760
# 22100293 2021-11-27         6       17        -9.0    1610612752
#
#                     AWAY_TEAM_ABBREVIATION         AWAY_TEAM_NAME AWAY_WL  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21                    DAL       Dallas Mavericks       L
# 22100043 2021-10-25                    DET        Detroit Pistons       L
# 22100097 2021-11-01                    WAS     Washington Wizards       L
# 22100120 2021-11-04                    UTA              Utah Jazz       W
# 22100193 2021-11-14                    MIL        Milwaukee Bucks       L
# 22100202 2021-11-15                    ORL          Orlando Magic       L
# 22100215 2021-11-17                    BOS         Boston Celtics       L
# 22100242 2021-11-20                    CHA      Charlotte Hornets       L
# 22100255 2021-11-22                    OKC  Oklahoma City Thunder       L
# 22100293 2021-11-27                    NYK        New York Knicks       W
#
#                      AWAY_MIN  AWAY_PTS  AWAY_FGM  AWAY_FGA  AWAY_FG_PCT  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21       240        87        31        93        0.333
# 22100043 2021-10-25       239       104        40        91        0.440
# 22100097 2021-11-01       240       111        41        86        0.477
# 22100120 2021-11-04       240       116        41        81        0.506
# 22100193 2021-11-14       240       100        38        84        0.452
# 22100202 2021-11-15       240       111        43        95        0.453
# 22100215 2021-11-17       242        99        37        84        0.440
# 22100242 2021-11-20       240       105        43       102        0.422
# 22100255 2021-11-22       240       101        39        97        0.402
# 22100293 2021-11-27       241        99        36        82        0.439
#
#                      AWAY_FG3M  AWAY_FG3A  AWAY_FG3_PCT  AWAY_FTM  AWAY_FTA  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21         13       43.0         0.302        12        13
# 22100043 2021-10-25          9       33.0         0.273        15        18
# 22100097 2021-11-01         13       39.0         0.333        16        16
# 22100120 2021-11-04         17       41.0         0.415        17        23
# 22100193 2021-11-14         14       41.0         0.341        10        16
# 22100202 2021-11-15         16       43.0         0.372         9        14
# 22100215 2021-11-17         11       41.0         0.268        14        17
# 22100242 2021-11-20         10       40.0         0.250         9        15
# 22100255 2021-11-22         10       38.0         0.263        13        14
# 22100293 2021-11-27         11       29.0         0.379        16        22
#
#                      AWAY_FT_PCT  AWAY_OREB  AWAY_DREB  AWAY_REB  AWAY_AST  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21        0.923       10.0       40.0      50.0        16
# 22100043 2021-10-25        0.833       11.0       25.0      36.0        26
# 22100097 2021-11-01        1.000        7.0       29.0      36.0        27
# 22100120 2021-11-04        0.739        8.0       38.0      46.0        30
# 22100193 2021-11-14        0.625        4.0       26.0      30.0        24
# 22100202 2021-11-15        0.643       12.0       29.0      41.0        30
# 22100215 2021-11-17        0.824       12.0       30.0      42.0        24
# 22100242 2021-11-20        0.600       20.0       31.0      51.0        26
# 22100255 2021-11-22        0.929       16.0       34.0      50.0        24
# 22100293 2021-11-27        0.727        8.0       42.0      50.0        20
#
#                      AWAY_STL  AWAY_BLK  AWAY_TOV  AWAY_PF  GAME_RESULT  \
# GAME_ID  GAME_DATE
# 22100014 2021-10-21       7.0         3        15       21            1
# 22100043 2021-10-25       7.0         6        14       15            1
# 22100097 2021-11-01       7.0         4        12       24            1
# 22100120 2021-11-04       6.0         4        14       20            0
# 22100193 2021-11-14       8.0         3        11       17            1
# 22100202 2021-11-15       8.0         5        16       27            1
# 22100215 2021-11-17       9.0         2        14       17            1
# 22100242 2021-11-20       6.0         2        10       22            1
# 22100255 2021-11-22       5.0         5         8       15            1
# 22100293 2021-11-27       4.0         3        10       17            0
#
#                      TOTAL_PTS
# GAME_ID  GAME_DATE
# 22100014 2021-10-21        200
# 22100043 2021-10-25        226
# 22100097 2021-11-01        229
# 22100120 2021-11-04        214
# 22100193 2021-11-14        220
# 22100202 2021-11-15        240
# 22100215 2021-11-17        209
# 22100242 2021-11-20        220
# 22100255 2021-11-22        214
# 22100293 2021-11-27        189

# %%
# apply grouping for rolling calculation
group_cols = [team_col, 'SEASON_ID'] if stratify_by_season else [team_col]
print(group_cols)

# group by 'group_cols' so that you only have home or away team stats stratified by season
rolling_stats = df_sorted.groupby(group_cols)
# Out:
# ['HOME_TEAM_NAME', 'SEASON_ID']

# %%
## this cell is commented out because its output is extremely long
## the purpose of this cell is to double check grouping and stratification works

## check that grouping works
## df should be grouped by team (HOME or AWAY), and should be stratified by season
#rolling_stats.apply(display)

# %%
# this cell is to double check the work of the bottom cell
# Filter rolling_stats df to only show numerical stats
# Then take the difference between columns
# ie HOME_PTS - AWAY_PTS, and roll the calculation rightward
# Afterwards filter the columns to only display home stats, as the away stats will have become nan 
rolling_stats[filtered_stats_cols_both].diff(axis=1,periods=-18)[filtered_stats_cols_home]
# Out:
#                                                   HOME_PTS  HOME_FGM  \
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21        26        14
#                              22100043 2021-10-25        18         6
#                              22100097 2021-11-01         7        -3
#                              22100120 2021-11-04       -18        -6
#                              22100193 2021-11-14        20         9
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300620 2024-01-24       -11        -5
#                              22300628 2024-01-25       -15        -7
#                              22300676 2024-01-31       -16        -2
#                              22300689 2024-02-02        -8        -1
#                              22300705 2024-02-04       -28        -7
#
#                                                   HOME_FGA  HOME_FG_PCT  \
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21         1        0.146
#                              22100043 2021-10-25        -1        0.071
#                              22100097 2021-11-01        -3       -0.019
#                              22100120 2021-11-04         1       -0.079
#                              22100193 2021-11-14        13        0.033
# ...                                                    ...          ...
# Washington Wizards 2023-24   22300620 2024-01-24       -23        0.061
#                              22300628 2024-01-25        -9       -0.026
#                              22300676 2024-01-31        -3       -0.006
#                              22300689 2024-02-02         2       -0.021
#                              22300705 2024-02-04         8       -0.124
#
#                                                   HOME_FG3M  HOME_FG3A  \
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21          2       -8.0
#                              22100043 2021-10-25          3       -1.0
#                              22100097 2021-11-01          0       -5.0
#                              22100120 2021-11-04        -10      -13.0
#                              22100193 2021-11-14          1       -6.0
# ...                                                     ...        ...
# Washington Wizards 2023-24   22300620 2024-01-24          1       -8.0
#                              22300628 2024-01-25         -6       -1.0
#                              22300676 2024-01-31         -3       -1.0
#                              22300689 2024-02-02          4       11.0
#                              22300705 2024-02-04         -4        7.0
#
#                                                   HOME_FG3_PCT  HOME_FTM  \
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21         0.127        -4
#                              22100043 2021-10-25         0.102         3
#                              22100097 2021-11-01         0.049        13
#                              22100120 2021-11-04        -0.165         4
#                              22100193 2021-11-14         0.088         1
# ...                                                        ...       ...
# Washington Wizards 2023-24   22300620 2024-01-24         0.136        -2
#                              22300628 2024-01-25        -0.186         5
#                              22300676 2024-01-31        -0.090        -9
#                              22300689 2024-02-02         0.036       -10
#                              22300705 2024-02-04        -0.221       -10
#
#                                                   HOME_FTA  HOME_FT_PCT  \
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21        -4       -0.034
#                              22100043 2021-10-25         3        0.024
#                              22100097 2021-11-01        13        0.000
#                              22100120 2021-11-04         3        0.069
#                              22100193 2021-11-14        -3        0.221
# ...                                                    ...          ...
# Washington Wizards 2023-24   22300620 2024-01-24         0       -0.069
#                              22300628 2024-01-25         8       -0.083
#                              22300676 2024-01-31        -7       -0.197
#                              22300689 2024-02-02       -14        0.039
#                              22300705 2024-02-04        -9       -0.161
#
#                                                   HOME_OREB  HOME_DREB  \
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21       -4.0        9.0
#                              22100043 2021-10-25       -1.0       14.0
#                              22100097 2021-11-01        6.0        5.0
#                              22100120 2021-11-04       -3.0      -11.0
#                              22100193 2021-11-14       11.0       10.0
# ...                                                     ...        ...
# Washington Wizards 2023-24   22300620 2024-01-24       -8.0        9.0
#                              22300628 2024-01-25       -8.0       -9.0
#                              22300676 2024-01-31       -6.0       -1.0
#                              22300689 2024-02-02       -8.0       -8.0
#                              22300705 2024-02-04        4.0      -11.0
#
#                                                   HOME_REB  HOME_AST  \
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21       5.0        15
#                              22100043 2021-10-25      13.0        -2
#                              22100097 2021-11-01      11.0        -3
#                              22100120 2021-11-04     -14.0       -12
#                              22100193 2021-11-14      21.0        -3
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300620 2024-01-24       1.0         5
#                              22300628 2024-01-25     -17.0        -1
#                              22300676 2024-01-31      -7.0        -6
#                              22300689 2024-02-02     -16.0         4
#                              22300705 2024-02-04      -7.0        -1
#
#                                                   HOME_STL  HOME_BLK  \
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21       1.0         6
#                              22100043 2021-10-25       4.0        -3
#                              22100097 2021-11-01       2.0         1
#                              22100120 2021-11-04       5.0         0
#                              22100193 2021-11-14      -2.0        -2
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300620 2024-01-24      -6.0        -4
#                              22300628 2024-01-25       5.0         5
#                              22300676 2024-01-31      -5.0         3
#                              22300689 2024-02-02       1.0         3
#                              22300705 2024-02-04      -2.0        -2
#
#                                                   HOME_TOV  HOME_PF
# HOME_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100014 2021-10-21        -2       -5
#                              22100043 2021-10-25        -1        4
#                              22100097 2021-11-01        -1       -7
#                              22100120 2021-11-04        -5        4
#                              22100193 2021-11-14         1        2
# ...                                                    ...      ...
# Washington Wizards 2023-24   22300620 2024-01-24        14        0
#                              22300628 2024-01-25        -4       -5
#                              22300676 2024-01-31         5        3
#                              22300689 2024-02-02        -4        7
#                              22300705 2024-02-04         1        7
#
# [3172 rows x 18 columns]

# %%
# Run full the sorting, difference, and rolling average functions from df_sorted
rolling_diff_stats_home = (df_sorted.groupby(group_cols)[filtered_stats_cols_both]
                                .diff(axis=1,periods=-18)[filtered_stats_cols_home]
                                .rolling(window=5, min_periods=1)
                                .mean()
                                .round(3)
                                .groupby(group_cols) # need to groupby again for shift
                                .shift(1)  # lag to exclude the current game from the rolling average
                                .add_prefix('ROLLDIFF_')
                                .reset_index() # reset the index to convert GAME_ID back into a column
                     )

# check if rolling diff stats has worked
rolling_diff_stats_home
# Out:
#           HOME_TEAM_NAME SEASON_ID   GAME_ID  GAME_DATE  ROLLDIFF_HOME_PTS  \
# 0          Atlanta Hawks   2021-22  22100014 2021-10-21                NaN
# 1          Atlanta Hawks   2021-22  22100043 2021-10-25              26.00
# 2          Atlanta Hawks   2021-22  22100097 2021-11-01              22.00
# 3          Atlanta Hawks   2021-22  22100120 2021-11-04              17.00
# 4          Atlanta Hawks   2021-22  22100193 2021-11-14               8.25
# ...                  ...       ...       ...        ...                ...
# 3167  Washington Wizards   2023-24  22300620 2024-01-24              -9.80
# 3168  Washington Wizards   2023-24  22300628 2024-01-25              -8.80
# 3169  Washington Wizards   2023-24  22300676 2024-01-31             -10.20
# 3170  Washington Wizards   2023-24  22300689 2024-02-02             -11.00
# 3171  Washington Wizards   2023-24  22300705 2024-02-04             -11.80
#
#       ROLLDIFF_HOME_FGM  ROLLDIFF_HOME_FGA  ROLLDIFF_HOME_FG_PCT  \
# 0                   NaN                NaN                   NaN
# 1                14.000                1.0                 0.146
# 2                10.000                0.0                 0.108
# 3                 5.667               -1.0                 0.066
# 4                 2.750               -0.5                 0.030
# ...                 ...                ...                   ...
# 3167             -4.600                2.8                -0.066
# 3168             -5.000               -1.4                -0.049
# 3169             -4.800               -3.4                -0.035
# 3170             -4.000               -5.0                -0.017
# 3171             -3.800               -6.0                -0.010
#
#       ROLLDIFF_HOME_FG3M  ROLLDIFF_HOME_FG3A  ROLLDIFF_HOME_FG3_PCT  \
# 0                    NaN                 NaN                    NaN
# 1                  2.000              -8.000                  0.127
# 2                  2.500              -4.500                  0.114
# 3                  1.667              -4.667                  0.093
# 4                 -1.250              -6.750                  0.028
# ...                  ...                 ...                    ...
# 3167               0.800               3.600                 -0.028
# 3168               1.200               1.800                  0.007
# 3169              -0.200               0.800                 -0.024
# 3170              -2.200              -1.400                 -0.057
# 3171              -0.800               1.200                 -0.034
#
#       ROLLDIFF_HOME_FTM  ROLLDIFF_HOME_FTA  ROLLDIFF_HOME_FT_PCT  \
# 0                   NaN                NaN                   NaN
# 1                  -4.0              -4.00                -0.034
# 2                  -0.5              -0.50                -0.005
# 3                   4.0               4.00                -0.003
# 4                   4.0               3.75                 0.015
# ...                 ...                ...                   ...
# 3167               -1.4              -3.40                 0.055
# 3168                0.0              -2.60                 0.097
# 3169               -0.4              -2.00                 0.058
# 3170               -0.8              -1.00                -0.016
# 3171               -3.4              -3.80                -0.034
#
#       ROLLDIFF_HOME_OREB  ROLLDIFF_HOME_DREB  ROLLDIFF_HOME_REB  \
# 0                    NaN                 NaN                NaN
# 1                 -4.000               9.000              5.000
# 2                 -2.500              11.500              9.000
# 3                  0.333               9.333              9.667
# 4                 -0.500               4.250              3.750
# ...                  ...                 ...                ...
# 3167              -0.400              -6.400             -6.800
# 3168              -2.200              -4.400             -6.600
# 3169              -4.200              -5.400             -9.600
# 3170              -4.600              -2.600             -7.200
# 3171              -6.200              -3.600             -9.800
#
#       ROLLDIFF_HOME_AST  ROLLDIFF_HOME_STL  ROLLDIFF_HOME_BLK  \
# 0                   NaN                NaN                NaN
# 1                15.000              1.000              6.000
# 2                 6.500              2.500              1.500
# 3                 3.333              2.333              1.333
# 4                -0.500              3.000              1.000
# ...                 ...                ...                ...
# 3167             -1.400             -0.600             -2.400
# 3168             -1.600             -1.000             -3.400
# 3169             -0.800              0.800             -2.000
# 3170             -2.000             -1.000             -0.800
# 3171              0.800             -1.600              1.000
#
#       ROLLDIFF_HOME_TOV  ROLLDIFF_HOME_PF
# 0                   NaN               NaN
# 1                -2.000            -5.000
# 2                -1.500            -0.500
# 3                -1.333            -2.667
# 4                -2.250            -1.000
# ...                 ...               ...
# 3167             -1.400             4.200
# 3168              0.200             3.400
# 3169             -0.600             2.000
# 3170              1.800             1.400
# 3171              2.200             2.400
#
# [3172 rows x 22 columns]

# %% [markdown]
# ## Check to see if AWAY works

# %%
# Check to see it works for away
# declared variables
team_col = "AWAY_TEAM_NAME"
stratify_by_season = True

# determine whether to use 'HOME' or 'AWAY' stats
prefix = 'HOME_' if 'HOME' in team_col else 'AWAY_'
prefix
# Out:
# 'AWAY_'

# %%
# ensure data is sorted by team, season (if stratified), and date for accurate rolling calculation
# set GAME_ID and GAME_DATE as the indices to preserve them through the rolling operation
sort_cols = [team_col, 'SEASON_ID', 'GAME_DATE'] if stratify_by_season else [team_col, 'GAME_DATE']
sort_cols
# Out:
# ['AWAY_TEAM_NAME', 'SEASON_ID', 'GAME_DATE']

# %%
df_sorted = team_bs_matchups_df.sort_values(by=sort_cols).set_index(['GAME_ID', 'GAME_DATE'])
df_sorted.shape
# Out:
# (3172, 50)

# %%
df_sorted.head(10)
# Out:
#                     SEASON_ID  HOME_TEAM_ID HOME_TEAM_ABBREVIATION  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23   2021-22    1610612739                    CLE
# 22100059 2021-10-27   2021-22    1610612740                    NOP
# 22100066 2021-10-28   2021-22    1610612764                    WAS
# 22100082 2021-10-30   2021-22    1610612755                    PHI
# 22100113 2021-11-03   2021-22    1610612751                    BKN
# 22100137 2021-11-06   2021-22    1610612756                    PHX
# 22100152 2021-11-08   2021-22    1610612744                    GSW
# 22100156 2021-11-09   2021-22    1610612762                    UTA
# 22100182 2021-11-12   2021-22    1610612743                    DEN
# 22100277 2021-11-24   2021-22    1610612759                    SAS
#
#                             HOME_TEAM_NAME HOME_WL  HOME_MIN  HOME_PTS  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23    Cleveland Cavaliers       W       242       101
# 22100059 2021-10-27   New Orleans Pelicans       L       240        99
# 22100066 2021-10-28     Washington Wizards       W       240       122
# 22100082 2021-10-30     Philadelphia 76ers       W       241       122
# 22100113 2021-11-03          Brooklyn Nets       W       240       117
# 22100137 2021-11-06           Phoenix Suns       W       240       121
# 22100152 2021-11-08  Golden State Warriors       W       241       127
# 22100156 2021-11-09              Utah Jazz       W       240       110
# 22100182 2021-11-12         Denver Nuggets       W       240       105
# 22100277 2021-11-24      San Antonio Spurs       L       240       106
#
#                      HOME_FGM  HOME_FGA  HOME_FG_PCT  HOME_FG3M  HOME_FG3A  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23        37        89        0.416          7       28.0
# 22100059 2021-10-27        40        93        0.430         11       36.0
# 22100066 2021-10-28        46        99        0.465         13       34.0
# 22100082 2021-10-30        46        86        0.535         12       38.0
# 22100113 2021-11-03        43        88        0.489         22       48.0
# 22100137 2021-11-06        45        88        0.511         14       43.0
# 22100152 2021-11-08        44        92        0.478         18       44.0
# 22100156 2021-11-09        41        81        0.506         15       38.0
# 22100182 2021-11-12        40        90        0.444         10       35.0
# 22100277 2021-11-24        43       100        0.430         12       33.0
#
#                      HOME_FG3_PCT  HOME_FTM  HOME_FTA  HOME_FT_PCT  HOME_OREB  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23         0.250        20        27        0.741       12.0
# 22100059 2021-10-27         0.306         8         9        0.889        9.0
# 22100066 2021-10-28         0.382        17        21        0.810       14.0
# 22100082 2021-10-30         0.316        18        19        0.947        5.0
# 22100113 2021-11-03         0.458         9        12        0.750        7.0
# 22100137 2021-11-06         0.326        17        21        0.810        5.0
# 22100152 2021-11-08         0.409        21        22        0.955       10.0
# 22100156 2021-11-09         0.395        13        16        0.813        8.0
# 22100182 2021-11-12         0.286        15        20        0.750       10.0
# 22100277 2021-11-24         0.364         8        10        0.800       15.0
#
#                      HOME_DREB  HOME_REB  HOME_AST  HOME_STL  HOME_BLK  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23       42.0      54.0        23       6.0         6
# 22100059 2021-10-27       35.0      44.0        24       5.0         6
# 22100066 2021-10-28       37.0      51.0        26       6.0         4
# 22100082 2021-10-30       32.0      37.0        24      11.0         6
# 22100113 2021-11-03       35.0      42.0        34       7.0         8
# 22100137 2021-11-06       37.0      42.0        26       8.0         6
# 22100152 2021-11-08       29.0      39.0        31      13.0         4
# 22100156 2021-11-09       36.0      44.0        21       8.0         4
# 22100182 2021-11-12       39.0      49.0        26       6.0         5
# 22100277 2021-11-24       29.0      44.0        27       8.0         4
#
#                      HOME_TOV  HOME_PF  PLUS_MINUS  AWAY_TEAM_ID  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23        10       16         6.0    1610612737
# 22100059 2021-10-27         9       19        -3.0    1610612737
# 22100066 2021-10-28         6       16        11.0    1610612737
# 22100082 2021-10-30        12       24        28.0    1610612737
# 22100113 2021-11-03        14       18         9.0    1610612737
# 22100137 2021-11-06        12       22         4.0    1610612737
# 22100152 2021-11-08        13       22        14.0    1610612737
# 22100156 2021-11-09        14       20        12.0    1610612737
# 22100182 2021-11-12         7       21         9.0    1610612737
# 22100277 2021-11-24        12       16       -18.0    1610612737
#
#                     AWAY_TEAM_ABBREVIATION AWAY_TEAM_NAME AWAY_WL  AWAY_MIN  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23                    ATL  Atlanta Hawks       L       241
# 22100059 2021-10-27                    ATL  Atlanta Hawks       W       240
# 22100066 2021-10-28                    ATL  Atlanta Hawks       L       241
# 22100082 2021-10-30                    ATL  Atlanta Hawks       L       239
# 22100113 2021-11-03                    ATL  Atlanta Hawks       L       241
# 22100137 2021-11-06                    ATL  Atlanta Hawks       L       240
# 22100152 2021-11-08                    ATL  Atlanta Hawks       L       239
# 22100156 2021-11-09                    ATL  Atlanta Hawks       L       240
# 22100182 2021-11-12                    ATL  Atlanta Hawks       L       238
# 22100277 2021-11-24                    ATL  Atlanta Hawks       W       239
#
#                      AWAY_PTS  AWAY_FGM  AWAY_FGA  AWAY_FG_PCT  AWAY_FG3M  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23        95        38        99        0.384         10
# 22100059 2021-10-27       102        40        96        0.417          8
# 22100066 2021-10-28       111        48        88        0.545          6
# 22100082 2021-10-30        94        36        95        0.379          8
# 22100113 2021-11-03       108        41        94        0.436         13
# 22100137 2021-11-06       117        42        97        0.433         13
# 22100152 2021-11-08       113        38        82        0.463         17
# 22100156 2021-11-09        98        37        85        0.435         18
# 22100182 2021-11-12        96        38        93        0.409          5
# 22100277 2021-11-24       124        45        88        0.511         12
#
#                      AWAY_FG3A  AWAY_FG3_PCT  AWAY_FTM  AWAY_FTA  AWAY_FT_PCT  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23       34.0         0.294         9        15        0.600
# 22100059 2021-10-27       30.0         0.267        14        17        0.824
# 22100066 2021-10-28       21.0         0.286         9        14        0.643
# 22100082 2021-10-30       22.0         0.364        14        19        0.737
# 22100113 2021-11-03       35.0         0.371        13        15        0.867
# 22100137 2021-11-06       33.0         0.394        20        23        0.870
# 22100152 2021-11-08       43.0         0.395        20        26        0.769
# 22100156 2021-11-09       35.0         0.514         6        10        0.600
# 22100182 2021-11-12       28.0         0.179        15        21        0.714
# 22100277 2021-11-24       26.0         0.462        22        24        0.917
#
#                      AWAY_OREB  AWAY_DREB  AWAY_REB  AWAY_AST  AWAY_STL  \
# GAME_ID  GAME_DATE
# 22100027 2021-10-23       17.0       37.0      54.0        20       5.0
# 22100059 2021-10-27       21.0       34.0      55.0        21       4.0
# 22100066 2021-10-28        6.0       37.0      43.0        26       4.0
# 22100082 2021-10-30       20.0       29.0      49.0        24       6.0
# 22100113 2021-11-03       12.0       40.0      52.0        23       8.0
# 22100137 2021-11-06       14.0       36.0      50.0        18       3.0
# 22100152 2021-11-08        3.0       32.0      35.0        21       6.0
# 22100156 2021-11-09        6.0       26.0      32.0        22       6.0
# 22100182 2021-11-12       14.0       36.0      50.0        20       2.0
# 22100277 2021-11-24        8.0       36.0      44.0        26      10.0
#
#                      AWAY_BLK  AWAY_TOV  AWAY_PF  GAME_RESULT  TOTAL_PTS
# GAME_ID  GAME_DATE
# 22100027 2021-10-23         3         9       23            1        196
# 22100059 2021-10-27         4        11       14            0        201
# 22100066 2021-10-28         3        13       16            1        233
# 22100082 2021-10-30         1        19       17            1        216
# 22100113 2021-11-03         4        14       16            1        225
# 22100137 2021-11-06         1        12       16            1        238
# 22100152 2021-11-08         2        18       16            1        240
# 22100156 2021-11-09         5        11       18            1        208
# 22100182 2021-11-12         5         8       20            1        201
# 22100277 2021-11-24         5         9       11            0        230

# %%
# apply grouping for rolling calculation
group_cols = [team_col, 'SEASON_ID'] if stratify_by_season else [team_col]
print(group_cols)

# group by 'group_cols' so that you only have home or away team stats stratified by season
rolling_stats = df_sorted.groupby(group_cols)
# Out:
# ['AWAY_TEAM_NAME', 'SEASON_ID']

# %%
# this cell is to double check the work of the full rolling diff

# Filter rolling_stats df to only show numerical stats
# Then take the difference between columns
# ie HOME_PTS - AWAY_PTS, and roll the calculation rightward
# Afterwards filter the columns to only display home stats, as the away stats will have become nan 
rolling_stats[filtered_stats_cols_both].diff(axis=1,periods=18)
# Out:
#                                                   HOME_PTS  HOME_FGM  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       NaN       NaN
#                              22100059 2021-10-27       NaN       NaN
#                              22100066 2021-10-28       NaN       NaN
#                              22100082 2021-10-30       NaN       NaN
#                              22100113 2021-11-03       NaN       NaN
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10       NaN       NaN
#                              22300543 2024-01-13       NaN       NaN
#                              22300579 2024-01-18       NaN       NaN
#                              22300642 2024-01-27       NaN       NaN
#                              22300665 2024-01-29       NaN       NaN
#
#                                                   HOME_FGA  HOME_FG_PCT  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       NaN          NaN
#                              22100059 2021-10-27       NaN          NaN
#                              22100066 2021-10-28       NaN          NaN
#                              22100082 2021-10-30       NaN          NaN
#                              22100113 2021-11-03       NaN          NaN
# ...                                                    ...          ...
# Washington Wizards 2023-24   22300520 2024-01-10       NaN          NaN
#                              22300543 2024-01-13       NaN          NaN
#                              22300579 2024-01-18       NaN          NaN
#                              22300642 2024-01-27       NaN          NaN
#                              22300665 2024-01-29       NaN          NaN
#
#                                                   HOME_FG3M  HOME_FG3A  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23        NaN        NaN
#                              22100059 2021-10-27        NaN        NaN
#                              22100066 2021-10-28        NaN        NaN
#                              22100082 2021-10-30        NaN        NaN
#                              22100113 2021-11-03        NaN        NaN
# ...                                                     ...        ...
# Washington Wizards 2023-24   22300520 2024-01-10        NaN        NaN
#                              22300543 2024-01-13        NaN        NaN
#                              22300579 2024-01-18        NaN        NaN
#                              22300642 2024-01-27        NaN        NaN
#                              22300665 2024-01-29        NaN        NaN
#
#                                                   HOME_FG3_PCT  HOME_FTM  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23           NaN       NaN
#                              22100059 2021-10-27           NaN       NaN
#                              22100066 2021-10-28           NaN       NaN
#                              22100082 2021-10-30           NaN       NaN
#                              22100113 2021-11-03           NaN       NaN
# ...                                                        ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10           NaN       NaN
#                              22300543 2024-01-13           NaN       NaN
#                              22300579 2024-01-18           NaN       NaN
#                              22300642 2024-01-27           NaN       NaN
#                              22300665 2024-01-29           NaN       NaN
#
#                                                   HOME_FTA  HOME_FT_PCT  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       NaN          NaN
#                              22100059 2021-10-27       NaN          NaN
#                              22100066 2021-10-28       NaN          NaN
#                              22100082 2021-10-30       NaN          NaN
#                              22100113 2021-11-03       NaN          NaN
# ...                                                    ...          ...
# Washington Wizards 2023-24   22300520 2024-01-10       NaN          NaN
#                              22300543 2024-01-13       NaN          NaN
#                              22300579 2024-01-18       NaN          NaN
#                              22300642 2024-01-27       NaN          NaN
#                              22300665 2024-01-29       NaN          NaN
#
#                                                   HOME_OREB  HOME_DREB  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23        NaN        NaN
#                              22100059 2021-10-27        NaN        NaN
#                              22100066 2021-10-28        NaN        NaN
#                              22100082 2021-10-30        NaN        NaN
#                              22100113 2021-11-03        NaN        NaN
# ...                                                     ...        ...
# Washington Wizards 2023-24   22300520 2024-01-10        NaN        NaN
#                              22300543 2024-01-13        NaN        NaN
#                              22300579 2024-01-18        NaN        NaN
#                              22300642 2024-01-27        NaN        NaN
#                              22300665 2024-01-29        NaN        NaN
#
#                                                   HOME_REB  HOME_AST  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       NaN       NaN
#                              22100059 2021-10-27       NaN       NaN
#                              22100066 2021-10-28       NaN       NaN
#                              22100082 2021-10-30       NaN       NaN
#                              22100113 2021-11-03       NaN       NaN
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10       NaN       NaN
#                              22300543 2024-01-13       NaN       NaN
#                              22300579 2024-01-18       NaN       NaN
#                              22300642 2024-01-27       NaN       NaN
#                              22300665 2024-01-29       NaN       NaN
#
#                                                   HOME_STL  HOME_BLK  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       NaN       NaN
#                              22100059 2021-10-27       NaN       NaN
#                              22100066 2021-10-28       NaN       NaN
#                              22100082 2021-10-30       NaN       NaN
#                              22100113 2021-11-03       NaN       NaN
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10       NaN       NaN
#                              22300543 2024-01-13       NaN       NaN
#                              22300579 2024-01-18       NaN       NaN
#                              22300642 2024-01-27       NaN       NaN
#                              22300665 2024-01-29       NaN       NaN
#
#                                                   HOME_TOV  HOME_PF  AWAY_PTS  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       NaN      NaN        -6
#                              22100059 2021-10-27       NaN      NaN         3
#                              22100066 2021-10-28       NaN      NaN       -11
#                              22100082 2021-10-30       NaN      NaN       -28
#                              22100113 2021-11-03       NaN      NaN        -9
# ...                                                    ...      ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10       NaN      NaN        -8
#                              22300543 2024-01-13       NaN      NaN        28
#                              22300579 2024-01-18       NaN      NaN        -4
#                              22300642 2024-01-27       NaN      NaN        14
#                              22300665 2024-01-29       NaN      NaN         5
#
#                                                   AWAY_FGM  AWAY_FGA  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23         1        10
#                              22100059 2021-10-27         0         3
#                              22100066 2021-10-28         2       -11
#                              22100082 2021-10-30       -10         9
#                              22100113 2021-11-03        -2         6
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10        -3        -4
#                              22300543 2024-01-13        15         4
#                              22300579 2024-01-18         2         4
#                              22300642 2024-01-27         8        15
#                              22300665 2024-01-29         3        -6
#
#                                                   AWAY_FG_PCT  AWAY_FG3M  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       -0.032          3
#                              22100059 2021-10-27       -0.013         -3
#                              22100066 2021-10-28        0.080         -7
#                              22100082 2021-10-30       -0.156         -4
#                              22100113 2021-11-03       -0.053         -9
# ...                                                       ...        ...
# Washington Wizards 2023-24   22300520 2024-01-10       -0.014         -1
#                              22300543 2024-01-13        0.141          1
#                              22300579 2024-01-18        0.003         -3
#                              22300642 2024-01-27        0.015          2
#                              22300665 2024-01-29        0.068         -3
#
#                                                   AWAY_FG3A  AWAY_FG3_PCT  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23        6.0         0.044
#                              22100059 2021-10-27       -6.0        -0.039
#                              22100066 2021-10-28      -13.0        -0.096
#                              22100082 2021-10-30      -16.0         0.048
#                              22100113 2021-11-03      -13.0        -0.087
# ...                                                     ...           ...
# Washington Wizards 2023-24   22300520 2024-01-10        6.0        -0.094
#                              22300543 2024-01-13       -8.0         0.100
#                              22300579 2024-01-18       -7.0        -0.019
#                              22300642 2024-01-27        2.0         0.043
#                              22300665 2024-01-29       -5.0        -0.040
#
#                                                   AWAY_FTM  AWAY_FTA  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       -11       -12
#                              22100059 2021-10-27         6         8
#                              22100066 2021-10-28        -8        -7
#                              22100082 2021-10-30        -4         0
#                              22100113 2021-11-03         4         3
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10        -1         6
#                              22300543 2024-01-13        -3        -7
#                              22300579 2024-01-18        -5        -4
#                              22300642 2024-01-27        -4        -6
#                              22300665 2024-01-29         2         7
#
#                                                   AWAY_FT_PCT  AWAY_OREB  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       -0.141        5.0
#                              22100059 2021-10-27       -0.065       12.0
#                              22100066 2021-10-28       -0.167       -8.0
#                              22100082 2021-10-30       -0.210       15.0
#                              22100113 2021-11-03        0.117        5.0
# ...                                                       ...        ...
# Washington Wizards 2023-24   22300520 2024-01-10       -0.217       -1.0
#                              22300543 2024-01-13        0.081       -4.0
#                              22300579 2024-01-18       -0.073        2.0
#                              22300642 2024-01-27        0.032        5.0
#                              22300665 2024-01-29       -0.174        4.0
#
#                                                   AWAY_DREB  AWAY_REB  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23       -5.0       0.0
#                              22100059 2021-10-27       -1.0      11.0
#                              22100066 2021-10-28        0.0      -8.0
#                              22100082 2021-10-30       -3.0      12.0
#                              22100113 2021-11-03        5.0      10.0
# ...                                                     ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10       -7.0      -8.0
#                              22300543 2024-01-13        8.0       4.0
#                              22300579 2024-01-18       -3.0      -1.0
#                              22300642 2024-01-27        0.0       5.0
#                              22300665 2024-01-29        5.0       9.0
#
#                                                   AWAY_AST  AWAY_STL  \
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23        -3      -1.0
#                              22100059 2021-10-27        -3      -1.0
#                              22100066 2021-10-28         0      -2.0
#                              22100082 2021-10-30         0      -5.0
#                              22100113 2021-11-03       -11       1.0
# ...                                                    ...       ...
# Washington Wizards 2023-24   22300520 2024-01-10        -7       1.0
#                              22300543 2024-01-13        11       1.0
#                              22300579 2024-01-18         9       3.0
#                              22300642 2024-01-27         4       8.0
#                              22300665 2024-01-29         1      -1.0
#
#                                                   AWAY_BLK  AWAY_TOV  AWAY_PF
# AWAY_TEAM_NAME     SEASON_ID GAME_ID  GAME_DATE
# Atlanta Hawks      2021-22   22100027 2021-10-23        -3        -1        7
#                              22100059 2021-10-27        -2         2       -5
#                              22100066 2021-10-28        -1         7        0
#                              22100082 2021-10-30        -5         7       -7
#                              22100113 2021-11-03        -4         0       -2
# ...                                                    ...       ...      ...
# Washington Wizards 2023-24   22300520 2024-01-10         2         0        1
#                              22300543 2024-01-13         2        -2        2
#                              22300579 2024-01-18        -1        -5        6
#                              22300642 2024-01-27        -4        -8       -1
#                              22300665 2024-01-29         1         4       -2
#
# [3172 rows x 36 columns]

# %%
# Run full the sorting, difference, and rolling average functions from df_sorted
rolling_diff_stats_away = (df_sorted.groupby(group_cols)[filtered_stats_cols_both]
                                .diff(axis=1,periods=18)[filtered_stats_cols_away]
                                .rolling(window=5, min_periods=1)
                                .mean()
                                .round(5)
                                .groupby(group_cols) # need to groupby again for shift
                                .shift(1)  # lag to exclude the current game from the rolling average
                                .add_prefix('ROLLDIFF_')
                                .reset_index() # reset the index to convert GAME_ID back into a column
                     )

# check if rolling diff stats has worked
rolling_diff_stats_away
# Out:
#           AWAY_TEAM_NAME SEASON_ID   GAME_ID  GAME_DATE  ROLLDIFF_AWAY_PTS  \
# 0          Atlanta Hawks   2021-22  22100027 2021-10-23                NaN
# 1          Atlanta Hawks   2021-22  22100059 2021-10-27             -6.000
# 2          Atlanta Hawks   2021-22  22100066 2021-10-28             -1.500
# 3          Atlanta Hawks   2021-22  22100082 2021-10-30             -4.667
# 4          Atlanta Hawks   2021-22  22100113 2021-11-03            -10.500
# ...                  ...       ...       ...        ...                ...
# 3167  Washington Wizards   2023-24  22300520 2024-01-10            -13.000
# 3168  Washington Wizards   2023-24  22300543 2024-01-13            -13.800
# 3169  Washington Wizards   2023-24  22300579 2024-01-18             -5.800
# 3170  Washington Wizards   2023-24  22300642 2024-01-27             -6.800
# 3171  Washington Wizards   2023-24  22300665 2024-01-29             -1.800
#
#       ROLLDIFF_AWAY_FGM  ROLLDIFF_AWAY_FGA  ROLLDIFF_AWAY_FG_PCT  \
# 0                   NaN                NaN                   NaN
# 1                  1.00             10.000                -0.032
# 2                  0.50              6.500                -0.022
# 3                  1.00              0.667                 0.012
# 4                 -1.75              2.750                -0.030
# ...                 ...                ...                   ...
# 3167              -5.40             -4.200                -0.032
# 3168              -5.60             -6.000                -0.026
# 3169              -0.80             -2.200                 0.005
# 3170              -0.20              0.800                -0.004
# 3171               2.00              3.800                 0.005
#
#       ROLLDIFF_AWAY_FG3M  ROLLDIFF_AWAY_FG3A  ROLLDIFF_AWAY_FG3_PCT  \
# 0                    NaN                 NaN                    NaN
# 1                  3.000               6.000                  0.044
# 2                  0.000               0.000                  0.003
# 3                 -2.333              -4.333                 -0.030
# 4                 -2.750              -7.250                 -0.011
# ...                  ...                 ...                    ...
# 3167              -1.800              -1.400                 -0.026
# 3168              -3.400              -3.200                 -0.060
# 3169              -3.400              -3.800                 -0.056
# 3170              -3.600              -5.200                 -0.046
# 3171              -1.800              -2.800                 -0.021
#
#       ROLLDIFF_AWAY_FTM  ROLLDIFF_AWAY_FTA  ROLLDIFF_AWAY_FT_PCT  \
# 0                   NaN                NaN                   NaN
# 1               -11.000            -12.000                -0.141
# 2                -2.500             -2.000                -0.103
# 3                -4.333             -3.667                -0.124
# 4                -4.250             -2.750                -0.146
# ...                 ...                ...                   ...
# 3167             -0.400              0.400                -0.061
# 3168              0.800              3.600                -0.111
# 3169             -0.800              1.400                -0.108
# 3170             -2.800             -1.200                -0.112
# 3171             -4.000             -3.200                -0.094
#
#       ROLLDIFF_AWAY_OREB  ROLLDIFF_AWAY_DREB  ROLLDIFF_AWAY_REB  \
# 0                    NaN                 NaN                NaN
# 1                    5.0               -5.00               0.00
# 2                    8.5               -3.00               5.50
# 3                    3.0               -2.00               1.00
# 4                    6.0               -2.25               3.75
# ...                  ...                 ...                ...
# 3167                -6.2               -8.00             -14.20
# 3168                -5.8               -8.00             -13.80
# 3169                -5.8               -6.60             -12.40
# 3170                -2.8               -7.00              -9.80
# 3171                -0.8               -4.40              -5.20
#
#       ROLLDIFF_AWAY_AST  ROLLDIFF_AWAY_STL  ROLLDIFF_AWAY_BLK  \
# 0                   NaN                NaN                NaN
# 1                  -3.0             -1.000              -3.00
# 2                  -3.0             -1.000              -2.50
# 3                  -2.0             -1.333              -2.00
# 4                  -1.5             -2.250              -2.75
# ...                 ...                ...                ...
# 3167               -7.0              0.400               0.00
# 3168               -7.4              0.600               0.40
# 3169               -3.4              1.800               0.60
# 3170               -2.0              2.000               0.40
# 3171                0.4              3.200              -0.80
#
#       ROLLDIFF_AWAY_TOV  ROLLDIFF_AWAY_PF
# 0                   NaN               NaN
# 1                -1.000             7.000
# 2                 0.500             1.000
# 3                 2.667             0.667
# 4                 3.750            -1.250
# ...                 ...               ...
# 3167             -2.000            -0.800
# 3168             -0.600            -2.400
# 3169             -1.800            -1.400
# 3170             -2.000             1.800
# 3171             -3.000             1.800
#
# [3172 rows x 22 columns]

# %% [markdown]
# ## Checking by game ID

# %%
df_check_away = rolling_diff_stats_away[rolling_diff_stats_away['GAME_ID'] == 22300704]
df_check_home = rolling_diff_stats_home[rolling_diff_stats_home['GAME_ID'] == 22300704]

# %%
df_check_home
# Out:
#       HOME_TEAM_NAME SEASON_ID   GAME_ID  GAME_DATE  ROLLDIFF_HOME_PTS  \
# 954  Detroit Pistons   2023-24  22300704 2024-02-04               -2.2
#
#      ROLLDIFF_HOME_FGM  ROLLDIFF_HOME_FGA  ROLLDIFF_HOME_FG_PCT  \
# 954               -2.0               -3.6                -0.005
#
#      ROLLDIFF_HOME_FG3M  ROLLDIFF_HOME_FG3A  ROLLDIFF_HOME_FG3_PCT  \
# 954                 0.8                -0.4                  0.023
#
#      ROLLDIFF_HOME_FTM  ROLLDIFF_HOME_FTA  ROLLDIFF_HOME_FT_PCT  \
# 954                1.0                2.8                -0.044
#
#      ROLLDIFF_HOME_OREB  ROLLDIFF_HOME_DREB  ROLLDIFF_HOME_REB  \
# 954                -0.6                -0.2               -0.8
#
#      ROLLDIFF_HOME_AST  ROLLDIFF_HOME_STL  ROLLDIFF_HOME_BLK  \
# 954                0.2               -4.0               -1.0
#
#      ROLLDIFF_HOME_TOV  ROLLDIFF_HOME_PF
# 954                3.0              -2.2

# %%
df_check_away
# Out:
#      AWAY_TEAM_NAME SEASON_ID   GAME_ID  GAME_DATE  ROLLDIFF_AWAY_PTS  \
# 2320  Orlando Magic   2023-24  22300704 2024-02-04                1.4
#
#       ROLLDIFF_AWAY_FGM  ROLLDIFF_AWAY_FGA  ROLLDIFF_AWAY_FG_PCT  \
# 2320                0.8                6.2                -0.031
#
#       ROLLDIFF_AWAY_FG3M  ROLLDIFF_AWAY_FG3A  ROLLDIFF_AWAY_FG3_PCT  \
# 2320                -0.8                -2.0                 -0.008
#
#       ROLLDIFF_AWAY_FTM  ROLLDIFF_AWAY_FTA  ROLLDIFF_AWAY_FT_PCT  \
# 2320                0.6                1.2                -0.008
#
#       ROLLDIFF_AWAY_OREB  ROLLDIFF_AWAY_DREB  ROLLDIFF_AWAY_REB  \
# 2320                 4.8                -4.0                0.8
#
#       ROLLDIFF_AWAY_AST  ROLLDIFF_AWAY_STL  ROLLDIFF_AWAY_BLK  \
# 2320               -1.4                2.4               -0.6
#
#       ROLLDIFF_AWAY_TOV  ROLLDIFF_AWAY_PF
# 2320               -4.4               0.8
