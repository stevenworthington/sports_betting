# %% [markdown]
# # Setup

# %%
# basic modules
import os
import time
import random as rn
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# plotting style
plt.style.use('seaborn-v0_8-notebook')
sns.set_style('white')
#sns.set_style('darkgrid')

# pandas tricks for better display
pd.options.display.max_columns = 50  
pd.options.display.max_rows = 500     
pd.options.display.max_colwidth = 100
pd.options.display.precision = 3

# preprocessing
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin

# warnings
import warnings
warnings.filterwarnings("ignore")

# user defined functions
import utility_functions as utl

# %% [markdown]
# # Synthetic Data

# %%
import pandas as pd
from datetime import timedelta, datetime

# Create a synthetic dataset
data = {
    "SEASON_ID": [],
    "GAME_ID": [],
    "GAME_DATE": [],
    "HOME_TEAM_NAME": [],
    "AWAY_TEAM_NAME": [],
    "HOME_STAT1": [],
    "AWAY_STAT1": [],
    "HOME_STAT2": [],
    "AWAY_STAT2": [],
    "HOME_STAT3": [],
    "AWAY_STAT3": []
}

# Define some parameters for the synthetic data
teams = ["Team A", "Team B"]
seasons = ["Season 1", "Season 2"]
start_date = datetime(2022, 1, 1)
games_per_team_per_season = 30 // (len(teams) * len(seasons))

# Generate the data
game_id = 1
for season in seasons:
    for team_home in teams:
        for team_away in teams:
            if team_home != team_away:
                for game in range(games_per_team_per_season):
                    game_date = start_date + timedelta(days=game_id - 1)
                    data["SEASON_ID"].append(season)
                    data["GAME_ID"].append(f"Game{game_id}")
                    data["GAME_DATE"].append(game_date.strftime("%Y-%m-%d"))
                    data["HOME_TEAM_NAME"].append(team_home)
                    data["AWAY_TEAM_NAME"].append(team_away)
                    data["HOME_STAT1"].append(game_id * 2)
                    data["AWAY_STAT1"].append(game_id * 2 + 1)
                    data["HOME_STAT2"].append(game_id * 3)
                    data["AWAY_STAT2"].append(game_id * 3 + 1)
                    data["HOME_STAT3"].append(game_id * 4)
                    data["AWAY_STAT3"].append(game_id * 4 + 1)
                    game_id += 1

# Create DataFrame
df = pd.DataFrame(data)

# Adding the 'TOTAL_POINTS' column with random integers in the range [150, 250]
df['TOTAL_POINTS'] = np.random.randint(150, 251, size=len(df))

print(df.shape)
df
# Out:
# (28, 12)
#    SEASON_ID GAME_ID   GAME_DATE HOME_TEAM_NAME AWAY_TEAM_NAME  HOME_STAT1  \
# 0   Season 1   Game1  2022-01-01         Team A         Team B           2
# 1   Season 1   Game2  2022-01-02         Team A         Team B           4
# 2   Season 1   Game3  2022-01-03         Team A         Team B           6
# 3   Season 1   Game4  2022-01-04         Team A         Team B           8
# 4   Season 1   Game5  2022-01-05         Team A         Team B          10
# 5   Season 1   Game6  2022-01-06         Team A         Team B          12
# 6   Season 1   Game7  2022-01-07         Team A         Team B          14
# 7   Season 1   Game8  2022-01-08         Team B         Team A          16
# 8   Season 1   Game9  2022-01-09         Team B         Team A          18
# 9   Season 1  Game10  2022-01-10         Team B         Team A          20
# 10  Season 1  Game11  2022-01-11         Team B         Team A          22
# 11  Season 1  Game12  2022-01-12         Team B         Team A          24
# 12  Season 1  Game13  2022-01-13         Team B         Team A          26
# 13  Season 1  Game14  2022-01-14         Team B         Team A          28
# 14  Season 2  Game15  2022-01-15         Team A         Team B          30
# 15  Season 2  Game16  2022-01-16         Team A         Team B          32
# 16  Season 2  Game17  2022-01-17         Team A         Team B          34
# 17  Season 2  Game18  2022-01-18         Team A         Team B          36
# 18  Season 2  Game19  2022-01-19         Team A         Team B          38
# 19  Season 2  Game20  2022-01-20         Team A         Team B          40
# 20  Season 2  Game21  2022-01-21         Team A         Team B          42
# 21  Season 2  Game22  2022-01-22         Team B         Team A          44
# 22  Season 2  Game23  2022-01-23         Team B         Team A          46
# 23  Season 2  Game24  2022-01-24         Team B         Team A          48
# 24  Season 2  Game25  2022-01-25         Team B         Team A          50
# 25  Season 2  Game26  2022-01-26         Team B         Team A          52
# 26  Season 2  Game27  2022-01-27         Team B         Team A          54
# 27  Season 2  Game28  2022-01-28         Team B         Team A          56
#
#     AWAY_STAT1  HOME_STAT2  AWAY_STAT2  HOME_STAT3  AWAY_STAT3  TOTAL_POINTS
# 0            3           3           4           4           5           161
# 1            5           6           7           8           9           238
# 2            7           9          10          12          13           230
# 3            9          12          13          16          17           248
# 4           11          15          16          20          21           176
# 5           13          18          19          24          25           211
# 6           15          21          22          28          29           227
# 7           17          24          25          32          33           190
# 8           19          27          28          36          37           174
# 9           21          30          31          40          41           212
# 10          23          33          34          44          45           161
# 11          25          36          37          48          49           207
# 12          27          39          40          52          53           163
# 13          29          42          43          56          57           197
# 14          31          45          46          60          61           177
# 15          33          48          49          64          65           163
# 16          35          51          52          68          69           176
# 17          37          54          55          72          73           234
# 18          39          57          58          76          77           200
# 19          41          60          61          80          81           247
# 20          43          63          64          84          85           211
# 21          45          66          67          88          89           216
# 22          47          69          70          92          93           172
# 23          49          72          73          96          97           162
# 24          51          75          76         100         101           180
# 25          53          78          79         104         105           172
# 26          55          81          82         108         109           237
# 27          57          84          85         112         113           231

# %% [markdown]
# # Prepare Data

# %%
prefix = 'HOME_' if 'HOME' in 'HOME_TEAM_NAME' else 'AWAY_'

stats_cols = ['HOME_STAT1',	'AWAY_STAT1',	'HOME_STAT2',	'AWAY_STAT2',	'HOME_STAT3',	'AWAY_STAT3']

# filter the stats columns based on the prefix
filtered_stats_cols = [col for col in stats_cols if col.startswith(prefix)]

# %%
filtered_stats_cols
# Out:
# ['HOME_STAT1', 'HOME_STAT2', 'HOME_STAT3']

# %%
sort_cols = ['HOME_TEAM_NAME', 'SEASON_ID', 'GAME_DATE']
df_sorted = df.sort_values(by=sort_cols).set_index(['GAME_ID', 'GAME_DATE'])

# %%
group_cols1 = 'HOME_TEAM_NAME'
group_cols2 = ['HOME_TEAM_NAME', 'SEASON_ID']

# %%
df_sorted
# Out:
#                    SEASON_ID HOME_TEAM_NAME AWAY_TEAM_NAME  HOME_STAT1  \
# GAME_ID GAME_DATE
# Game1   2022-01-01  Season 1         Team A         Team B           2
# Game2   2022-01-02  Season 1         Team A         Team B           4
# Game3   2022-01-03  Season 1         Team A         Team B           6
# Game20  2022-01-20          81           247
# Game21  2022-01-21          85           211
# Game8   2022-01-08          33           190
# Game9   2022-01-09          37           174
# Game10  2022-01-10          41           212
# Game11  2022-01-11          45           161
# Game12  2022-01-12          49           207
# Game13  2022-01-13          53           163
# Game14  2022-01-14          57           197
# Game22  2022-01-22          89           216
# Game23  2022-01-23          93           172
# Game24  2022-01-24          97           162
# Game25  2022-01-25         101           180
# Game26  2022-01-26         105           172
# Game27  2022-01-27         109           237
# Game28  2022-01-28         113           231

# %% [markdown]
# # Experiment 1

# %%
roll_stats = (df_sorted.groupby(group_cols2)[filtered_stats_cols]
                       .rolling(window=3, min_periods=3)
                       .mean()
                       .groupby(group_cols2)
                       .shift(1)
             )
roll_stats
# Out:
#                                              HOME_STAT1  HOME_STAT2  \
# HOME_TEAM_NAME SEASON_ID GAME_ID GAME_DATE
# Team A         Season 1  Game1   2022-01-01         NaN         NaN
#                          Game2   2022-01-02         NaN         NaN
#                          Game3   2022-01-03         NaN         NaN
#                          Game4   2022-01-04         4.0         6.0
#                          Game5   2022-01-05         6.0         9.0
#                          Game6   2022-01-06         8.0        12.0
#                          Game7   2022-01-07        10.0        15.0
#                Season 2  Game15  2022-01-15         NaN         NaN
#                          Game16  2022-01-16         NaN         NaN
#                          Game17  2022-01-17         NaN         NaN
#                          Game18  2022-01-18        32.0        48.0
#                          Game19  2022-01-19        34.0        51.0
#                          Game20  2022-01-20        36.0        54.0
#                          Game21  2022-01-21        38.0        57.0
# Team B         Season 1  Game8   2022-01-08         NaN         NaN
#                          Game9   2022-01-09         NaN         NaN
#                          Game10  2022-01-10         NaN         NaN
#                          Game11  2022-01-11        18.0        27.0
#                          Game12  2022-01-12        20.0        30.0
#                          Game13  2022-01-13        22.0        33.0
#                          Game14  2022-01-14        24.0        36.0
#                Season 2  Game22  2022-01-22         NaN         NaN
#                          Game23  2022-01-23         NaN         NaN
#                          Game24  2022-01-24         NaN         NaN
#                          Game25  2022-01-25        46.0        69.0
#                          Game26  2022-01-26        48.0        72.0
#                          Game27  2022-01-27        50.0        75.0
#                          Game28  2022-01-28        52.0        78.0
#
#                                              HOME_STAT3
# HOME_TEAM_NAME SEASON_ID GAME_ID GAME_DATE
# Team A         Season 1  Game1   2022-01-01         NaN
#                          Game2   2022-01-02         NaN
#                          Game3   2022-01-03         NaN
#                          Game4   2022-01-04         8.0
#                          Game5   2022-01-05        12.0
#                          Game6   2022-01-06        16.0
#                          Game7   2022-01-07        20.0
#                Season 2  Game15  2022-01-15         NaN
#                          Game16  2022-01-16         NaN
#                          Game17  2022-01-17         NaN
#                          Game18  2022-01-18        64.0
#                          Game19  2022-01-19        68.0
#                          Game20  2022-01-20        72.0
#                          Game21  2022-01-21        76.0
# Team B         Season 1  Game8   2022-01-08         NaN
#                          Game9   2022-01-09         NaN
#                          Game10  2022-01-10         NaN
#                          Game11  2022-01-11        36.0
#                          Game12  2022-01-12        40.0
#                          Game13  2022-01-13        44.0
#                          Game14  2022-01-14        48.0
#                Season 2  Game22  2022-01-22         NaN
#                          Game23  2022-01-23         NaN
#                          Game24  2022-01-24         NaN
#                          Game25  2022-01-25        92.0
#                          Game26  2022-01-26        96.0
#                          Game27  2022-01-27       100.0
#                          Game28  2022-01-28       104.0

# %% [markdown]
# # Experiment 2

# %%
roll_stats = (df_sorted.groupby(group_cols2)[filtered_stats_cols]
                       .rolling(window=3, min_periods=1)
                       .mean()
                       .groupby(group_cols2)
                       .shift(1)
             )
roll_stats
# Out:
#                                              HOME_STAT1  HOME_STAT2  \
# HOME_TEAM_NAME SEASON_ID GAME_ID GAME_DATE
# Team A         Season 1  Game1   2022-01-01         NaN         NaN
#                          Game2   2022-01-02         2.0         3.0
#                          Game3   2022-01-03         3.0         4.5
#                          Game4   2022-01-04         4.0         6.0
#                          Game5   2022-01-05         6.0         9.0
#                          Game6   2022-01-06         8.0        12.0
#                          Game7   2022-01-07        10.0        15.0
#                Season 2  Game15  2022-01-15         NaN         NaN
#                          Game16  2022-01-16        30.0        45.0
#                          Game17  2022-01-17        31.0        46.5
#                          Game18  2022-01-18        32.0        48.0
#                          Game19  2022-01-19        34.0        51.0
#                          Game20  2022-01-20        36.0        54.0
#                          Game21  2022-01-21        38.0        57.0
# Team B         Season 1  Game8   2022-01-08         NaN         NaN
#                          Game9   2022-01-09        16.0        24.0
#                          Game10  2022-01-10        17.0        25.5
#                          Game11  2022-01-11        18.0        27.0
#                          Game12  2022-01-12        20.0        30.0
#                          Game13  2022-01-13        22.0        33.0
#                          Game14  2022-01-14        24.0        36.0
#                Season 2  Game22  2022-01-22         NaN         NaN
#                          Game23  2022-01-23        44.0        66.0
#                          Game24  2022-01-24        45.0        67.5
#                          Game25  2022-01-25        46.0        69.0
#                          Game26  2022-01-26        48.0        72.0
#                          Game27  2022-01-27        50.0        75.0
#                          Game28  2022-01-28        52.0        78.0
#
#                                              HOME_STAT3
# HOME_TEAM_NAME SEASON_ID GAME_ID GAME_DATE
# Team A         Season 1  Game1   2022-01-01         NaN
#                          Game2   2022-01-02         4.0
#                          Game3   2022-01-03         6.0
#                          Game4   2022-01-04         8.0
#                          Game5   2022-01-05        12.0
#                          Game6   2022-01-06        16.0
#                          Game7   2022-01-07        20.0
#                Season 2  Game15  2022-01-15         NaN
#                          Game16  2022-01-16        60.0
#                          Game17  2022-01-17        62.0
#                          Game18  2022-01-18        64.0
#                          Game19  2022-01-19        68.0
#                          Game20  2022-01-20        72.0
#                          Game21  2022-01-21        76.0
# Team B         Season 1  Game8   2022-01-08         NaN
#                          Game9   2022-01-09        32.0
#                          Game10  2022-01-10        34.0
#                          Game11  2022-01-11        36.0
#                          Game12  2022-01-12        40.0
#                          Game13  2022-01-13        44.0
#                          Game14  2022-01-14        48.0
#                Season 2  Game22  2022-01-22         NaN
#                          Game23  2022-01-23        88.0
#                          Game24  2022-01-24        90.0
#                          Game25  2022-01-25        92.0
#                          Game26  2022-01-26        96.0
#                          Game27  2022-01-27       100.0
#                          Game28  2022-01-28       104.0
