# %%
import pandas as pd

# %%
from nba_api.stats.endpoints import playercareerstats

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
career.get_data_frames()[0]

# json
# career.get_json()

# dictionary
 #career.get_dict()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203999   2015-16        00  1610612743               DEN        21.0
# 1     203999   2016-17        00  1610612743               DEN        22.0
# 2     203999   2017-18        00  1610612743               DEN        23.0
# 3     203999   2018-19        00  1610612743               DEN        24.0
# 4     203999   2019-20        00  1610612743               DEN        25.0
# 5     203999   2020-21        00  1610612743               DEN        26.0
# 6     203999   2021-22        00  1610612743               DEN        27.0
# 7     203999   2022-23        00  1610612743               DEN        28.0
# 8     203999   2023-24        00  1610612743               DEN        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0  80  55  1733.0  307  ...   0.811   181   379   560  189   79   50  104
# ...

# %%
from nba_api.stats.static import teams

# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print("Number of teams fetched: {}".format(len(nba_teams)))
pd.DataFrame(nba_teams)
# Out:
# Number of teams fetched: 30
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
from nba_api.stats.endpoints import TeamGameLogs

mav_id = '1610612742'

logs = TeamGameLogs.DataSet()

logs.get_data_frame(data=)
# Out:
#   Cell In[16], line 7
#     logs.get_data_frame(data=)
#                              ^
# SyntaxError: invalid syntax

# %%
from nba_api.stats.endpoints import TeamEstimatedMetrics

# %%
from nba_api.stats.endpoints import leaguegamefinder

celtics_id = '1610612738'
mav_id = '1610612742'

# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=mav_id)
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION         TEAM_NAME     GAME_ID  \
# 0     22023  1610612742               DAL  Dallas Mavericks  0022300515
# 1     22023  1610612742               DAL  Dallas Mavericks  0022300501
# 2     22023  1610612742               DAL  Dallas Mavericks  0022300487
# 3     22023  1610612742               DAL  Dallas Mavericks  0022300472
# 4     22023  1610612742               DAL  Dallas Mavericks  0022300457
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2024-01-09  DAL vs. MEM  L  240  103  ...   0.815     8    25   33   20
# 1  2024-01-07  DAL vs. MIN  W  240  115  ...   0.700    15    29   44   20
# 2  2024-01-05  DAL vs. POR  W  240  139  ...   0.667    10    42   52   35
# 3  2024-01-03  DAL vs. POR  W  240  126  ...   0.707     7    36   43   25
# 4  2024-01-01    DAL @ UTA  L  241   90  ...   0.500     8    33   41   28
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    9    4   12  17       -17.0
# ...

# %%
from nba_api.stats.static import players

# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print("Number of players fetched: {}".format(len(nba_players)))
pd.DataFrame(nba_players)
# Out:
# Number of players fetched: 4900
#            id            full_name first_name     last_name  is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False
# ...       ...                  ...        ...           ...        ...
# 4895  1627790           Ante Zizic       Ante         Zizic      False
# 4896    78647             Jim Zoet        Jim          Zoet      False
# 4897    78648            Bill Zopf       Bill          Zopf      False
# 4898  1627826          Ivica Zubac      Ivica         Zubac       True
# 4899    78650           Matt Zunic       Matt         Zunic      False
#
# [4900 rows x 5 columns]

# %%
from nba_api.live.nba.endpoints import scoreboard

# Today's Score Board
games = scoreboard.ScoreBoard()

# json
games.get_json()

# dictionary
games.get_dict()

# %% [markdown]
# # Basketball Reference API

# %%
import pandas as pd
from datetime import datetime, timedelta
import time

# %%
from basketball_reference_web_scraper import client
from basketball_reference_web_scraper.data import League, Location, Outcome, OutputType
from basketball_reference_web_scraper.data import OutputWriteOption, Position, PeriodType, Team

# %% [markdown]
# ## Team Box Scores

# %%
start_time = time.time()

# initialize empty list
team_box_scores = []

# define start and end dates
start_date = datetime(2000, 1, 1)
end_date = datetime(2008, 12, 31)

# loop over each day in the range
current_date = start_date
while current_date <= end_date:
    
    print(current_date)
    
    # fetch data for current day
    day_data = client.player_box_scores(day=current_date.day, month=current_date.month, year=current_date.year)
    
    # check if day_data is not empty
    if day_data:
        # add current date to each dictionary in day_data
        for record in day_data:
            record['date'] = current_date

        # append the day's data (list of dictionaries) to team_box_scores
        team_box_scores.extend(day_data)

    # add time delay between requests
    time.sleep(3)
    
    # move to next day
    current_date += timedelta(days=1)

# convert list of dictionaries to a DataFrame
team_box_scores_df = pd.DataFrame(team_box_scores)

end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {total_time} seconds")
# Out:
# 2002-02-01 00:00:00
# 2002-02-02 00:00:00
# 2002-02-03 00:00:00
# Total time taken: 16.34035301208496 seconds

# %%
team_box_scores_df.to_csv('team_box_scores_2000_2008.csv', index=False)

# %%
client.team_box_scores(day=1, month=2, year=2002)

# %% [markdown]
# ## Player Box Scores

# %%
start_time = time.time()

# initialize empty list
player_box_scores = []

# define start and end dates
start_date = datetime(2000, 1, 1)
end_date = datetime(2008, 12, 31)

# loop over each day in the range
current_date = start_date
while current_date <= end_date:
    
    print(current_date)
    
    # fetch data for current day
    day_data = client.player_box_scores(day=current_date.day, month=current_date.month, year=current_date.year)
    
    # check if day_data is not empty
    if day_data:
        # add current date to each dictionary in day_data
        for record in day_data:
            record['date'] = current_date

        # append the day's data (list of dictionaries) to team_box_scores
        player_box_scores.extend(day_data)

    # add time delay between requests
    time.sleep(3)
    
    # move to next day
    current_date += timedelta(days=1)

# convert list of dictionaries to a DataFrame
player_box_scores_df = pd.DataFrame(player_box_scores)

end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {total_time} seconds")

# %%
player_box_scores_df.to_csv('player_box_scores_2000_2008.csv', index=False)

# %%
pd.DataFrame(client.player_box_scores(day=1, month=1, year=2017))
# Out:
#           slug               name                         team       location  \
# 0    lowryky01         Kyle Lowry         Team.TORONTO_RAPTORS  Location.AWAY
# 1    mccolcj01        CJ McCollum  Team.PORTLAND_TRAIL_BLAZERS  Location.AWAY
# 2    aldrila01  LaMarcus Aldridge       Team.SAN_ANTONIO_SPURS  Location.AWAY
# 3    hardati02       Tim Hardaway           Team.ATLANTA_HAWKS  Location.HOME
# 4    russeda01   D'Angelo Russell      Team.LOS_ANGELES_LAKERS  Location.HOME
# ..         ...                ...                          ...            ...
# 99   clarkjo01    Jordan Clarkson      Team.LOS_ANGELES_LAKERS  Location.HOME
# 100  davised01           Ed Davis  Team.PORTLAND_TRAIL_BLAZERS  Location.AWAY
# 101  dedmode01     Dewayne Dedmon       Team.SAN_ANTONIO_SPURS  Location.AWAY
# 102  smithis01          Ish Smith         Team.DETROIT_PISTONS  Location.AWAY
# 103  leoname01     Meyers Leonard  Team.PORTLAND_TRAIL_BLAZERS  Location.AWAY
#
# ...

# %% [markdown]
# ## Season Schedule

# %%
pd.DataFrame(client.season_schedule(season_end_year=2018))
# Out:
#                     start_time                   away_team  \
# 0    2017-10-18 00:01:00+00:00         Team.BOSTON_CELTICS
# 1    2017-10-18 02:30:00+00:00        Team.HOUSTON_ROCKETS
# 2    2017-10-18 23:00:00+00:00      Team.CHARLOTTE_HORNETS
# 3    2017-10-18 23:00:00+00:00          Team.BROOKLYN_NETS
# 4    2017-10-18 23:00:00+00:00             Team.MIAMI_HEAT
# ...                        ...                         ...
# 1307 2018-05-29 01:00:00+00:00  Team.GOLDEN_STATE_WARRIORS
# 1308 2018-06-01 01:00:00+00:00    Team.CLEVELAND_CAVALIERS
# 1309 2018-06-04 00:00:00+00:00    Team.CLEVELAND_CAVALIERS
# 1310 2018-06-07 01:00:00+00:00  Team.GOLDEN_STATE_WARRIORS
# 1311 2018-06-09 01:00:00+00:00  Team.GOLDEN_STATE_WARRIORS
#
#                        home_team  away_team_score  home_team_score
# 0       Team.CLEVELAND_CAVALIERS               99              102
# 1     Team.GOLDEN_STATE_WARRIORS              122              121
# ...

# %% [markdown]
# ## Play by Play

# %%
pd.DataFrame(client.play_by_play(home_team=Team.BOSTON_CELTICS, year=2018, month=10, day=16))
# Out:
#      period         period_type  remaining_seconds_in_period  \
# 0         1  PeriodType.QUARTER                        700.0
# 1         1  PeriodType.QUARTER                        700.0
# 2         1  PeriodType.QUARTER                        675.0
# 3         1  PeriodType.QUARTER                        673.0
# 4         1  PeriodType.QUARTER                        668.0
# ..      ...                 ...                          ...
# 475       4  PeriodType.QUARTER                         48.0
# 476       4  PeriodType.QUARTER                         46.0
# 477       4  PeriodType.QUARTER                         38.0
# 478       4  PeriodType.QUARTER                         22.0
# 479       4  PeriodType.QUARTER                         19.0
#
#                relevant_team                away_team            home_team  \
# 0    Team.PHILADELPHIA_76ERS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 1        Team.BOSTON_CELTICS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# ...

# %% [markdown]
# ## Standings

# %%
pd.DataFrame(client.standings(season_end_year=2019))
# Out:
#                            team  wins  losses            division  \
# 0          Team.TORONTO_RAPTORS    58      24   Division.ATLANTIC
# 1       Team.PHILADELPHIA_76ERS    51      31   Division.ATLANTIC
# 2           Team.BOSTON_CELTICS    49      33   Division.ATLANTIC
# 3            Team.BROOKLYN_NETS    42      40   Division.ATLANTIC
# 4          Team.NEW_YORK_KNICKS    17      65   Division.ATLANTIC
# 5          Team.MILWAUKEE_BUCKS    60      22    Division.CENTRAL
# 6           Team.INDIANA_PACERS    48      34    Division.CENTRAL
# 7          Team.DETROIT_PISTONS    41      41    Division.CENTRAL
# 8            Team.CHICAGO_BULLS    22      60    Division.CENTRAL
# 9      Team.CLEVELAND_CAVALIERS    19      63    Division.CENTRAL
# 10           Team.ORLANDO_MAGIC    42      40  Division.SOUTHEAST
# 11       Team.CHARLOTTE_HORNETS    39      43  Division.SOUTHEAST
# 12              Team.MIAMI_HEAT    39      43  Division.SOUTHEAST
# ...

# %% [markdown]
# ## Player Season Totals (Basic Stats)

# %%
pd.DataFrame(client.players_season_totals(season_end_year=2018))
# Out:
#           slug           name                  positions  age  \
# 0    abrinal01   Álex Abrines  [Position.SHOOTING_GUARD]   24
# 1      acyqu01     Quincy Acy   [Position.POWER_FORWARD]   27
# 2    adamsst01   Steven Adams          [Position.CENTER]   24
# 3    adebaba01    Bam Adebayo          [Position.CENTER]   20
# 4    afflaar01  Arron Afflalo  [Position.SHOOTING_GUARD]   32
# ..         ...            ...                        ...  ...
# 600  zellety01   Tyler Zeller          [Position.CENTER]   28
# 601  zellety01   Tyler Zeller          [Position.CENTER]   28
# 602  zipsepa01    Paul Zipser   [Position.SMALL_FORWARD]   23
# 603  zizican01     Ante Žižić          [Position.CENTER]   21
# 604  zubaciv01    Ivica Zubac          [Position.CENTER]   20
#
#                            team  games_played  games_started  minutes_played  \
# 0    Team.OKLAHOMA_CITY_THUNDER            75              8            1134
# ...

# %% [markdown]
# ## Player Season Totals (Advanced Stats)

# %%
pd.DataFrame(client.players_advanced_season_totals(season_end_year=2018))
# Out:
#           slug           name                  positions  age  \
# 0    abrinal01   Álex Abrines  [Position.SHOOTING_GUARD]   24
# 1      acyqu01     Quincy Acy   [Position.POWER_FORWARD]   27
# 2    adamsst01   Steven Adams          [Position.CENTER]   24
# 3    adebaba01    Bam Adebayo          [Position.CENTER]   20
# 4    afflaar01  Arron Afflalo  [Position.SHOOTING_GUARD]   32
# ..         ...            ...                        ...  ...
# 600  zellety01   Tyler Zeller          [Position.CENTER]   28
# 601  zellety01   Tyler Zeller          [Position.CENTER]   28
# 602  zipsepa01    Paul Zipser   [Position.SMALL_FORWARD]   23
# 603  zizican01     Ante Žižić          [Position.CENTER]   21
# 604  zubaciv01    Ivica Zubac          [Position.CENTER]   20
#
#                            team  games_played  minutes_played  \
# 0    Team.OKLAHOMA_CITY_THUNDER            75            1134
# 1            Team.BROOKLYN_NETS            70            1359
# ...
